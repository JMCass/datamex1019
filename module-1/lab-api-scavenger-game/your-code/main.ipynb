# %%
import requests
import json
import pandas as pd
from pandas.io.json import json_normalize
import numpy as np

# %%
#Challenge 1
url = 'https://api.github.com/repos/ironhack-datalabs/datamex1019/forks'
headers = {'Authorization':'8e9f9f33d7a1b256352dfcdf554158a01d05c31e'}

# %%
respon1 = requests.get(url,)
result1 = respon1.json()
flattened_data1 = json_normalize(result1)
df1 = flattened_data1

# %%
df1
# Out:
#            id                           node_id         name  \
# 0   218619240  MDEwOlJlcG9zaXRvcnkyMTg2MTkyNDA=  datamex1019
# 1   217363066  MDEwOlJlcG9zaXRvcnkyMTczNjMwNjY=  datamex1019
# 2   216659447  MDEwOlJlcG9zaXRvcnkyMTY2NTk0NDc=  datamex1019
# 3   216617567  MDEwOlJlcG9zaXRvcnkyMTY2MTc1Njc=  datamex1019
# 4   216611773  MDEwOlJlcG9zaXRvcnkyMTY2MTE3NzM=  datamex1019
# 5   216610348  MDEwOlJlcG9zaXRvcnkyMTY2MTAzNDg=  datamex1019
# 6   216610307  MDEwOlJlcG9zaXRvcnkyMTY2MTAzMDc=  datamex1019
# 7   216610286  MDEwOlJlcG9zaXRvcnkyMTY2MTAyODY=  datamex1019
# 8   216610287  MDEwOlJlcG9zaXRvcnkyMTY2MTAyODc=  datamex1019
# 9   216610282  MDEwOlJlcG9zaXRvcnkyMTY2MTAyODI=  datamex1019
# 10  216610284  MDEwOlJlcG9zaXRvcnkyMTY2MTAyODQ=  datamex1019
# 11  216610270  MDEwOlJlcG9zaXRvcnkyMTY2MTAyNzA=  datamex1019
# 12  216610271  MDEwOlJlcG9zaXRvcnkyMTY2MTAyNzE=  datamex1019
# 13  216610274  MDEwOlJlcG9zaXRvcnkyMTY2MTAyNzQ=  datamex1019
# ...

# %%
lst = []
for i in df1['language']:
    lst.append(i)

lst
# Out:
# [None,
#  'Jupyter Notebook',
#  'Jupyter Notebook',
#  None,
#  None,
#  'Jupyter Notebook',
#  'Jupyter Notebook',
#  'Jupyter Notebook',
#  'Jupyter Notebook',
#  'Jupyter Notebook',
#  'Jupyter Notebook',
#  None,
#  'Jupyter Notebook',
#  None,
#  'Jupyter Notebook',
#  'Jupyter Notebook',
#  'Jupyter Notebook',
#  'Jupyter Notebook']

# %%
ary = np.array(list(set(lst)))
print(ary)
# Out:
# [None 'Jupyter Notebook']

# %%
#Challenge 2
url2 = 'https://api.github.com/repos/ironhack-datalabs/datamex1019/commits'
headers = {'Authorization':'8e9f9f33d7a1b256352dfcdf554158a01d05c31e'}

# %%
respon2 = requests.get(url2)
result2 = respon2.json()
flattened_data2 = json_normalize(result2)
df2 = pd.DataFrame(flattened_data2)

# %%
df2
# Out:
#                                         sha  \
# 0  242d427ccbf3d7b26bcd1a7c7ed78db7d3a85336
#
#                                              node_id  \
# 0  MDY6Q29tbWl0MjE2NDA3MjQ0OjI0MmQ0MjdjY2JmM2Q3Yj...
#
#                                                  url  \
# 0  https://api.github.com/repos/ironhack-datalabs...
#
#                                             html_url  \
# 0  https://github.com/ironhack-datalabs/datamex10...
#
#                                         comments_url parents  \
# 0  https://api.github.com/repos/ironhack-datalabs...      []
#
#   commit.author.name commit.author.email    commit.author.date  \
# 0          YonatanRA       yeho@mail.com  2019-10-20T18:25:00Z
#
#   commit.committer.name  ...  \
# 0             YonatanRA  ...
#
#                              committer.following_url  \
# 0  https://api.github.com/users/YonatanRA/followi...
#
#                                  committer.gists_url  \
# ...

# %%
lst_lst = []
for i in df2['commit.author.date']:
    if int(i[9]) < 9:
        lst_lst.append(1)

lst_lst
# Out:
# [1]

# %%
print(len(lst_lst))
# Out:
# 1

# %%
#Challenge 3
url='https://api.github.com/repos/ironhack-datalabs/scavenger/contents/'
headers = {'Authorization':'8e9f9f33d7a1b256352dfcdf554158a01d05c31e'}

# %%
response = requests.get(url, headers=headers)
response
# Out:
# <Response [200]>

# %%
data=pd.DataFrame(response.json())
data.head()
# Out:
#          name        path                                       sha  size  \
# 0  .gitignore  .gitignore  e43b0f988953ae3a84b00331d0ccf5f7d51cb3cf    10
# 1       15024       15024  2945e51c87ad5da893c954afcf092f06343bbb7d     0
# 2       15534       15534  5af6f2a7287e4191f39e55693fc1e9c8918d1d3a     0
# 3       17020       17020  9c49f920aa4d9433fa99a5824128f0e6b90ec5f2     0
# 4       30351       30351  c488d7f64088c852e22067d48fdc64ee3670f3ba     0
#
#                                                  url  \
# 0  https://api.github.com/repos/ironhack-datalabs...
# 1  https://api.github.com/repos/ironhack-datalabs...
# 2  https://api.github.com/repos/ironhack-datalabs...
# 3  https://api.github.com/repos/ironhack-datalabs...
# 4  https://api.github.com/repos/ironhack-datalabs...
#
#                                             html_url  \
# 0  https://github.com/ironhack-datalabs/scavenger...
# 1  https://github.com/ironhack-datalabs/scavenger...
# ...

# %%
flattened=json_normalize(response.json())
flattened.head()
# Out:
#          name        path                                       sha  size  \
# 0  .gitignore  .gitignore  e43b0f988953ae3a84b00331d0ccf5f7d51cb3cf    10
# 1       15024       15024  2945e51c87ad5da893c954afcf092f06343bbb7d     0
# 2       15534       15534  5af6f2a7287e4191f39e55693fc1e9c8918d1d3a     0
# 3       17020       17020  9c49f920aa4d9433fa99a5824128f0e6b90ec5f2     0
# 4       30351       30351  c488d7f64088c852e22067d48fdc64ee3670f3ba     0
#
#                                                  url  \
# 0  https://api.github.com/repos/ironhack-datalabs...
# 1  https://api.github.com/repos/ironhack-datalabs...
# 2  https://api.github.com/repos/ironhack-datalabs...
# 3  https://api.github.com/repos/ironhack-datalabs...
# 4  https://api.github.com/repos/ironhack-datalabs...
#
#                                             html_url  \
# 0  https://github.com/ironhack-datalabs/scavenger...
# 1  https://github.com/ironhack-datalabs/scavenger...
# ...
