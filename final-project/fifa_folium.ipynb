# %%
pip install folium
# Out:
# Requirement already satisfied: folium in /usr/local/Cellar/jupyterlab/1.2.3/libexec/lib/python3.7/site-packages (0.10.1)
# Requirement already satisfied: numpy in /usr/local/Cellar/jupyterlab/1.2.3/libexec/lib/python3.7/site-packages (from folium) (1.17.4)
# Requirement already satisfied: requests in /usr/local/Cellar/jupyterlab/1.2.3/libexec/lib/python3.7/site-packages (from folium) (2.22.0)
# Requirement already satisfied: branca>=0.3.0 in /usr/local/Cellar/jupyterlab/1.2.3/libexec/lib/python3.7/site-packages (from folium) (0.3.1)
# Requirement already satisfied: jinja2>=2.9 in /usr/local/Cellar/jupyterlab/1.2.3/libexec/lib/python3.7/site-packages (from folium) (2.10.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/Cellar/jupyterlab/1.2.3/libexec/lib/python3.7/site-packages (from requests->folium) (2019.11.28)
# Requirement already satisfied: idna<2.9,>=2.5 in /usr/local/Cellar/jupyterlab/1.2.3/libexec/lib/python3.7/site-packages (from requests->folium) (2.8)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/Cellar/jupyterlab/1.2.3/libexec/lib/python3.7/site-packages (from requests->folium) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/Cellar/jupyterlab/1.2.3/libexec/lib/python3.7/site-packages (from requests->folium) (1.25.7)
# Requirement already satisfied: six in /usr/local/Cellar/jupyterlab/1.2.3/libexec/lib/python3.7/site-packages (from branca>=0.3.0->folium) (1.12.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/Cellar/jupyterlab/1.2.3/libexec/lib/python3.7/site-packages (from jinja2>=2.9->folium) (1.1.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import folium
import numpy as np
import matplotlib.pyplot as plt

# %%
geoloc_club=pd.read_csv('./Club.csv', index_col=0)
geoloc_club.head()
# Out:
#       Continent Nationality  Div                    Team   Latitude  \
# Index
# 0       America   Argentina  SAF  Club Atlético Aldosivi -38.017944
# 1       America   Argentina  SAF      Argentinos Juniors -34.606028
# 2       America   Argentina  SAF   San Martin de Tucumán -26.836281
# 3       America   Argentina  SAF  Club Atlético Banfield -34.750847
# 4       America   Argentina  SAF     Belgrano de Córdoba -31.403500
#
#        Longitude                                            Stadium
# Index
# 0     -57.582333                                 José María Minella
# 1     -58.472583                 Autocrédito Diego Armando Maradona
# 2     -65.229606                                       La Ciudadela
# 3     -58.387544                                     Florencio Sola
# 4     -64.206272  Estadio Julio César Villagra "El Gigante de Al...

# %%
america_df = geoloc_club['Continent'] == 'America'
df1 = geoloc_club[america_df].reset_index()

# %%
ame_map=folium.Map(location=[19.302778, -99.150556], tiles='cartodbpositron', zoom_start=2)

# %%
lat1 = df1['Latitude']
lng1 = df1['Longitude']
label1 = df1['Stadium']
country1 = df1['Nationality']
division1 = df1['Div']
club1 = df1['Team']

# %%
for i in range(len(lat1)):
    folium.CircleMarker([lat1[i], lng1[i]], radius=1, color='red', popup=('<b>''Club: ''</b>' + club1[i] + '<br>'+
                                                                          '<b>''Stadium: ''</b>' + label1[i] + '<br>'+
                                                                          '<b>''Country: ''</b>' + country1[i] + '<br>'+ 
                                                                          '<b>''Division: ''</b>' + division1[i])
                  ,icon=folium.Icon()).add_to(ame_map)

# %%
ame_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
ame_map.save('america.html')

# %%
europe_df = geoloc_club['Continent'] == 'Europe'
df2 = geoloc_club[europe_df].reset_index()

# %%
eur_map=folium.Map(location=[47.816250, 12.998222], tiles='cartodbpositron', zoom_start=2)

# %%
lat2 = df2['Latitude']
lng2 = df2['Longitude']
label2 = df2['Stadium']
country2 = df2['Nationality']
division2 = df2['Div']
club2 = df2['Team']

# %%
for i in range(len(lat2)):
    folium.CircleMarker([lat2[i], lng2[i]], radius=1, color='green', popup=('<b>''Club: ''</b>' + club2[i] + '<br>'+
                                                                          '<b>''Stadium: ''</b>' + label2[i] + '<br>'+
                                                                          '<b>''Country: ''</b>' + country2[i] + '<br>'+ 
                                                                          '<b>''Division: ''</b>' + division2[i])
                  ,icon=folium.Icon()).add_to(eur_map)

# %%
eur_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
eur_map.save('europe.html')

# %%
asia_df = geoloc_club['Continent'] == 'Asia'
df3 = geoloc_club[asia_df].reset_index()

# %%
asia_map=folium.Map(location=[29.528723, 106.502109], tiles='cartodbpositron', zoom_start=2)

# %%
lat3 = df3['Latitude']
lng3 = df3['Longitude']
label3 = df3['Stadium']
country3 = df3['Nationality']
division3 = df3['Div']
club3 = df3['Team']

# %%
for i in range(len(lat3)):
    folium.CircleMarker([lat3[i], lng3[i]], radius=1, color='orange', popup=('<b>''Club: ''</b>' + club3[i] + '<br>'+
                                                                          '<b>''Stadium: ''</b>' + label3[i] + '<br>'+
                                                                          '<b>''Country: ''</b>' + country3[i] + '<br>'+ 
                                                                          '<b>''Division: ''</b>' + division3[i])
                  ,icon=folium.Icon()).add_to(asia_map)

# %%
asia_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
asia_map.save('asia.html')

# %%
africa_df = geoloc_club['Continent'] == 'Africa'
df4 = geoloc_club[africa_df].reset_index()

# %%
afr_map=folium.Map(location=[-26.234806, 27.982378], tiles='cartodbpositron', zoom_start=2)

# %%
lat4 = df4['Latitude']
lng4 = df4['Longitude']
label4 = df4['Stadium']
country4 = df4['Nationality']
division4 = df4['Div']
club4 = df4['Team']

# %%
for i in range(len(lat4)):
    folium.CircleMarker([lat4[i], lng4[i]], radius=1, color='black', popup=('<b>''Club: ''</b>' + club4[i] + '<br>'+
                                                                          '<b>''Stadium: ''</b>' + label4[i] + '<br>'+
                                                                          '<b>''Country: ''</b>' + country4[i] + '<br>'+ 
                                                                          '<b>''Division: ''</b>' + division4[i])
                  ,icon=folium.Icon()).add_to(afr_map)

# %%
afr_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
afr_map.save('africa.html')

# %%
oceania_df = geoloc_club['Continent'] == 'Oceania'
df5 = geoloc_club[oceania_df].reset_index()

# %%
oce_map=folium.Map(location=[-32.918889, 151.726667], tiles='cartodbpositron', zoom_start=2)

# %%
lat5 = df5['Latitude']
lng5 = df5['Longitude']
label5 = df5['Stadium']
country5 = df5['Nationality']
division5 = df5['Div']
club5 = df5['Team']

# %%
for i in range(len(lat5)):
    folium.CircleMarker([lat5[i], lng5[i]], radius=1, color='purple', popup=('<b>''Club: ''</b>' + club5[i] + '<br>'+
                                                                          '<b>''Stadium: ''</b>' + label5[i] + '<br>'+
                                                                          '<b>''Country: ''</b>' + country5[i] + '<br>'+ 
                                                                          '<b>''Division: ''</b>' + division5[i])
                  ,icon=folium.Icon()).add_to(oce_map)

# %%
oce_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
oce_map.save('oceania.html')
