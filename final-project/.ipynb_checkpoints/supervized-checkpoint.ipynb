# %%
# !pip3 install xgboost
# Out:
# Requirement already satisfied: xgboost in /usr/local/lib/python3.7/site-packages (0.90)
# Requirement already satisfied: numpy in /Users/macos/Library/Python/3.7/lib/python/site-packages (from xgboost) (1.17.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/site-packages (from xgboost) (1.3.1)

# %% [markdown]
# # IMPORTANDO LIBRERÍAS

# %%
import warnings
warnings.filterwarnings('ignore')

import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns
import plotly.plotly as py

from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error, mean_squared_error
import xgboost as xgb

from itertools import product
import itertools
from collections import OrderedDict
import operator
import re
from math import sqrt
import pickle

# %% [markdown]
# # DATAFRAME

# %%
fifasup=pd.read_csv('prediction.csv')
fifasup.head()
# Out:
#        ID               Name Position  Age  Height(cm)  Weight(kgs)  \
# 0  158023           L. Messi       RF   31  173.727522    72.137028
# 1   20801  Cristiano Ronaldo       ST   33  188.966778    83.025636
# 2  190871          Neymar Jr       LW   26  179.823225    68.053800
# 3  193080             De Gea       GK   27  195.062481    76.220256
# 4  192985       K. De Bruyne      RCM   27  155.745200    69.868568
#
#   Preferred Foot  Weak Foot Nationality Continent  ...  LWB LDM CDM  RDM  RWB  \
# 0           Left        4.0   Argentina   America  ...   64  61  61   61   64
# 1          Right        4.0    Portugal    Europe  ...   65  61  61   61   65
# 2          Right        5.0      Brazil   America  ...   65  60  60   60   65
# 3          Right        3.0       Spain    Europe  ...   50  50  50   50   50
# 4          Right        5.0     Belgium    Europe  ...   77  77  77   77   77
#
#    LB  LCB  CB  RCB  RB
# 0  59   47  47   47  59
# 1  61   53  53   53  61
# 2  60   47  47   47  60
# 3  50   50  50   50  50
# 4  73   66  66   66  73
#
# [5 rows x 90 columns]

# %% [markdown]
# # AGRUPACIÓN DE DATOS

# %%
#Player value per position
positions = {
    'Forward' : ['CF', 'LF', 'LS', 'LW', 'RF', 'RS', 'RW', 'ST'],
    'Midfield' : ['CAM', 'CDM', 'CM', 'LAM', 'LCM', 'LDM', 'LM', 'RAM', 'RCB', 'RCM', 'RDM', 'RM'],
    'Defense' : ['CB', 'LB', 'LCB', 'LWB', 'RB', 'RCB', 'RWB'],
    'Goalkeeper' : ['GK'],
}
count_position = {'Forward': 0, 'Midfield': 0, 'Defense': 0, 'Goalkeeper': 0}
players_position = {'Forward': 0, 'Midfield': 0, 'Defense': 0, 'Goalkeeper': 0}
position_avg = {'Forward': 0, 'Midfield': 0, 'Defense': 0, 'Goalkeeper': 0}

def add_values(series):
    already_counted = [0, 0, 0, 0] #Array to avoid having repeated values in the average
    preferred_position_list = re.sub("[^\w]", " ",  series[0]).split() #Split the preferred positions
    value = series[1]

    #Count the players per position category
    index = 0
    for preferred_position in preferred_position_list:
        for position in positions:
            if preferred_position in positions[position]:
                if(not already_counted[index]):
                    count_position[position] += value
                    players_position[position] += 1                    
                    already_counted[index] = 1
                    
position_value = fifasup[['Position', 'Value(€M)']]
position_value.apply(add_values, 1)

#Average the players value per position category
for position in count_position:
    position_avg[position] = count_position[position] / players_position[position]

fig = plt.figure(figsize=(6,4))
ax = fig.add_subplot(111)
ax.bar(range(len(position_avg)), list(position_avg.values()))
plt.xticks(range(len(position_avg)), list(position_avg.keys()))
plt.xlabel('Position')
plt.ylabel('Average value of players')
plt.show()

# %% [markdown]
# Como podemos observar, las posiciones con mayor cantidad de jugadores son **Delanteros** y **Mediocampistas**.

# %% [markdown]
# # MODELOS PREDICTIVOS

# %% [markdown]
# Estableceremos un modelo de machine learning para intentar predecir el **valor de mercado** de una jugadora y el **salario** que debería de recibir con base en sus características individuales.
#
# Es importante mencionar que la **nacionalidad** y el **club** son variables que por sí solas genera una brecha salarial y mercado.

# %%
fifasup_mach = fifasup.copy()
fifasup_mach = fifasup_mach.drop(['Name', 'Nationality', 'Club','Work Rate','Work RAttack',
                                 'Work RDefense','Contract_Expiry','Preferred Foot', 'Joined',
                                 'Evolution', 'Continent', 'year_joined', 'month_joined',
                                 'day_joined', 'Jersey'], 1)
fifasup_mach = fifasup_mach.drop(fifasup_mach.columns[0], 1)

# %%
fifasup_mach.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18207 entries, 0 to 18206
# Data columns (total 74 columns):
# Position              18207 non-null object
# Age                   18207 non-null int64
# Height(cm)            18207 non-null float64
# Weight(kgs)           18207 non-null float64
# Weak Foot             18207 non-null float64
# Inter_Rep             18207 non-null float64
# Overall               18207 non-null int64
# Potential             18207 non-null int64
# Difference            18207 non-null int64
# Value(€M)             18207 non-null float64
# Wage(€K)              18207 non-null float64
# Release_Clause(€M)    18207 non-null float64
# Special               18207 non-null int64
# SkillMoves            18207 non-null float64
# ShortPass             18207 non-null float64
# LongPass              18207 non-null float64
# ShotPower             18207 non-null float64
# LongShots             18207 non-null float64
# Penalties             18207 non-null float64
# Agility               18207 non-null float64
# Acceleration          18207 non-null float64
# SprintSpeed           18207 non-null float64
# Stamina               18207 non-null float64
# Strength              18207 non-null float64
# Reactions             18207 non-null float64
# Dribbling             18207 non-null float64
# BallControl           18207 non-null float64
# Aggression            18207 non-null float64
# Interceptions         18207 non-null float64
# Positioning           18207 non-null float64
# Vision                18207 non-null float64
# Balance               18207 non-null float64
# Composure             18207 non-null float64
# Crossing              18207 non-null float64
# Finishing             18207 non-null float64
# Jumping               18207 non-null float64
# HeadAccuracy          18207 non-null float64
# Marking               18207 non-null float64
# StandingTackle        18207 non-null float64
# SlidingTackle         18207 non-null float64
# GKDiving              18207 non-null float64
# Volleys               18207 non-null float64
# Curve                 18207 non-null float64
# FKAccuracy            18207 non-null float64
# GKHandling            18207 non-null float64
# GKKicking             18207 non-null float64
# GKPositioning         18207 non-null float64
# GKReflexes            18207 non-null float64
# LS                    18207 non-null int64
# ST                    18207 non-null int64
# RS                    18207 non-null int64
# LW                    18207 non-null int64
# LF                    18207 non-null int64
# CF                    18207 non-null int64
# RF                    18207 non-null int64
# RW                    18207 non-null int64
# LAM                   18207 non-null int64
# CAM                   18207 non-null int64
# RAM                   18207 non-null int64
# LM                    18207 non-null int64
# LCM                   18207 non-null int64
# CM                    18207 non-null int64
# RCM                   18207 non-null int64
# RM                    18207 non-null int64
# LWB                   18207 non-null int64
# LDM                   18207 non-null int64
# CDM                   18207 non-null int64
# RDM                   18207 non-null int64
# RWB                   18207 non-null int64
# LB                    18207 non-null int64
# LCB                   18207 non-null int64
# CB                    18207 non-null int64
# RCB                   18207 non-null int64
# RB                    18207 non-null int64
# dtypes: float64(42), int64(31), object(1)
# memory usage: 10.3+ MB

# %%
y_value = fifasup_mach['Value(€M)'].copy()
y_wage = fifasup_mach['Wage(€K)'].copy()
fifasup_mach = fifasup_mach.drop(['Value(€M)', 'Wage(€K)'], 1)

# %%
def count_positions(position):
    return len(re.sub("[^\w]", " ",  position).split())

fifasup_mach['Versatility'] = fifasup_mach['Position'].apply(count_positions)
fifasup_mach.head()
# Out:
#   Position  Age  Height(cm)  Weight(kgs)  Weak Foot  Inter_Rep  Overall  \
# 0       RF   31  173.727522    72.137028        4.0        5.0       94
# 1       ST   33  188.966778    83.025636        4.0        5.0       94
# 2       LW   26  179.823225    68.053800        5.0        5.0       92
# 3       GK   27  195.062481    76.220256        3.0        4.0       91
# 4      RCM   27  155.745200    69.868568        5.0        4.0       91
#
#    Potential  Difference  Release_Clause(€M)  ...  LDM  CDM  RDM  RWB  LB  \
# 0         94           0         226500000.0  ...   61   61   61   64  59
# 1         94           0         127100000.0  ...   61   61   61   65  61
# 2         93           1         228100000.0  ...   60   60   60   65  60
# 3         93           2         138600000.0  ...   50   50   50   50  50
# 4         92           1         196400000.0  ...   77   77   77   77  73
#
#    LCB  CB  RCB  RB  Versatility
# 0   47  47   47  59            1
# 1   53  53   53  61            1
# 2   47  47   47  60            1
# 3   50  50   50  50            1
# 4   66  66   66  73            1
#
# [5 rows x 73 columns]

# %%
fifasup_mach = fifasup_mach.drop(['Position'], 1)
#fifasup_mach.columns = fifasup_mach.columns.str.replace('\s+', '_')

# %% [markdown]
# # MODELO 1: Predicción del valor de mercado

# %%
X_train_value, X_test_value, y_train_value, y_test_value = train_test_split(fifasup_mach, y_value, test_size=0.2)

# %%
num_boost_round = 999
early_stopping_rounds = 10

xgb_params = {
                'n_estimators':[500],
                # otros parámetros
                'objective':['reg:linear'],
                'eval_metric':[ ["rmse" ,"mae"]],
                'min_child_weight': [1],
                'eta': [0.01, 0.1], #Learning rate
                'gamma': [0.05, 0.1], #Minimum acceptable entropy improvement to perform a split
                #Bias\variance tradeoff knobs
                'subsample': [0.8, 1.0],
                'colsample_bytree': [0.8, 1.0],
                'max_depth': [6, 9]
              }

params_perms = [dict(zip(xgb_params, v)) for v in product(*xgb_params.values())]
print(len(params_perms))
print(params_perms[0])
# Out:
# 32
# {'n_estimators': 500, 'objective': 'reg:linear', 'eval_metric': ['rmse', 'mae'], 'min_child_weight': 1, 'eta': 0.01, 'gamma': 0.05, 'subsample': 0.8, 'colsample_bytree': 0.8, 'max_depth': 6}

# %%
dtrain_value = xgb.DMatrix(X_train_value, label=y_train_value)
dtest_value = xgb.DMatrix(X_test_value, label=y_test_value)
evaluation_set_value = [(dtest_value, "Test_set")]

# %%
mean_train_value = np.mean(y_train_value)

# Get predictions on the test set
baseline_predictions_value = np.ones(y_test_value.shape) * mean_train_value

# Compute MAE
mae_baseline_value = mean_absolute_error(y_test_value, baseline_predictions_value)

# Compute RMSE
rmse_baseline_value = sqrt(mean_squared_error(y_test_value, baseline_predictions_value))

print("Baseline MAE is {:.2f}".format(mae_baseline_value))
print("Baseline RMSE is {:.2f}".format(rmse_baseline_value))
# Out:
# Baseline MAE is 2857131.31
# Baseline RMSE is 6227914.18

# %%
best_score_value = mae_baseline_value
best_params_value = {}
for i, grid_search_value in enumerate(params_perms):
    print("Permutation number:", i+1)
    cv_results_value = xgb.cv(grid_search_value,
                        dtrain_value,
                        num_boost_round=num_boost_round,
                        seed=42,
                        nfold=2,
                        metrics=['mae', 'rmse'],
                        early_stopping_rounds=early_stopping_rounds
                        )
    
    mean_mae_value = cv_results_value['test-mae-mean'].min()
    boost_rounds_value = cv_results_value['test-mae-mean'].argmin()
    print("\tMAE {} for {} rounds".format(mean_mae_value, boost_rounds_value))
    if mean_mae_value < best_score_value:
        best_score_value = mean_mae_value
        best_params_value = grid_search_value
# Out:
# Permutation number: 1
# [12:22:55] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [12:22:55] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 178175.7421875 for 998 rounds
# Permutation number: 2
# [12:24:22] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [12:24:22] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 167600.2578125 for 998 rounds
# Permutation number: 3
# [12:26:15] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [12:26:15] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 182845.1171875 for 998 rounds
# Permutation number: 4
# [12:27:49] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [12:27:49] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 167993.5859375 for 998 rounds
# Permutation number: 5
# [12:29:59] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [12:29:59] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 182633.34375 for 998 rounds
# Permutation number: 6
# [12:31:19] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [12:31:19] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 170726.3984375 for 998 rounds
# Permutation number: 7
# [12:33:08] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [12:33:08] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 186653.359375 for 961 rounds
# Permutation number: 8
# [12:34:37] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [12:34:37] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 174323.5390625 for 998 rounds
# Permutation number: 9
# [12:36:44] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [12:36:44] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 178175.7421875 for 998 rounds
# Permutation number: 10
# [12:38:06] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [12:38:06] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 167600.2578125 for 998 rounds
# Permutation number: 11
# [12:39:59] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [12:39:59] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 182845.1171875 for 998 rounds
# Permutation number: 12
# [12:41:34] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [12:41:35] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 167993.5859375 for 998 rounds
# Permutation number: 13
# [12:43:44] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [12:43:44] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 182633.34375 for 998 rounds
# Permutation number: 14
# [12:45:03] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [12:45:03] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 170726.3984375 for 998 rounds
# Permutation number: 15
# [12:46:52] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [12:46:52] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 186653.359375 for 961 rounds
# Permutation number: 16
# [12:48:20] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [12:48:20] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 174323.5390625 for 998 rounds
# Permutation number: 17
# [12:50:27] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [12:50:27] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 189853.4921875 for 121 rounds
# Permutation number: 18
# [12:50:38] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [12:50:38] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 180572.59375 for 115 rounds
# Permutation number: 19
# [12:50:52] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [12:50:52] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 189775.9375 for 104 rounds
# Permutation number: 20
# [12:51:03] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [12:51:03] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 177226.0078125 for 103 rounds
# Permutation number: 21
# [12:51:18] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [12:51:18] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 186630.359375 for 105 rounds
# Permutation number: 22
# [12:51:27] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [12:51:27] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 177415.84375 for 218 rounds
# Permutation number: 23
# [12:51:53] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [12:51:53] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 182470.9921875 for 205 rounds
# Permutation number: 24
# [12:52:13] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [12:52:13] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 174956.703125 for 182 rounds
# Permutation number: 25
# [12:52:38] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [12:52:38] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 189853.4921875 for 121 rounds
# Permutation number: 26
# [12:52:48] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [12:52:49] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 180572.59375 for 115 rounds
# Permutation number: 27
# [12:53:03] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [12:53:03] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 189775.9375 for 104 rounds
# Permutation number: 28
# [12:53:14] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [12:53:14] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 177226.0078125 for 103 rounds
# Permutation number: 29
# [12:53:29] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [12:53:29] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 186630.359375 for 105 rounds
# Permutation number: 30
# [12:53:38] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [12:53:38] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 177415.84375 for 218 rounds
# Permutation number: 31
# [12:54:04] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [12:54:04] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 182470.9921875 for 205 rounds
# Permutation number: 32
# [12:54:24] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [12:54:24] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 174956.703125 for 182 rounds

# %%
print("Best Score:", best_score_value)
print("Best Parameters:", best_params_value)
# Out:
# Best Score: 167600.2578125
# Best Parameters: {'n_estimators': 500, 'objective': 'reg:linear', 'eval_metric': ['rmse', 'mae'], 'min_child_weight': 1, 'eta': 0.01, 'gamma': 0.05, 'subsample': 0.8, 'colsample_bytree': 0.8, 'max_depth': 9}

# %%
#Retrain a model with new best params
model_value = xgb.train(
    best_params_value,
    dtrain_value,
    num_boost_round=num_boost_round,
    evals=evaluation_set_value,
    early_stopping_rounds=early_stopping_rounds
)
# Out:
# [12:54:49] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	Test_set-rmse:6.67572e+06	Test_set-mae:2.54366e+06
# Multiple eval metrics have been passed: 'Test_set-mae' will be used for early stopping.
#
# Will train until Test_set-mae hasn't improved in 10 rounds.
# [1]	Test_set-rmse:6.6191e+06	Test_set-mae:2.51953e+06
# [2]	Test_set-rmse:6.56389e+06	Test_set-mae:2.49604e+06
# [3]	Test_set-rmse:6.50864e+06	Test_set-mae:2.47244e+06
# [4]	Test_set-rmse:6.45258e+06	Test_set-mae:2.44885e+06
# [5]	Test_set-rmse:6.39672e+06	Test_set-mae:2.42542e+06
# [6]	Test_set-rmse:6.34288e+06	Test_set-mae:2.40244e+06
# [7]	Test_set-rmse:6.28937e+06	Test_set-mae:2.38004e+06
# [8]	Test_set-rmse:6.23652e+06	Test_set-mae:2.35759e+06
# [9]	Test_set-rmse:6.18535e+06	Test_set-mae:2.33579e+06
# [10]	Test_set-rmse:6.13227e+06	Test_set-mae:2.3136e+06
# [11]	Test_set-rmse:6.08092e+06	Test_set-mae:2.29181e+06
# [12]	Test_set-rmse:6.02932e+06	Test_set-mae:2.27018e+06
# [13]	Test_set-rmse:5.9789e+06	Test_set-mae:2.24886e+06
# [14]	Test_set-rmse:5.92875e+06	Test_set-mae:2.22762e+06
# [15]	Test_set-rmse:5.87687e+06	Test_set-mae:2.20637e+06
# [16]	Test_set-rmse:5.82704e+06	Test_set-mae:2.18561e+06
# [17]	Test_set-rmse:5.77566e+06	Test_set-mae:2.16473e+06
# [18]	Test_set-rmse:5.72533e+06	Test_set-mae:2.14423e+06
# [19]	Test_set-rmse:5.67787e+06	Test_set-mae:2.12401e+06
# [20]	Test_set-rmse:5.62872e+06	Test_set-mae:2.1037e+06
# [21]	Test_set-rmse:5.58163e+06	Test_set-mae:2.08383e+06
# [22]	Test_set-rmse:5.53456e+06	Test_set-mae:2.0643e+06
# [23]	Test_set-rmse:5.48723e+06	Test_set-mae:2.04468e+06
# [24]	Test_set-rmse:5.44165e+06	Test_set-mae:2.02581e+06
# [25]	Test_set-rmse:5.39655e+06	Test_set-mae:2.00696e+06
# [26]	Test_set-rmse:5.35258e+06	Test_set-mae:1.98826e+06
# [27]	Test_set-rmse:5.30918e+06	Test_set-mae:1.9697e+06
# [28]	Test_set-rmse:5.26507e+06	Test_set-mae:1.95119e+06
# [29]	Test_set-rmse:5.2224e+06	Test_set-mae:1.9331e+06
# [30]	Test_set-rmse:5.18026e+06	Test_set-mae:1.91502e+06
# [31]	Test_set-rmse:5.13514e+06	Test_set-mae:1.89687e+06
# [32]	Test_set-rmse:5.09114e+06	Test_set-mae:1.8789e+06
# [33]	Test_set-rmse:5.04834e+06	Test_set-mae:1.86132e+06
# [34]	Test_set-rmse:5.00626e+06	Test_set-mae:1.84387e+06
# [35]	Test_set-rmse:4.96296e+06	Test_set-mae:1.82639e+06
# [36]	Test_set-rmse:4.9223e+06	Test_set-mae:1.80958e+06
# [37]	Test_set-rmse:4.88274e+06	Test_set-mae:1.79303e+06
# [38]	Test_set-rmse:4.84146e+06	Test_set-mae:1.77627e+06
# [39]	Test_set-rmse:4.80248e+06	Test_set-mae:1.7597e+06
# [40]	Test_set-rmse:4.76334e+06	Test_set-mae:1.74348e+06
# [41]	Test_set-rmse:4.72453e+06	Test_set-mae:1.72707e+06
# [42]	Test_set-rmse:4.68497e+06	Test_set-mae:1.71085e+06
# [43]	Test_set-rmse:4.6462e+06	Test_set-mae:1.6949e+06
# [44]	Test_set-rmse:4.60879e+06	Test_set-mae:1.67913e+06
# [45]	Test_set-rmse:4.57302e+06	Test_set-mae:1.66356e+06
# [46]	Test_set-rmse:4.53611e+06	Test_set-mae:1.64818e+06
# [47]	Test_set-rmse:4.49959e+06	Test_set-mae:1.633e+06
# [48]	Test_set-rmse:4.46476e+06	Test_set-mae:1.61809e+06
# [49]	Test_set-rmse:4.42813e+06	Test_set-mae:1.60315e+06
# [50]	Test_set-rmse:4.39202e+06	Test_set-mae:1.58819e+06
# [51]	Test_set-rmse:4.3559e+06	Test_set-mae:1.5735e+06
# [52]	Test_set-rmse:4.32127e+06	Test_set-mae:1.55899e+06
# [53]	Test_set-rmse:4.2884e+06	Test_set-mae:1.54502e+06
# [54]	Test_set-rmse:4.25303e+06	Test_set-mae:1.53068e+06
# [55]	Test_set-rmse:4.2216e+06	Test_set-mae:1.51705e+06
# [56]	Test_set-rmse:4.18796e+06	Test_set-mae:1.50298e+06
# [57]	Test_set-rmse:4.15475e+06	Test_set-mae:1.48915e+06
# [58]	Test_set-rmse:4.12023e+06	Test_set-mae:1.47526e+06
# [59]	Test_set-rmse:4.08642e+06	Test_set-mae:1.46159e+06
# [60]	Test_set-rmse:4.05428e+06	Test_set-mae:1.44835e+06
# [61]	Test_set-rmse:4.0232e+06	Test_set-mae:1.43512e+06
# [62]	Test_set-rmse:3.99357e+06	Test_set-mae:1.42235e+06
# [63]	Test_set-rmse:3.96168e+06	Test_set-mae:1.40923e+06
# [64]	Test_set-rmse:3.93137e+06	Test_set-mae:1.3964e+06
# [65]	Test_set-rmse:3.90023e+06	Test_set-mae:1.38361e+06
# [66]	Test_set-rmse:3.86987e+06	Test_set-mae:1.37093e+06
# [67]	Test_set-rmse:3.83974e+06	Test_set-mae:1.35829e+06
# [68]	Test_set-rmse:3.80936e+06	Test_set-mae:1.34592e+06
# [69]	Test_set-rmse:3.78085e+06	Test_set-mae:1.33364e+06
# [70]	Test_set-rmse:3.75193e+06	Test_set-mae:1.32146e+06
# [71]	Test_set-rmse:3.72267e+06	Test_set-mae:1.30946e+06
# [72]	Test_set-rmse:3.69403e+06	Test_set-mae:1.29778e+06
# [73]	Test_set-rmse:3.66573e+06	Test_set-mae:1.286e+06
# [74]	Test_set-rmse:3.63603e+06	Test_set-mae:1.27411e+06
# [75]	Test_set-rmse:3.60853e+06	Test_set-mae:1.26256e+06
# [76]	Test_set-rmse:3.5802e+06	Test_set-mae:1.25101e+06
# [77]	Test_set-rmse:3.55288e+06	Test_set-mae:1.2397e+06
# [78]	Test_set-rmse:3.52562e+06	Test_set-mae:1.22848e+06
# [79]	Test_set-rmse:3.49968e+06	Test_set-mae:1.21748e+06
# [80]	Test_set-rmse:3.47259e+06	Test_set-mae:1.20638e+06
# [81]	Test_set-rmse:3.44605e+06	Test_set-mae:1.19543e+06
# [82]	Test_set-rmse:3.41946e+06	Test_set-mae:1.18459e+06
# [83]	Test_set-rmse:3.3937e+06	Test_set-mae:1.17389e+06
# [84]	Test_set-rmse:3.36852e+06	Test_set-mae:1.16336e+06
# [85]	Test_set-rmse:3.34368e+06	Test_set-mae:1.15289e+06
# [86]	Test_set-rmse:3.31866e+06	Test_set-mae:1.14246e+06
# [87]	Test_set-rmse:3.2943e+06	Test_set-mae:1.13221e+06
# [88]	Test_set-rmse:3.26901e+06	Test_set-mae:1.1219e+06
# [89]	Test_set-rmse:3.24399e+06	Test_set-mae:1.11168e+06
# [90]	Test_set-rmse:3.22162e+06	Test_set-mae:1.10213e+06
# [91]	Test_set-rmse:3.19783e+06	Test_set-mae:1.09236e+06
# [92]	Test_set-rmse:3.1754e+06	Test_set-mae:1.08276e+06
# [93]	Test_set-rmse:3.15216e+06	Test_set-mae:1.07301e+06
# [94]	Test_set-rmse:3.13073e+06	Test_set-mae:1.0635e+06
# [95]	Test_set-rmse:3.10814e+06	Test_set-mae:1.05401e+06
# [96]	Test_set-rmse:3.08549e+06	Test_set-mae:1.04452e+06
# [97]	Test_set-rmse:3.06436e+06	Test_set-mae:1.03517e+06
# [98]	Test_set-rmse:3.04217e+06	Test_set-mae:1.02587e+06
# [99]	Test_set-rmse:3.01934e+06	Test_set-mae:1.0165e+06
# [100]	Test_set-rmse:2.99806e+06	Test_set-mae:1.00749e+06
# [101]	Test_set-rmse:2.97751e+06	Test_set-mae:998652
# [102]	Test_set-rmse:2.95686e+06	Test_set-mae:989921
# [103]	Test_set-rmse:2.93539e+06	Test_set-mae:981108
# [104]	Test_set-rmse:2.915e+06	Test_set-mae:972421
# [105]	Test_set-rmse:2.89435e+06	Test_set-mae:963820
# [106]	Test_set-rmse:2.87474e+06	Test_set-mae:955266
# [107]	Test_set-rmse:2.85579e+06	Test_set-mae:946935
# [108]	Test_set-rmse:2.83575e+06	Test_set-mae:938507
# [109]	Test_set-rmse:2.81715e+06	Test_set-mae:930327
# [110]	Test_set-rmse:2.79736e+06	Test_set-mae:922078
# [111]	Test_set-rmse:2.7783e+06	Test_set-mae:914068
# [112]	Test_set-rmse:2.75972e+06	Test_set-mae:906102
# [113]	Test_set-rmse:2.74125e+06	Test_set-mae:898261
# [114]	Test_set-rmse:2.72306e+06	Test_set-mae:890422
# [115]	Test_set-rmse:2.70559e+06	Test_set-mae:882686
# [116]	Test_set-rmse:2.68807e+06	Test_set-mae:875049
# [117]	Test_set-rmse:2.67054e+06	Test_set-mae:867417
# [118]	Test_set-rmse:2.65319e+06	Test_set-mae:859902
# [119]	Test_set-rmse:2.63514e+06	Test_set-mae:852285
# [120]	Test_set-rmse:2.61824e+06	Test_set-mae:844863
# [121]	Test_set-rmse:2.60108e+06	Test_set-mae:837440
# [122]	Test_set-rmse:2.58388e+06	Test_set-mae:830017
# [123]	Test_set-rmse:2.56747e+06	Test_set-mae:822912
# [124]	Test_set-rmse:2.55234e+06	Test_set-mae:815927
# [125]	Test_set-rmse:2.53601e+06	Test_set-mae:808834
# [126]	Test_set-rmse:2.51933e+06	Test_set-mae:801837
# [127]	Test_set-rmse:2.5037e+06	Test_set-mae:795043
# [128]	Test_set-rmse:2.48926e+06	Test_set-mae:788234
# [129]	Test_set-rmse:2.47531e+06	Test_set-mae:781566
# [130]	Test_set-rmse:2.46015e+06	Test_set-mae:774874
# [131]	Test_set-rmse:2.44478e+06	Test_set-mae:768161
# [132]	Test_set-rmse:2.42988e+06	Test_set-mae:761624
# [133]	Test_set-rmse:2.41578e+06	Test_set-mae:755221
# [134]	Test_set-rmse:2.40022e+06	Test_set-mae:748665
# [135]	Test_set-rmse:2.38598e+06	Test_set-mae:742358
# [136]	Test_set-rmse:2.37105e+06	Test_set-mae:735993
# [137]	Test_set-rmse:2.35587e+06	Test_set-mae:729633
# [138]	Test_set-rmse:2.34235e+06	Test_set-mae:723654
# [139]	Test_set-rmse:2.32839e+06	Test_set-mae:717630
# [140]	Test_set-rmse:2.31437e+06	Test_set-mae:711539
# [141]	Test_set-rmse:2.3002e+06	Test_set-mae:705497
# [142]	Test_set-rmse:2.28702e+06	Test_set-mae:699694
# [143]	Test_set-rmse:2.27384e+06	Test_set-mae:693863
# [144]	Test_set-rmse:2.26123e+06	Test_set-mae:688173
# [145]	Test_set-rmse:2.24866e+06	Test_set-mae:682497
# [146]	Test_set-rmse:2.23513e+06	Test_set-mae:676671
# [147]	Test_set-rmse:2.22278e+06	Test_set-mae:671114
# [148]	Test_set-rmse:2.21105e+06	Test_set-mae:665537
# [149]	Test_set-rmse:2.19928e+06	Test_set-mae:660086
# [150]	Test_set-rmse:2.18659e+06	Test_set-mae:654539
# [151]	Test_set-rmse:2.17354e+06	Test_set-mae:649064
# [152]	Test_set-rmse:2.16067e+06	Test_set-mae:643592
# [153]	Test_set-rmse:2.14819e+06	Test_set-mae:638269
# [154]	Test_set-rmse:2.13612e+06	Test_set-mae:633084
# [155]	Test_set-rmse:2.12451e+06	Test_set-mae:627813
# [156]	Test_set-rmse:2.11328e+06	Test_set-mae:622748
# [157]	Test_set-rmse:2.10179e+06	Test_set-mae:617679
# [158]	Test_set-rmse:2.08964e+06	Test_set-mae:612568
# [159]	Test_set-rmse:2.07907e+06	Test_set-mae:607667
# [160]	Test_set-rmse:2.068e+06	Test_set-mae:602703
# [161]	Test_set-rmse:2.0569e+06	Test_set-mae:597778
# [162]	Test_set-rmse:2.04553e+06	Test_set-mae:592869
# [163]	Test_set-rmse:2.03518e+06	Test_set-mae:588122
# [164]	Test_set-rmse:2.02506e+06	Test_set-mae:583389
# [165]	Test_set-rmse:2.01461e+06	Test_set-mae:578715
# [166]	Test_set-rmse:2.00364e+06	Test_set-mae:573992
# [167]	Test_set-rmse:1.99388e+06	Test_set-mae:569496
# [168]	Test_set-rmse:1.98355e+06	Test_set-mae:564826
# [169]	Test_set-rmse:1.97354e+06	Test_set-mae:560243
# [170]	Test_set-rmse:1.96395e+06	Test_set-mae:555813
# [171]	Test_set-rmse:1.95512e+06	Test_set-mae:551566
# [172]	Test_set-rmse:1.94539e+06	Test_set-mae:547118
# [173]	Test_set-rmse:1.93579e+06	Test_set-mae:542807
# [174]	Test_set-rmse:1.9256e+06	Test_set-mae:538436
# [175]	Test_set-rmse:1.91601e+06	Test_set-mae:534159
# [176]	Test_set-rmse:1.90665e+06	Test_set-mae:529912
# [177]	Test_set-rmse:1.89756e+06	Test_set-mae:525795
# [178]	Test_set-rmse:1.88933e+06	Test_set-mae:521708
# [179]	Test_set-rmse:1.88064e+06	Test_set-mae:517603
# [180]	Test_set-rmse:1.87101e+06	Test_set-mae:513551
# [181]	Test_set-rmse:1.86238e+06	Test_set-mae:509489
# [182]	Test_set-rmse:1.85377e+06	Test_set-mae:505598
# [183]	Test_set-rmse:1.84415e+06	Test_set-mae:501584
# [184]	Test_set-rmse:1.83564e+06	Test_set-mae:497637
# [185]	Test_set-rmse:1.82826e+06	Test_set-mae:493931
# [186]	Test_set-rmse:1.81993e+06	Test_set-mae:490220
# [187]	Test_set-rmse:1.81123e+06	Test_set-mae:486527
# [188]	Test_set-rmse:1.80317e+06	Test_set-mae:482812
# [189]	Test_set-rmse:1.79428e+06	Test_set-mae:479095
# [190]	Test_set-rmse:1.78718e+06	Test_set-mae:475554
# [191]	Test_set-rmse:1.7798e+06	Test_set-mae:471912
# [192]	Test_set-rmse:1.77187e+06	Test_set-mae:468293
# [193]	Test_set-rmse:1.7646e+06	Test_set-mae:464689
# [194]	Test_set-rmse:1.75786e+06	Test_set-mae:461292
# [195]	Test_set-rmse:1.74997e+06	Test_set-mae:457761
# [196]	Test_set-rmse:1.74192e+06	Test_set-mae:454325
# [197]	Test_set-rmse:1.73414e+06	Test_set-mae:450938
# [198]	Test_set-rmse:1.72714e+06	Test_set-mae:447685
# [199]	Test_set-rmse:1.7211e+06	Test_set-mae:444396
# [200]	Test_set-rmse:1.71384e+06	Test_set-mae:441118
# [201]	Test_set-rmse:1.70729e+06	Test_set-mae:437855
# [202]	Test_set-rmse:1.70039e+06	Test_set-mae:434686
# [203]	Test_set-rmse:1.69445e+06	Test_set-mae:431662
# [204]	Test_set-rmse:1.68725e+06	Test_set-mae:428520
# [205]	Test_set-rmse:1.67994e+06	Test_set-mae:425434
# [206]	Test_set-rmse:1.6742e+06	Test_set-mae:422522
# [207]	Test_set-rmse:1.66761e+06	Test_set-mae:419533
# [208]	Test_set-rmse:1.66066e+06	Test_set-mae:416489
# [209]	Test_set-rmse:1.65361e+06	Test_set-mae:413554
# [210]	Test_set-rmse:1.64722e+06	Test_set-mae:410680
# [211]	Test_set-rmse:1.64072e+06	Test_set-mae:407766
# [212]	Test_set-rmse:1.63504e+06	Test_set-mae:404986
# [213]	Test_set-rmse:1.62896e+06	Test_set-mae:402196
# [214]	Test_set-rmse:1.62459e+06	Test_set-mae:399509
# [215]	Test_set-rmse:1.61935e+06	Test_set-mae:396750
# [216]	Test_set-rmse:1.61181e+06	Test_set-mae:393885
# [217]	Test_set-rmse:1.60561e+06	Test_set-mae:391158
# [218]	Test_set-rmse:1.59956e+06	Test_set-mae:388494
# [219]	Test_set-rmse:1.59298e+06	Test_set-mae:385854
# [220]	Test_set-rmse:1.58683e+06	Test_set-mae:383277
# [221]	Test_set-rmse:1.58145e+06	Test_set-mae:380705
# [222]	Test_set-rmse:1.57513e+06	Test_set-mae:378203
# [223]	Test_set-rmse:1.56902e+06	Test_set-mae:375752
# [224]	Test_set-rmse:1.563e+06	Test_set-mae:373315
# [225]	Test_set-rmse:1.55809e+06	Test_set-mae:370876
# [226]	Test_set-rmse:1.55206e+06	Test_set-mae:368506
# [227]	Test_set-rmse:1.54682e+06	Test_set-mae:366061
# [228]	Test_set-rmse:1.54122e+06	Test_set-mae:363744
# [229]	Test_set-rmse:1.53559e+06	Test_set-mae:361383
# [230]	Test_set-rmse:1.52927e+06	Test_set-mae:359122
# [231]	Test_set-rmse:1.52452e+06	Test_set-mae:356842
# [232]	Test_set-rmse:1.51916e+06	Test_set-mae:354623
# [233]	Test_set-rmse:1.51538e+06	Test_set-mae:352509
# [234]	Test_set-rmse:1.51027e+06	Test_set-mae:350404
# [235]	Test_set-rmse:1.50573e+06	Test_set-mae:348373
# [236]	Test_set-rmse:1.50015e+06	Test_set-mae:346180
# [237]	Test_set-rmse:1.49579e+06	Test_set-mae:344048
# [238]	Test_set-rmse:1.49139e+06	Test_set-mae:342088
# [239]	Test_set-rmse:1.48632e+06	Test_set-mae:340067
# [240]	Test_set-rmse:1.48087e+06	Test_set-mae:338185
# [241]	Test_set-rmse:1.47733e+06	Test_set-mae:336309
# [242]	Test_set-rmse:1.47403e+06	Test_set-mae:334473
# [243]	Test_set-rmse:1.469e+06	Test_set-mae:332534
# [244]	Test_set-rmse:1.4636e+06	Test_set-mae:330670
# [245]	Test_set-rmse:1.45936e+06	Test_set-mae:328842
# [246]	Test_set-rmse:1.45578e+06	Test_set-mae:327041
# [247]	Test_set-rmse:1.45163e+06	Test_set-mae:325301
# [248]	Test_set-rmse:1.44699e+06	Test_set-mae:323540
# [249]	Test_set-rmse:1.44246e+06	Test_set-mae:321745
# [250]	Test_set-rmse:1.43911e+06	Test_set-mae:319992
# [251]	Test_set-rmse:1.43442e+06	Test_set-mae:318284
# [252]	Test_set-rmse:1.43148e+06	Test_set-mae:316600
# [253]	Test_set-rmse:1.42709e+06	Test_set-mae:314980
# [254]	Test_set-rmse:1.4237e+06	Test_set-mae:313331
# [255]	Test_set-rmse:1.41917e+06	Test_set-mae:311662
# [256]	Test_set-rmse:1.41477e+06	Test_set-mae:309973
# [257]	Test_set-rmse:1.41224e+06	Test_set-mae:308410
# [258]	Test_set-rmse:1.40794e+06	Test_set-mae:306877
# [259]	Test_set-rmse:1.4035e+06	Test_set-mae:305251
# [260]	Test_set-rmse:1.40049e+06	Test_set-mae:303706
# [261]	Test_set-rmse:1.39601e+06	Test_set-mae:302152
# [262]	Test_set-rmse:1.39158e+06	Test_set-mae:300652
# [263]	Test_set-rmse:1.38731e+06	Test_set-mae:299233
# [264]	Test_set-rmse:1.38283e+06	Test_set-mae:297848
# [265]	Test_set-rmse:1.37842e+06	Test_set-mae:296346
# [266]	Test_set-rmse:1.3747e+06	Test_set-mae:294980
# [267]	Test_set-rmse:1.37063e+06	Test_set-mae:293534
# [268]	Test_set-rmse:1.36634e+06	Test_set-mae:292105
# [269]	Test_set-rmse:1.36307e+06	Test_set-mae:290753
# [270]	Test_set-rmse:1.35955e+06	Test_set-mae:289386
# [271]	Test_set-rmse:1.35664e+06	Test_set-mae:288170
# [272]	Test_set-rmse:1.3524e+06	Test_set-mae:286815
# [273]	Test_set-rmse:1.34838e+06	Test_set-mae:285538
# [274]	Test_set-rmse:1.34438e+06	Test_set-mae:284296
# [275]	Test_set-rmse:1.34062e+06	Test_set-mae:283064
# [276]	Test_set-rmse:1.338e+06	Test_set-mae:281832
# [277]	Test_set-rmse:1.3344e+06	Test_set-mae:280568
# [278]	Test_set-rmse:1.33259e+06	Test_set-mae:279414
# [279]	Test_set-rmse:1.33013e+06	Test_set-mae:278233
# [280]	Test_set-rmse:1.3259e+06	Test_set-mae:277061
# [281]	Test_set-rmse:1.32257e+06	Test_set-mae:275861
# [282]	Test_set-rmse:1.31971e+06	Test_set-mae:274747
# [283]	Test_set-rmse:1.31727e+06	Test_set-mae:273645
# [284]	Test_set-rmse:1.31377e+06	Test_set-mae:272518
# [285]	Test_set-rmse:1.3104e+06	Test_set-mae:271472
# [286]	Test_set-rmse:1.30751e+06	Test_set-mae:270388
# [287]	Test_set-rmse:1.30461e+06	Test_set-mae:269303
# [288]	Test_set-rmse:1.30122e+06	Test_set-mae:268264
# [289]	Test_set-rmse:1.2977e+06	Test_set-mae:267210
# [290]	Test_set-rmse:1.29432e+06	Test_set-mae:266173
# [291]	Test_set-rmse:1.29164e+06	Test_set-mae:265180
# [292]	Test_set-rmse:1.28816e+06	Test_set-mae:264183
# [293]	Test_set-rmse:1.28681e+06	Test_set-mae:263237
# [294]	Test_set-rmse:1.28365e+06	Test_set-mae:262224
# [295]	Test_set-rmse:1.28042e+06	Test_set-mae:261283
# [296]	Test_set-rmse:1.27742e+06	Test_set-mae:260311
# [297]	Test_set-rmse:1.27569e+06	Test_set-mae:259415
# [298]	Test_set-rmse:1.27225e+06	Test_set-mae:258515
# [299]	Test_set-rmse:1.26916e+06	Test_set-mae:257547
# [300]	Test_set-rmse:1.26614e+06	Test_set-mae:256658
# [301]	Test_set-rmse:1.26394e+06	Test_set-mae:255859
# [302]	Test_set-rmse:1.26107e+06	Test_set-mae:255022
# [303]	Test_set-rmse:1.25926e+06	Test_set-mae:254180
# [304]	Test_set-rmse:1.25639e+06	Test_set-mae:253289
# [305]	Test_set-rmse:1.25372e+06	Test_set-mae:252486
# [306]	Test_set-rmse:1.25078e+06	Test_set-mae:251767
# [307]	Test_set-rmse:1.2489e+06	Test_set-mae:250989
# [308]	Test_set-rmse:1.24616e+06	Test_set-mae:250203
# [309]	Test_set-rmse:1.24395e+06	Test_set-mae:249486
# [310]	Test_set-rmse:1.2411e+06	Test_set-mae:248713
# [311]	Test_set-rmse:1.23803e+06	Test_set-mae:247874
# [312]	Test_set-rmse:1.23526e+06	Test_set-mae:247106
# [313]	Test_set-rmse:1.23313e+06	Test_set-mae:246369
# [314]	Test_set-rmse:1.23132e+06	Test_set-mae:245658
# [315]	Test_set-rmse:1.22816e+06	Test_set-mae:244998
# [316]	Test_set-rmse:1.22558e+06	Test_set-mae:244283
# [317]	Test_set-rmse:1.22288e+06	Test_set-mae:243520
# [318]	Test_set-rmse:1.22054e+06	Test_set-mae:242822
# [319]	Test_set-rmse:1.21806e+06	Test_set-mae:242126
# [320]	Test_set-rmse:1.21491e+06	Test_set-mae:241359
# [321]	Test_set-rmse:1.21297e+06	Test_set-mae:240680
# [322]	Test_set-rmse:1.21061e+06	Test_set-mae:240025
# [323]	Test_set-rmse:1.20785e+06	Test_set-mae:239353
# [324]	Test_set-rmse:1.20557e+06	Test_set-mae:238728
# [325]	Test_set-rmse:1.20318e+06	Test_set-mae:238097
# [326]	Test_set-rmse:1.20077e+06	Test_set-mae:237521
# [327]	Test_set-rmse:1.19826e+06	Test_set-mae:237003
# [328]	Test_set-rmse:1.19621e+06	Test_set-mae:236415
# [329]	Test_set-rmse:1.19349e+06	Test_set-mae:235793
# [330]	Test_set-rmse:1.19171e+06	Test_set-mae:235244
# [331]	Test_set-rmse:1.19048e+06	Test_set-mae:234744
# [332]	Test_set-rmse:1.18839e+06	Test_set-mae:234207
# [333]	Test_set-rmse:1.18666e+06	Test_set-mae:233647
# [334]	Test_set-rmse:1.1839e+06	Test_set-mae:233137
# [335]	Test_set-rmse:1.18142e+06	Test_set-mae:232541
# [336]	Test_set-rmse:1.1788e+06	Test_set-mae:232049
# [337]	Test_set-rmse:1.17667e+06	Test_set-mae:231558
# [338]	Test_set-rmse:1.17445e+06	Test_set-mae:231045
# [339]	Test_set-rmse:1.17177e+06	Test_set-mae:230490
# [340]	Test_set-rmse:1.16941e+06	Test_set-mae:230022
# [341]	Test_set-rmse:1.16729e+06	Test_set-mae:229521
# [342]	Test_set-rmse:1.16517e+06	Test_set-mae:229005
# [343]	Test_set-rmse:1.16416e+06	Test_set-mae:228591
# [344]	Test_set-rmse:1.1621e+06	Test_set-mae:228078
# [345]	Test_set-rmse:1.16019e+06	Test_set-mae:227622
# [346]	Test_set-rmse:1.15818e+06	Test_set-mae:227210
# [347]	Test_set-rmse:1.15702e+06	Test_set-mae:226787
# [348]	Test_set-rmse:1.15498e+06	Test_set-mae:226413
# [349]	Test_set-rmse:1.15282e+06	Test_set-mae:225932
# [350]	Test_set-rmse:1.15099e+06	Test_set-mae:225467
# [351]	Test_set-rmse:1.14904e+06	Test_set-mae:225066
# [352]	Test_set-rmse:1.14786e+06	Test_set-mae:224718
# [353]	Test_set-rmse:1.14649e+06	Test_set-mae:224337
# [354]	Test_set-rmse:1.14467e+06	Test_set-mae:223942
# [355]	Test_set-rmse:1.1425e+06	Test_set-mae:223493
# [356]	Test_set-rmse:1.14057e+06	Test_set-mae:223099
# [357]	Test_set-rmse:1.13825e+06	Test_set-mae:222747
# [358]	Test_set-rmse:1.13589e+06	Test_set-mae:222324
# [359]	Test_set-rmse:1.13398e+06	Test_set-mae:221920
# [360]	Test_set-rmse:1.13193e+06	Test_set-mae:221479
# [361]	Test_set-rmse:1.13018e+06	Test_set-mae:221171
# [362]	Test_set-rmse:1.12834e+06	Test_set-mae:220792
# [363]	Test_set-rmse:1.12664e+06	Test_set-mae:220420
# [364]	Test_set-rmse:1.12446e+06	Test_set-mae:220016
# [365]	Test_set-rmse:1.1232e+06	Test_set-mae:219727
# [366]	Test_set-rmse:1.12152e+06	Test_set-mae:219371
# [367]	Test_set-rmse:1.11991e+06	Test_set-mae:219059
# [368]	Test_set-rmse:1.11826e+06	Test_set-mae:218768
# [369]	Test_set-rmse:1.11602e+06	Test_set-mae:218364
# [370]	Test_set-rmse:1.1149e+06	Test_set-mae:218030
# [371]	Test_set-rmse:1.11327e+06	Test_set-mae:217700
# [372]	Test_set-rmse:1.1121e+06	Test_set-mae:217390
# [373]	Test_set-rmse:1.11040e+06	Test_set-mae:217029
# [374]	Test_set-rmse:1.10896e+06	Test_set-mae:216751
# [375]	Test_set-rmse:1.10731e+06	Test_set-mae:216406
# [376]	Test_set-rmse:1.10572e+06	Test_set-mae:216085
# [377]	Test_set-rmse:1.10411e+06	Test_set-mae:215786
# [378]	Test_set-rmse:1.10269e+06	Test_set-mae:215468
# [379]	Test_set-rmse:1.10087e+06	Test_set-mae:215126
# [380]	Test_set-rmse:1.1002e+06	Test_set-mae:214870
# [381]	Test_set-rmse:1.0985e+06	Test_set-mae:214568
# [382]	Test_set-rmse:1.09741e+06	Test_set-mae:214258
# [383]	Test_set-rmse:1.09588e+06	Test_set-mae:213984
# [384]	Test_set-rmse:1.09404e+06	Test_set-mae:213619
# [385]	Test_set-rmse:1.09241e+06	Test_set-mae:213311
# [386]	Test_set-rmse:1.0917e+06	Test_set-mae:213036
# [387]	Test_set-rmse:1.09017e+06	Test_set-mae:212774
# [388]	Test_set-rmse:1.08863e+06	Test_set-mae:212490
# [389]	Test_set-rmse:1.08698e+06	Test_set-mae:212192
# [390]	Test_set-rmse:1.08565e+06	Test_set-mae:211936
# [391]	Test_set-rmse:1.0846e+06	Test_set-mae:211697
# [392]	Test_set-rmse:1.08333e+06	Test_set-mae:211452
# [393]	Test_set-rmse:1.08174e+06	Test_set-mae:211183
# [394]	Test_set-rmse:1.07996e+06	Test_set-mae:210893
# [395]	Test_set-rmse:1.07866e+06	Test_set-mae:210624
# [396]	Test_set-rmse:1.07717e+06	Test_set-mae:210375
# [397]	Test_set-rmse:1.07555e+06	Test_set-mae:210131
# [398]	Test_set-rmse:1.07397e+06	Test_set-mae:209872
# [399]	Test_set-rmse:1.07213e+06	Test_set-mae:209586
# [400]	Test_set-rmse:1.07081e+06	Test_set-mae:209381
# [401]	Test_set-rmse:1.06969e+06	Test_set-mae:209173
# [402]	Test_set-rmse:1.06933e+06	Test_set-mae:209023
# [403]	Test_set-rmse:1.06779e+06	Test_set-mae:208749
# [404]	Test_set-rmse:1.06607e+06	Test_set-mae:208495
# [405]	Test_set-rmse:1.06563e+06	Test_set-mae:208333
# [406]	Test_set-rmse:1.06431e+06	Test_set-mae:208112
# [407]	Test_set-rmse:1.06407e+06	Test_set-mae:207975
# [408]	Test_set-rmse:1.06281e+06	Test_set-mae:207723
# [409]	Test_set-rmse:1.06104e+06	Test_set-mae:207467
# [410]	Test_set-rmse:1.06028e+06	Test_set-mae:207284
# [411]	Test_set-rmse:1.05947e+06	Test_set-mae:207076
# [412]	Test_set-rmse:1.05894e+06	Test_set-mae:206936
# [413]	Test_set-rmse:1.05768e+06	Test_set-mae:206780
# [414]	Test_set-rmse:1.0565e+06	Test_set-mae:206564
# [415]	Test_set-rmse:1.0549e+06	Test_set-mae:206308
# [416]	Test_set-rmse:1.05377e+06	Test_set-mae:206133
# [417]	Test_set-rmse:1.05286e+06	Test_set-mae:205986
# [418]	Test_set-rmse:1.05125e+06	Test_set-mae:205767
# [419]	Test_set-rmse:1.05114e+06	Test_set-mae:205666
# [420]	Test_set-rmse:1.04974e+06	Test_set-mae:205445
# [421]	Test_set-rmse:1.04874e+06	Test_set-mae:205271
# [422]	Test_set-rmse:1.04766e+06	Test_set-mae:205104
# [423]	Test_set-rmse:1.04645e+06	Test_set-mae:204914
# [424]	Test_set-rmse:1.04491e+06	Test_set-mae:204722
# [425]	Test_set-rmse:1.04366e+06	Test_set-mae:204550
# [426]	Test_set-rmse:1.04297e+06	Test_set-mae:204406
# [427]	Test_set-rmse:1.04205e+06	Test_set-mae:204251
# [428]	Test_set-rmse:1.04067e+06	Test_set-mae:204076
# [429]	Test_set-rmse:1.03963e+06	Test_set-mae:203909
# [430]	Test_set-rmse:1.03886e+06	Test_set-mae:203749
# [431]	Test_set-rmse:1.03755e+06	Test_set-mae:203542
# [432]	Test_set-rmse:1.03685e+06	Test_set-mae:203389
# [433]	Test_set-rmse:1.03564e+06	Test_set-mae:203228
# [434]	Test_set-rmse:1.0344e+06	Test_set-mae:203055
# [435]	Test_set-rmse:1.0332e+06	Test_set-mae:202870
# [436]	Test_set-rmse:1.03208e+06	Test_set-mae:202738
# [437]	Test_set-rmse:1.03074e+06	Test_set-mae:202577
# [438]	Test_set-rmse:1.02961e+06	Test_set-mae:202443
# [439]	Test_set-rmse:1.02874e+06	Test_set-mae:202321
# [440]	Test_set-rmse:1.02856e+06	Test_set-mae:202225
# [441]	Test_set-rmse:1.02798e+06	Test_set-mae:202061
# [442]	Test_set-rmse:1.02744e+06	Test_set-mae:201938
# [443]	Test_set-rmse:1.02652e+06	Test_set-mae:201817
# [444]	Test_set-rmse:1.02586e+06	Test_set-mae:201637
# [445]	Test_set-rmse:1.02468e+06	Test_set-mae:201498
# [446]	Test_set-rmse:1.02413e+06	Test_set-mae:201379
# [447]	Test_set-rmse:1.02303e+06	Test_set-mae:201243
# [448]	Test_set-rmse:1.02214e+06	Test_set-mae:201110
# [449]	Test_set-rmse:1.02135e+06	Test_set-mae:200987
# [450]	Test_set-rmse:1.02052e+06	Test_set-mae:200889
# [451]	Test_set-rmse:1.01958e+06	Test_set-mae:200761
# [452]	Test_set-rmse:1.01875e+06	Test_set-mae:200651
# [453]	Test_set-rmse:1.01749e+06	Test_set-mae:200512
# [454]	Test_set-rmse:1.01656e+06	Test_set-mae:200394
# [455]	Test_set-rmse:1.01543e+06	Test_set-mae:200268
# [456]	Test_set-rmse:1.01456e+06	Test_set-mae:200134
# [457]	Test_set-rmse:1.01364e+06	Test_set-mae:200006
# [458]	Test_set-rmse:1.01255e+06	Test_set-mae:199869
# [459]	Test_set-rmse:1.01174e+06	Test_set-mae:199780
# [460]	Test_set-rmse:1.0109e+06	Test_set-mae:199661
# [461]	Test_set-rmse:1.0107e+06	Test_set-mae:199575
# [462]	Test_set-rmse:1.01013e+06	Test_set-mae:199473
# [463]	Test_set-rmse:1.00958e+06	Test_set-mae:199398
# [464]	Test_set-rmse:1.00874e+06	Test_set-mae:199302
# [465]	Test_set-rmse:1.00782e+06	Test_set-mae:199199
# [466]	Test_set-rmse:1.00705e+06	Test_set-mae:199106
# [467]	Test_set-rmse:1.00611e+06	Test_set-mae:198954
# [468]	Test_set-rmse:1.00514e+06	Test_set-mae:198853
# [469]	Test_set-rmse:1.00418e+06	Test_set-mae:198760
# [470]	Test_set-rmse:1.00348e+06	Test_set-mae:198675
# [471]	Test_set-rmse:1.00253e+06	Test_set-mae:198558
# [472]	Test_set-rmse:1.00226e+06	Test_set-mae:198470
# [473]	Test_set-rmse:1.0013e+06	Test_set-mae:198355
# [474]	Test_set-rmse:1.00031e+06	Test_set-mae:198245
# [475]	Test_set-rmse:999374	Test_set-mae:198142
# [476]	Test_set-rmse:998428	Test_set-mae:198029
# [477]	Test_set-rmse:997608	Test_set-mae:197927
# [478]	Test_set-rmse:996610	Test_set-mae:197822
# [479]	Test_set-rmse:995941	Test_set-mae:197736
# [480]	Test_set-rmse:995005	Test_set-mae:197635
# [481]	Test_set-rmse:994120	Test_set-mae:197527
# [482]	Test_set-rmse:993316	Test_set-mae:197461
# [483]	Test_set-rmse:992352	Test_set-mae:197369
# [484]	Test_set-rmse:991772	Test_set-mae:197299
# [485]	Test_set-rmse:991075	Test_set-mae:197225
# [486]	Test_set-rmse:990365	Test_set-mae:197107
# [487]	Test_set-rmse:989616	Test_set-mae:197040
# [488]	Test_set-rmse:989322	Test_set-mae:196980
# [489]	Test_set-rmse:988633	Test_set-mae:196899
# [490]	Test_set-rmse:987909	Test_set-mae:196824
# [491]	Test_set-rmse:987161	Test_set-mae:196755
# [492]	Test_set-rmse:986683	Test_set-mae:196675
# [493]	Test_set-rmse:986071	Test_set-mae:196579
# [494]	Test_set-rmse:985557	Test_set-mae:196511
# [495]	Test_set-rmse:985083	Test_set-mae:196453
# [496]	Test_set-rmse:984633	Test_set-mae:196363
# [497]	Test_set-rmse:983890	Test_set-mae:196311
# [498]	Test_set-rmse:983781	Test_set-mae:196269
# [499]	Test_set-rmse:983184	Test_set-mae:196194
# [500]	Test_set-rmse:982931	Test_set-mae:196156
# [501]	Test_set-rmse:982219	Test_set-mae:196093
# [502]	Test_set-rmse:981843	Test_set-mae:196033
# [503]	Test_set-rmse:981024	Test_set-mae:195928
# [504]	Test_set-rmse:980367	Test_set-mae:195849
# [505]	Test_set-rmse:980133	Test_set-mae:195817
# [506]	Test_set-rmse:979606	Test_set-mae:195759
# [507]	Test_set-rmse:979446	Test_set-mae:195713
# [508]	Test_set-rmse:979263	Test_set-mae:195669
# [509]	Test_set-rmse:978957	Test_set-mae:195600
# [510]	Test_set-rmse:978589	Test_set-mae:195545
# [511]	Test_set-rmse:978210	Test_set-mae:195469
# [512]	Test_set-rmse:977857	Test_set-mae:195425
# [513]	Test_set-rmse:977662	Test_set-mae:195360
# [514]	Test_set-rmse:976630	Test_set-mae:195240
# [515]	Test_set-rmse:976201	Test_set-mae:195189
# [516]	Test_set-rmse:975815	Test_set-mae:195122
# [517]	Test_set-rmse:975451	Test_set-mae:195076
# [518]	Test_set-rmse:975301	Test_set-mae:195037
# [519]	Test_set-rmse:974720	Test_set-mae:194979
# [520]	Test_set-rmse:974590	Test_set-mae:194937
# [521]	Test_set-rmse:974311	Test_set-mae:194880
# [522]	Test_set-rmse:973754	Test_set-mae:194816
# [523]	Test_set-rmse:973441	Test_set-mae:194740
# [524]	Test_set-rmse:972656	Test_set-mae:194629
# [525]	Test_set-rmse:971856	Test_set-mae:194571
# [526]	Test_set-rmse:971642	Test_set-mae:194542
# [527]	Test_set-rmse:971485	Test_set-mae:194500
# [528]	Test_set-rmse:971304	Test_set-mae:194473
# [529]	Test_set-rmse:970850	Test_set-mae:194409
# [530]	Test_set-rmse:970048	Test_set-mae:194351
# [531]	Test_set-rmse:969116	Test_set-mae:194268
# [532]	Test_set-rmse:968779	Test_set-mae:194187
# [533]	Test_set-rmse:968205	Test_set-mae:194122
# [534]	Test_set-rmse:967474	Test_set-mae:194046
# [535]	Test_set-rmse:967233	Test_set-mae:193980
# [536]	Test_set-rmse:966894	Test_set-mae:193937
# [537]	Test_set-rmse:966321	Test_set-mae:193885
# [538]	Test_set-rmse:966152	Test_set-mae:193865
# [539]	Test_set-rmse:965918	Test_set-mae:193836
# [540]	Test_set-rmse:965251	Test_set-mae:193774
# [541]	Test_set-rmse:964874	Test_set-mae:193730
# [542]	Test_set-rmse:964032	Test_set-mae:193668
# [543]	Test_set-rmse:963337	Test_set-mae:193599
# [544]	Test_set-rmse:962713	Test_set-mae:193502
# [545]	Test_set-rmse:962570	Test_set-mae:193449
# [546]	Test_set-rmse:962338	Test_set-mae:193412
# [547]	Test_set-rmse:961627	Test_set-mae:193343
# [548]	Test_set-rmse:961321	Test_set-mae:193301
# [549]	Test_set-rmse:960986	Test_set-mae:193267
# [550]	Test_set-rmse:960459	Test_set-mae:193223
# [551]	Test_set-rmse:960236	Test_set-mae:193201
# [552]	Test_set-rmse:959624	Test_set-mae:193147
# [553]	Test_set-rmse:959477	Test_set-mae:193127
# [554]	Test_set-rmse:959201	Test_set-mae:193079
# [555]	Test_set-rmse:959020	Test_set-mae:193060
# [556]	Test_set-rmse:958670	Test_set-mae:193016
# [557]	Test_set-rmse:958422	Test_set-mae:192982
# [558]	Test_set-rmse:958369	Test_set-mae:192965
# [559]	Test_set-rmse:958101	Test_set-mae:192920
# [560]	Test_set-rmse:957597	Test_set-mae:192868
# [561]	Test_set-rmse:957578	Test_set-mae:192858
# [562]	Test_set-rmse:957396	Test_set-mae:192791
# [563]	Test_set-rmse:956908	Test_set-mae:192751
# [564]	Test_set-rmse:956539	Test_set-mae:192710
# [565]	Test_set-rmse:956251	Test_set-mae:192680
# [566]	Test_set-rmse:955903	Test_set-mae:192647
# [567]	Test_set-rmse:955706	Test_set-mae:192609
# [568]	Test_set-rmse:955619	Test_set-mae:192566
# [569]	Test_set-rmse:955037	Test_set-mae:192526
# [570]	Test_set-rmse:954782	Test_set-mae:192489
# [571]	Test_set-rmse:954604	Test_set-mae:192462
# [572]	Test_set-rmse:954367	Test_set-mae:192432
# [573]	Test_set-rmse:953938	Test_set-mae:192388
# [574]	Test_set-rmse:953752	Test_set-mae:192339
# [575]	Test_set-rmse:953459	Test_set-mae:192280
# [576]	Test_set-rmse:953056	Test_set-mae:192244
# [577]	Test_set-rmse:952773	Test_set-mae:192209
# [578]	Test_set-rmse:952488	Test_set-mae:192180
# [579]	Test_set-rmse:952168	Test_set-mae:192148
# [580]	Test_set-rmse:951955	Test_set-mae:192120
# [581]	Test_set-rmse:951812	Test_set-mae:192090
# [582]	Test_set-rmse:951615	Test_set-mae:192024
# [583]	Test_set-rmse:951421	Test_set-mae:192008
# [584]	Test_set-rmse:950989	Test_set-mae:191968
# [585]	Test_set-rmse:950488	Test_set-mae:191932
# [586]	Test_set-rmse:950372	Test_set-mae:191912
# [587]	Test_set-rmse:950246	Test_set-mae:191901
# [588]	Test_set-rmse:949911	Test_set-mae:191854
# [589]	Test_set-rmse:949590	Test_set-mae:191798
# [590]	Test_set-rmse:949024	Test_set-mae:191741
# [591]	Test_set-rmse:948734	Test_set-mae:191708
# [592]	Test_set-rmse:948420	Test_set-mae:191640
# [593]	Test_set-rmse:948272	Test_set-mae:191611
# [594]	Test_set-rmse:948090	Test_set-mae:191565
# [595]	Test_set-rmse:947975	Test_set-mae:191543
# [596]	Test_set-rmse:947827	Test_set-mae:191522
# [597]	Test_set-rmse:947400	Test_set-mae:191479
# [598]	Test_set-rmse:947191	Test_set-mae:191446
# [599]	Test_set-rmse:947013	Test_set-mae:191411
# [600]	Test_set-rmse:946851	Test_set-mae:191407
# [601]	Test_set-rmse:946533	Test_set-mae:191370
# [602]	Test_set-rmse:946458	Test_set-mae:191362
# [603]	Test_set-rmse:946217	Test_set-mae:191316
# [604]	Test_set-rmse:945839	Test_set-mae:191289
# [605]	Test_set-rmse:945402	Test_set-mae:191238
# [606]	Test_set-rmse:945219	Test_set-mae:191206
# [607]	Test_set-rmse:945104	Test_set-mae:191179
# [608]	Test_set-rmse:944773	Test_set-mae:191140
# [609]	Test_set-rmse:944460	Test_set-mae:191093
# [610]	Test_set-rmse:944285	Test_set-mae:191063
# [611]	Test_set-rmse:944158	Test_set-mae:191036
# [612]	Test_set-rmse:943868	Test_set-mae:190995
# [613]	Test_set-rmse:943727	Test_set-mae:190963
# [614]	Test_set-rmse:943586	Test_set-mae:190948
# [615]	Test_set-rmse:943358	Test_set-mae:190921
# [616]	Test_set-rmse:943259	Test_set-mae:190901
# [617]	Test_set-rmse:943178	Test_set-mae:190890
# [618]	Test_set-rmse:943038	Test_set-mae:190867
# [619]	Test_set-rmse:942748	Test_set-mae:190840
# [620]	Test_set-rmse:942626	Test_set-mae:190825
# [621]	Test_set-rmse:942483	Test_set-mae:190802
# [622]	Test_set-rmse:942405	Test_set-mae:190781
# [623]	Test_set-rmse:942171	Test_set-mae:190761
# [624]	Test_set-rmse:941702	Test_set-mae:190729
# [625]	Test_set-rmse:941485	Test_set-mae:190700
# [626]	Test_set-rmse:941405	Test_set-mae:190677
# [627]	Test_set-rmse:941172	Test_set-mae:190643
# [628]	Test_set-rmse:941053	Test_set-mae:190623
# [629]	Test_set-rmse:940938	Test_set-mae:190604
# [630]	Test_set-rmse:940816	Test_set-mae:190589
# [631]	Test_set-rmse:940563	Test_set-mae:190566
# [632]	Test_set-rmse:940473	Test_set-mae:190539
# [633]	Test_set-rmse:940403	Test_set-mae:190525
# [634]	Test_set-rmse:940313	Test_set-mae:190497
# [635]	Test_set-rmse:940190	Test_set-mae:190478
# [636]	Test_set-rmse:939962	Test_set-mae:190464
# [637]	Test_set-rmse:939853	Test_set-mae:190437
# [638]	Test_set-rmse:939642	Test_set-mae:190429
# [639]	Test_set-rmse:939277	Test_set-mae:190403
# [640]	Test_set-rmse:939162	Test_set-mae:190386
# [641]	Test_set-rmse:939127	Test_set-mae:190372
# [642]	Test_set-rmse:939000	Test_set-mae:190337
# [643]	Test_set-rmse:938785	Test_set-mae:190322
# [644]	Test_set-rmse:938666	Test_set-mae:190301
# [645]	Test_set-rmse:938459	Test_set-mae:190270
# [646]	Test_set-rmse:938358	Test_set-mae:190253
# [647]	Test_set-rmse:938298	Test_set-mae:190243
# [648]	Test_set-rmse:938068	Test_set-mae:190224
# [649]	Test_set-rmse:937960	Test_set-mae:190192
# [650]	Test_set-rmse:937851	Test_set-mae:190177
# [651]	Test_set-rmse:937327	Test_set-mae:190148
# [652]	Test_set-rmse:937227	Test_set-mae:190121
# [653]	Test_set-rmse:937134	Test_set-mae:190101
# [654]	Test_set-rmse:936828	Test_set-mae:190077
# [655]	Test_set-rmse:936478	Test_set-mae:190056
# [656]	Test_set-rmse:936405	Test_set-mae:190034
# [657]	Test_set-rmse:936327	Test_set-mae:190023
# [658]	Test_set-rmse:936071	Test_set-mae:189975
# [659]	Test_set-rmse:935994	Test_set-mae:189962
# [660]	Test_set-rmse:935861	Test_set-mae:189905
# [661]	Test_set-rmse:935515	Test_set-mae:189868
# [662]	Test_set-rmse:935184	Test_set-mae:189836
# [663]	Test_set-rmse:935135	Test_set-mae:189807
# [664]	Test_set-rmse:935037	Test_set-mae:189792
# [665]	Test_set-rmse:934913	Test_set-mae:189768
# [666]	Test_set-rmse:934768	Test_set-mae:189760
# [667]	Test_set-rmse:934715	Test_set-mae:189750
# [668]	Test_set-rmse:934513	Test_set-mae:189725
# [669]	Test_set-rmse:934428	Test_set-mae:189700
# [670]	Test_set-rmse:934072	Test_set-mae:189659
# [671]	Test_set-rmse:933843	Test_set-mae:189636
# [672]	Test_set-rmse:933715	Test_set-mae:189596
# [673]	Test_set-rmse:933650	Test_set-mae:189585
# [674]	Test_set-rmse:933544	Test_set-mae:189571
# [675]	Test_set-rmse:933445	Test_set-mae:189553
# [676]	Test_set-rmse:933386	Test_set-mae:189536
# [677]	Test_set-rmse:933069	Test_set-mae:189517
# [678]	Test_set-rmse:932886	Test_set-mae:189487
# [679]	Test_set-rmse:932654	Test_set-mae:189466
# [680]	Test_set-rmse:932504	Test_set-mae:189455
# [681]	Test_set-rmse:932513	Test_set-mae:189449
# [682]	Test_set-rmse:932204	Test_set-mae:189425
# [683]	Test_set-rmse:932108	Test_set-mae:189429
# [684]	Test_set-rmse:932037	Test_set-mae:189402
# [685]	Test_set-rmse:931876	Test_set-mae:189391
# [686]	Test_set-rmse:931578	Test_set-mae:189369
# [687]	Test_set-rmse:931478	Test_set-mae:189342
# [688]	Test_set-rmse:931414	Test_set-mae:189338
# [689]	Test_set-rmse:931297	Test_set-mae:189292
# [690]	Test_set-rmse:931125	Test_set-mae:189274
# [691]	Test_set-rmse:931048	Test_set-mae:189261
# [692]	Test_set-rmse:930984	Test_set-mae:189246
# [693]	Test_set-rmse:930931	Test_set-mae:189230
# [694]	Test_set-rmse:930665	Test_set-mae:189209
# [695]	Test_set-rmse:930565	Test_set-mae:189193
# [696]	Test_set-rmse:930287	Test_set-mae:189177
# [697]	Test_set-rmse:930208	Test_set-mae:189162
# [698]	Test_set-rmse:930038	Test_set-mae:189147
# [699]	Test_set-rmse:929774	Test_set-mae:189129
# [700]	Test_set-rmse:929489	Test_set-mae:189101
# [701]	Test_set-rmse:929305	Test_set-mae:189084
# [702]	Test_set-rmse:929108	Test_set-mae:189038
# [703]	Test_set-rmse:929064	Test_set-mae:189028
# [704]	Test_set-rmse:929027	Test_set-mae:189016
# [705]	Test_set-rmse:928973	Test_set-mae:189003
# [706]	Test_set-rmse:928873	Test_set-mae:188985
# [707]	Test_set-rmse:928810	Test_set-mae:188968
# [708]	Test_set-rmse:928749	Test_set-mae:188951
# [709]	Test_set-rmse:928674	Test_set-mae:188937
# [710]	Test_set-rmse:928568	Test_set-mae:188929
# [711]	Test_set-rmse:928537	Test_set-mae:188916
# [712]	Test_set-rmse:928499	Test_set-mae:188905
# [713]	Test_set-rmse:928458	Test_set-mae:188874
# [714]	Test_set-rmse:928146	Test_set-mae:188849
# [715]	Test_set-rmse:927831	Test_set-mae:188818
# [716]	Test_set-rmse:927773	Test_set-mae:188799
# [717]	Test_set-rmse:927517	Test_set-mae:188784
# [718]	Test_set-rmse:927254	Test_set-mae:188736
# [719]	Test_set-rmse:927193	Test_set-mae:188729
# [720]	Test_set-rmse:926982	Test_set-mae:188710
# [721]	Test_set-rmse:926935	Test_set-mae:188689
# [722]	Test_set-rmse:926672	Test_set-mae:188672
# [723]	Test_set-rmse:926440	Test_set-mae:188659
# [724]	Test_set-rmse:926185	Test_set-mae:188628
# [725]	Test_set-rmse:925922	Test_set-mae:188606
# [726]	Test_set-rmse:925888	Test_set-mae:188600
# [727]	Test_set-rmse:925658	Test_set-mae:188574
# [728]	Test_set-rmse:925579	Test_set-mae:188562
# [729]	Test_set-rmse:925291	Test_set-mae:188540
# [730]	Test_set-rmse:925223	Test_set-mae:188525
# [731]	Test_set-rmse:924942	Test_set-mae:188504
# [732]	Test_set-rmse:924936	Test_set-mae:188496
# [733]	Test_set-rmse:924588	Test_set-mae:188457
# [734]	Test_set-rmse:924535	Test_set-mae:188450
# [735]	Test_set-rmse:924307	Test_set-mae:188435
# [736]	Test_set-rmse:924122	Test_set-mae:188420
# [737]	Test_set-rmse:923874	Test_set-mae:188402
# [738]	Test_set-rmse:923622	Test_set-mae:188382
# [739]	Test_set-rmse:923579	Test_set-mae:188364
# [740]	Test_set-rmse:923320	Test_set-mae:188343
# [741]	Test_set-rmse:923298	Test_set-mae:188337
# [742]	Test_set-rmse:923091	Test_set-mae:188316
# [743]	Test_set-rmse:922947	Test_set-mae:188300
# [744]	Test_set-rmse:922918	Test_set-mae:188300
# [745]	Test_set-rmse:922684	Test_set-mae:188284
# [746]	Test_set-rmse:922437	Test_set-mae:188268
# [747]	Test_set-rmse:922249	Test_set-mae:188258
# [748]	Test_set-rmse:922185	Test_set-mae:188235
# [749]	Test_set-rmse:921852	Test_set-mae:188198
# [750]	Test_set-rmse:921704	Test_set-mae:188169
# [751]	Test_set-rmse:921485	Test_set-mae:188151
# [752]	Test_set-rmse:921275	Test_set-mae:188134
# [753]	Test_set-rmse:921019	Test_set-mae:188115
# [754]	Test_set-rmse:920764	Test_set-mae:188087
# [755]	Test_set-rmse:920690	Test_set-mae:188074
# [756]	Test_set-rmse:920465	Test_set-mae:188040
# [757]	Test_set-rmse:920240	Test_set-mae:188021
# [758]	Test_set-rmse:920044	Test_set-mae:188017
# [759]	Test_set-rmse:920035	Test_set-mae:188013
# [760]	Test_set-rmse:919828	Test_set-mae:188003
# [761]	Test_set-rmse:919616	Test_set-mae:187991
# [762]	Test_set-rmse:919609	Test_set-mae:187984
# [763]	Test_set-rmse:919313	Test_set-mae:187953
# [764]	Test_set-rmse:919265	Test_set-mae:187939
# [765]	Test_set-rmse:919036	Test_set-mae:187907
# [766]	Test_set-rmse:919030	Test_set-mae:187909
# [767]	Test_set-rmse:918812	Test_set-mae:187895
# [768]	Test_set-rmse:918792	Test_set-mae:187890
# [769]	Test_set-rmse:918535	Test_set-mae:187863
# [770]	Test_set-rmse:918504	Test_set-mae:187857
# [771]	Test_set-rmse:918277	Test_set-mae:187831
# [772]	Test_set-rmse:918169	Test_set-mae:187800
# [773]	Test_set-rmse:917949	Test_set-mae:187786
# [774]	Test_set-rmse:917758	Test_set-mae:187764
# [775]	Test_set-rmse:917644	Test_set-mae:187756
# [776]	Test_set-rmse:917458	Test_set-mae:187732
# [777]	Test_set-rmse:917276	Test_set-mae:187720
# [778]	Test_set-rmse:917251	Test_set-mae:187715
# [779]	Test_set-rmse:917023	Test_set-mae:187693
# [780]	Test_set-rmse:916797	Test_set-mae:187665
# [781]	Test_set-rmse:916511	Test_set-mae:187639
# [782]	Test_set-rmse:916352	Test_set-mae:187606
# [783]	Test_set-rmse:916128	Test_set-mae:187585
# [784]	Test_set-rmse:915932	Test_set-mae:187567
# [785]	Test_set-rmse:915933	Test_set-mae:187566
# [786]	Test_set-rmse:915651	Test_set-mae:187532
# [787]	Test_set-rmse:915465	Test_set-mae:187511
# [788]	Test_set-rmse:915444	Test_set-mae:187505
# [789]	Test_set-rmse:915203	Test_set-mae:187485
# [790]	Test_set-rmse:915030	Test_set-mae:187468
# [791]	Test_set-rmse:914932	Test_set-mae:187452
# [792]	Test_set-rmse:914748	Test_set-mae:187438
# [793]	Test_set-rmse:914473	Test_set-mae:187426
# [794]	Test_set-rmse:914305	Test_set-mae:187414
# [795]	Test_set-rmse:914105	Test_set-mae:187398
# [796]	Test_set-rmse:914091	Test_set-mae:187380
# [797]	Test_set-rmse:913875	Test_set-mae:187351
# [798]	Test_set-rmse:913695	Test_set-mae:187343
# [799]	Test_set-rmse:913523	Test_set-mae:187333
# [800]	Test_set-rmse:913358	Test_set-mae:187314
# [801]	Test_set-rmse:913263	Test_set-mae:187301
# [802]	Test_set-rmse:913084	Test_set-mae:187277
# [803]	Test_set-rmse:912911	Test_set-mae:187262
# [804]	Test_set-rmse:912733	Test_set-mae:187241
# [805]	Test_set-rmse:912556	Test_set-mae:187224
# [806]	Test_set-rmse:912582	Test_set-mae:187214
# [807]	Test_set-rmse:912376	Test_set-mae:187186
# [808]	Test_set-rmse:912335	Test_set-mae:187170
# [809]	Test_set-rmse:912328	Test_set-mae:187166
# [810]	Test_set-rmse:912158	Test_set-mae:187151
# [811]	Test_set-rmse:911993	Test_set-mae:187138
# [812]	Test_set-rmse:911855	Test_set-mae:187127
# [813]	Test_set-rmse:911838	Test_set-mae:187099
# [814]	Test_set-rmse:911662	Test_set-mae:187080
# [815]	Test_set-rmse:911513	Test_set-mae:187068
# [816]	Test_set-rmse:911346	Test_set-mae:187053
# [817]	Test_set-rmse:911250	Test_set-mae:187040
# [818]	Test_set-rmse:911116	Test_set-mae:187032
# [819]	Test_set-rmse:911044	Test_set-mae:187018
# [820]	Test_set-rmse:910885	Test_set-mae:187009
# [821]	Test_set-rmse:910719	Test_set-mae:186993
# [822]	Test_set-rmse:910711	Test_set-mae:186981
# [823]	Test_set-rmse:910553	Test_set-mae:186973
# [824]	Test_set-rmse:910426	Test_set-mae:186952
# [825]	Test_set-rmse:910437	Test_set-mae:186945
# [826]	Test_set-rmse:910382	Test_set-mae:186941
# [827]	Test_set-rmse:910246	Test_set-mae:186933
# [828]	Test_set-rmse:910091	Test_set-mae:186916
# [829]	Test_set-rmse:909958	Test_set-mae:186905
# [830]	Test_set-rmse:909920	Test_set-mae:186894
# [831]	Test_set-rmse:909893	Test_set-mae:186888
# [832]	Test_set-rmse:909745	Test_set-mae:186866
# [833]	Test_set-rmse:909587	Test_set-mae:186848
# [834]	Test_set-rmse:909419	Test_set-mae:186831
# [835]	Test_set-rmse:909359	Test_set-mae:186822
# [836]	Test_set-rmse:909367	Test_set-mae:186818
# [837]	Test_set-rmse:909332	Test_set-mae:186813
# [838]	Test_set-rmse:909128	Test_set-mae:186797
# [839]	Test_set-rmse:908956	Test_set-mae:186776
# [840]	Test_set-rmse:908939	Test_set-mae:186773
# [841]	Test_set-rmse:908778	Test_set-mae:186755
# [842]	Test_set-rmse:908628	Test_set-mae:186745
# [843]	Test_set-rmse:908594	Test_set-mae:186737
# [844]	Test_set-rmse:908459	Test_set-mae:186731
# [845]	Test_set-rmse:908306	Test_set-mae:186707
# [846]	Test_set-rmse:908162	Test_set-mae:186687
# [847]	Test_set-rmse:908024	Test_set-mae:186671
# [848]	Test_set-rmse:908007	Test_set-mae:186663
# [849]	Test_set-rmse:907788	Test_set-mae:186649
# [850]	Test_set-rmse:907704	Test_set-mae:186643
# [851]	Test_set-rmse:907549	Test_set-mae:186620
# [852]	Test_set-rmse:907398	Test_set-mae:186595
# [853]	Test_set-rmse:907331	Test_set-mae:186590
# [854]	Test_set-rmse:907195	Test_set-mae:186573
# [855]	Test_set-rmse:907133	Test_set-mae:186570
# [856]	Test_set-rmse:907104	Test_set-mae:186557
# [857]	Test_set-rmse:906892	Test_set-mae:186540
# [858]	Test_set-rmse:906759	Test_set-mae:186531
# [859]	Test_set-rmse:906602	Test_set-mae:186511
# [860]	Test_set-rmse:906447	Test_set-mae:186489
# [861]	Test_set-rmse:906301	Test_set-mae:186478
# [862]	Test_set-rmse:906184	Test_set-mae:186452
# [863]	Test_set-rmse:906174	Test_set-mae:186449
# [864]	Test_set-rmse:906138	Test_set-mae:186443
# [865]	Test_set-rmse:905994	Test_set-mae:186424
# [866]	Test_set-rmse:905831	Test_set-mae:186404
# [867]	Test_set-rmse:905834	Test_set-mae:186408
# [868]	Test_set-rmse:905655	Test_set-mae:186394
# [869]	Test_set-rmse:905600	Test_set-mae:186389
# [870]	Test_set-rmse:905545	Test_set-mae:186389
# [871]	Test_set-rmse:905400	Test_set-mae:186374
# [872]	Test_set-rmse:905265	Test_set-mae:186344
# [873]	Test_set-rmse:905131	Test_set-mae:186335
# [874]	Test_set-rmse:905132	Test_set-mae:186332
# [875]	Test_set-rmse:905013	Test_set-mae:186323
# [876]	Test_set-rmse:904992	Test_set-mae:186316
# [877]	Test_set-rmse:904896	Test_set-mae:186310
# [878]	Test_set-rmse:904775	Test_set-mae:186305
# [879]	Test_set-rmse:904663	Test_set-mae:186302
# [880]	Test_set-rmse:904517	Test_set-mae:186289
# [881]	Test_set-rmse:904374	Test_set-mae:186275
# [882]	Test_set-rmse:904302	Test_set-mae:186268
# [883]	Test_set-rmse:904239	Test_set-mae:186267
# [884]	Test_set-rmse:904226	Test_set-mae:186260
# [885]	Test_set-rmse:904038	Test_set-mae:186241
# [886]	Test_set-rmse:904030	Test_set-mae:186235
# [887]	Test_set-rmse:903922	Test_set-mae:186231
# [888]	Test_set-rmse:903748	Test_set-mae:186212
# [889]	Test_set-rmse:903742	Test_set-mae:186206
# [890]	Test_set-rmse:903633	Test_set-mae:186202
# [891]	Test_set-rmse:903485	Test_set-mae:186174
# [892]	Test_set-rmse:903374	Test_set-mae:186158
# [893]	Test_set-rmse:903335	Test_set-mae:186160
# [894]	Test_set-rmse:903277	Test_set-mae:186152
# [895]	Test_set-rmse:903158	Test_set-mae:186128
# [896]	Test_set-rmse:903129	Test_set-mae:186098
# [897]	Test_set-rmse:903014	Test_set-mae:186087
# [898]	Test_set-rmse:902995	Test_set-mae:186073
# [899]	Test_set-rmse:902807	Test_set-mae:186056
# [900]	Test_set-rmse:902682	Test_set-mae:186037
# [901]	Test_set-rmse:902576	Test_set-mae:186018
# [902]	Test_set-rmse:902529	Test_set-mae:186011
# [903]	Test_set-rmse:902429	Test_set-mae:186005
# [904]	Test_set-rmse:902319	Test_set-mae:185993
# [905]	Test_set-rmse:902192	Test_set-mae:185973
# [906]	Test_set-rmse:902118	Test_set-mae:185953
# [907]	Test_set-rmse:902098	Test_set-mae:185945
# [908]	Test_set-rmse:902000	Test_set-mae:185926
# [909]	Test_set-rmse:901841	Test_set-mae:185907
# [910]	Test_set-rmse:901786	Test_set-mae:185896
# [911]	Test_set-rmse:901671	Test_set-mae:185884
# [912]	Test_set-rmse:901496	Test_set-mae:185868
# [913]	Test_set-rmse:901506	Test_set-mae:185873
# [914]	Test_set-rmse:901416	Test_set-mae:185857
# [915]	Test_set-rmse:901397	Test_set-mae:185854
# [916]	Test_set-rmse:901218	Test_set-mae:185823
# [917]	Test_set-rmse:901126	Test_set-mae:185812
# [918]	Test_set-rmse:901119	Test_set-mae:185816
# [919]	Test_set-rmse:901018	Test_set-mae:185789
# [920]	Test_set-rmse:900918	Test_set-mae:185765
# [921]	Test_set-rmse:900792	Test_set-mae:185733
# [922]	Test_set-rmse:900691	Test_set-mae:185718
# [923]	Test_set-rmse:900588	Test_set-mae:185709
# [924]	Test_set-rmse:900497	Test_set-mae:185699
# [925]	Test_set-rmse:900326	Test_set-mae:185675
# [926]	Test_set-rmse:900240	Test_set-mae:185666
# [927]	Test_set-rmse:900072	Test_set-mae:185649
# [928]	Test_set-rmse:900011	Test_set-mae:185639
# [929]	Test_set-rmse:899901	Test_set-mae:185624
# [930]	Test_set-rmse:899892	Test_set-mae:185613
# [931]	Test_set-rmse:899749	Test_set-mae:185601
# [932]	Test_set-rmse:899654	Test_set-mae:185600
# [933]	Test_set-rmse:899541	Test_set-mae:185583
# [934]	Test_set-rmse:899440	Test_set-mae:185571
# [935]	Test_set-rmse:899431	Test_set-mae:185568
# [936]	Test_set-rmse:899426	Test_set-mae:185561
# [937]	Test_set-rmse:899323	Test_set-mae:185545
# [938]	Test_set-rmse:899310	Test_set-mae:185542
# [939]	Test_set-rmse:899240	Test_set-mae:185539
# [940]	Test_set-rmse:899268	Test_set-mae:185532
# [941]	Test_set-rmse:899207	Test_set-mae:185519
# [942]	Test_set-rmse:899177	Test_set-mae:185518
# [943]	Test_set-rmse:899113	Test_set-mae:185508
# [944]	Test_set-rmse:899057	Test_set-mae:185509
# [945]	Test_set-rmse:898963	Test_set-mae:185499
# [946]	Test_set-rmse:898960	Test_set-mae:185494
# [947]	Test_set-rmse:898944	Test_set-mae:185485
# [948]	Test_set-rmse:898858	Test_set-mae:185467
# [949]	Test_set-rmse:898776	Test_set-mae:185461
# [950]	Test_set-rmse:898667	Test_set-mae:185443
# [951]	Test_set-rmse:898552	Test_set-mae:185416
# [952]	Test_set-rmse:898484	Test_set-mae:185410
# [953]	Test_set-rmse:898371	Test_set-mae:185401
# [954]	Test_set-rmse:898305	Test_set-mae:185387
# [955]	Test_set-rmse:898240	Test_set-mae:185373
# [956]	Test_set-rmse:898147	Test_set-mae:185367
# [957]	Test_set-rmse:898056	Test_set-mae:185354
# [958]	Test_set-rmse:897945	Test_set-mae:185341
# [959]	Test_set-rmse:897930	Test_set-mae:185328
# [960]	Test_set-rmse:897830	Test_set-mae:185316
# [961]	Test_set-rmse:897739	Test_set-mae:185306
# [962]	Test_set-rmse:897689	Test_set-mae:185303
# [963]	Test_set-rmse:897599	Test_set-mae:185293
# [964]	Test_set-rmse:897512	Test_set-mae:185293
# [965]	Test_set-rmse:897452	Test_set-mae:185291
# [966]	Test_set-rmse:897450	Test_set-mae:185291
# [967]	Test_set-rmse:897359	Test_set-mae:185276
# [968]	Test_set-rmse:897276	Test_set-mae:185253
# [969]	Test_set-rmse:897242	Test_set-mae:185249
# [970]	Test_set-rmse:897243	Test_set-mae:185246
# [971]	Test_set-rmse:897215	Test_set-mae:185243
# [972]	Test_set-rmse:897119	Test_set-mae:185220
# [973]	Test_set-rmse:897048	Test_set-mae:185213
# [974]	Test_set-rmse:896965	Test_set-mae:185196
# [975]	Test_set-rmse:896924	Test_set-mae:185197
# [976]	Test_set-rmse:896829	Test_set-mae:185174
# [977]	Test_set-rmse:896740	Test_set-mae:185167
# [978]	Test_set-rmse:896708	Test_set-mae:185157
# [979]	Test_set-rmse:896645	Test_set-mae:185148
# [980]	Test_set-rmse:896645	Test_set-mae:185139
# [981]	Test_set-rmse:896557	Test_set-mae:185125
# [982]	Test_set-rmse:896566	Test_set-mae:185124
# [983]	Test_set-rmse:896569	Test_set-mae:185123
# [984]	Test_set-rmse:896469	Test_set-mae:185118
# [985]	Test_set-rmse:896402	Test_set-mae:185095
# [986]	Test_set-rmse:896390	Test_set-mae:185092
# [987]	Test_set-rmse:896254	Test_set-mae:185080
# [988]	Test_set-rmse:896150	Test_set-mae:185054
# [989]	Test_set-rmse:896148	Test_set-mae:185039
# [990]	Test_set-rmse:896063	Test_set-mae:185033
# [991]	Test_set-rmse:895991	Test_set-mae:185025
# [992]	Test_set-rmse:896004	Test_set-mae:185024
# [993]	Test_set-rmse:895991	Test_set-mae:184995
# [994]	Test_set-rmse:895903	Test_set-mae:184978
# [995]	Test_set-rmse:895836	Test_set-mae:184962
# [996]	Test_set-rmse:895760	Test_set-mae:184957
# [997]	Test_set-rmse:895744	Test_set-mae:184962
# [998]	Test_set-rmse:895650	Test_set-mae:184946

# %%
print("Average guess error", mae_baseline_value)
print("vs Mean Absolute Error", mean_absolute_error(model_value.predict(dtest_value), y_test_value))
# Out:
# Average guess error 2857131.3053849954
# vs Mean Absolute Error 184945.91504281646

# %%
#Feature Importance
plt.figure(figsize=(20,15))
xgb.plot_importance(model_value, ax=plt.gca())

# %%
#Tree Diagram
plt.figure()
plt.savefig('tree_value.png');

# %%
#Predict the value based on the model.
dpred_value = xgb.DMatrix(fifasup_mach, label = y_value)
y_pred = pd.Series(model_value.predict(dpred_value))

# %%
#Top 10% players with overpriced transfer values.
sub_value = y_value.subtract(y_pred)
exp_value = fifasup_mach.loc[sub_value.nlargest(int(len(sub_value)/1000)).index]
exp_value.head()
# Out:
#     Age  Height(cm)  Weight(kgs)  Weak Foot  Inter_Rep  Overall  Potential  \
# 28   26  155.745200    78.035024        3.0        4.0       88         89
# 2    26  179.823225    68.053800        5.0        5.0       92         93
# 0    31  173.727522    72.137028        4.0        5.0       94         94
# 15   24  155.440415    74.859180        3.0        3.0       89         94
# 91   29  182.871076    71.229644        3.0        3.0       85         85
#
#     Difference  Release_Clause(€M)  Special  ...  LDM  CDM  RDM  RWB  LB  LCB  \
# 28           1            200000.0     2171  ...   68   68   68   69  65   58
# 2            1         228100000.0     2143  ...   60   60   60   65  60   47
# 0            0         226500000.0     2202  ...   61   61   61   64  59   47
# 15           5         153500000.0     2092  ...   58   58   58   62  56   45
# 91           0            200000.0     2245  ...   81   81   81   78  78   80
#
#     CB  RCB  RB  Versatility
# 28  58   58  65            1
# 2   47   47  60            1
# 0   47   47  59            1
# 15  45   45  56            1
# 91  80   80  78            1
#
# [5 rows x 72 columns]

# %%
#Top 10% players with underpriced transfer values.
cheap_value = sub_value.nsmallest(int(len(sub_value)/1000))
cheap_value = fifasup_mach.loc[cheap_value.index]
cheap_value.head()
# Out:
#       Age  Height(cm)  Weight(kgs)  Weak Foot  Inter_Rep  Overall  Potential  \
# 41     40  195.062481    92.099476        2.0        4.0       88         88
# 1964   26  182.871076    78.942408        3.0        1.0       75         78
# 1008   29  155.745200    79.849792        3.0        2.0       77         77
# 35     30  179.823225    79.849792        4.0        4.0       88         88
# 27     26  185.918927    83.933020        3.0        3.0       88         90
#
#       Difference  Release_Clause(€M)  Special  ...  LDM  CDM  RDM  RWB  LB  \
# 41             0           7400000.0     1334  ...   50   50   50   50  50
# 1964           3            200000.0     1868  ...   60   60   60   62  58
# 1008           0            200000.0     1933  ...   52   52   52   53  50
# 35             0          88200000.0     2279  ...   83   83   83   85  84
# 27             2         126400000.0     2170  ...   85   85   85   78  79
#
#       LCB  CB  RCB  RB  Versatility
# 41     50  50   50  50            1
# 1964   51  51   51  58            1
# 1008   46  46   46  50            1
# 35     81  81   81  84            1
# 27     85  85   85  79            1
#
# [5 rows x 72 columns]

# %%
model_value.save_model("model_value.model")

# %% [markdown]
# # MODELO 2: Predicción del salario

# %%
X_train_wage, X_test_wage, y_train_wage, y_test_wage = train_test_split(fifasup_mach, y_wage, test_size=0.2)

# %%
dtrain_wage = xgb.DMatrix(X_train_wage, label=y_train_wage)
dtest_wage = xgb.DMatrix(X_test_wage, label=y_test_wage)
evaluation_set_wage = [(dtest_wage, "Test_set")]

# %%
mean_train_wage = np.mean(y_train_wage)

# Get predictions on the test set
baseline_predictions_wage = np.ones(y_test_wage.shape) * mean_train_wage

# Compute MAE
mae_baseline_wage = mean_absolute_error(y_test_wage, baseline_predictions_wage)

# Compute RMSE
rmse_baseline_wage = sqrt(mean_squared_error(y_test_wage, baseline_predictions_wage))

print("Baseline MAE is {:.2f}".format(mae_baseline_wage))
print("Baseline RMSE is {:.2f}".format(rmse_baseline_wage))
# Out:
# Baseline MAE is 10533.13
# Baseline RMSE is 23076.73

# %%
best_score_wage = mae_baseline_wage
best_params_wage = {}
for i, grid_search_wage in enumerate(params_perms):
    print("Permutation number:", i+1)
    cv_results_wage = xgb.cv(grid_search_wage,
                        dtrain_wage,
                        num_boost_round=num_boost_round,
                        seed=42,
                        nfold=2,
                        metrics=['mae', 'rmse'],
                        early_stopping_rounds=early_stopping_rounds
                        )
    
    mean_mae_wage = cv_results_wage['test-mae-mean'].min()
    boost_rounds_wage = cv_results_wage['test-mae-mean'].argmin()
    print("\tMAE {} for {} rounds".format(mean_mae_wage, boost_rounds_wage))
    if mean_mae_wage < best_score_wage:
        best_score_wage = mean_mae_wage
        best_params_wage = grid_search_wage
# Out:
# Permutation number: 1
# [12:56:32] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [12:56:32] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 4531.0183105 for 231 rounds
# Permutation number: 2
# [12:57:25] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [12:57:25] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 4492.954834 for 242 rounds
# Permutation number: 3
# [12:58:35] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [12:58:35] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 4538.6750485 for 244 rounds
# Permutation number: 4
# [12:59:50] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [12:59:50] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 4512.965087500001 for 241 rounds
# Permutation number: 5
# [13:01:39] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [13:01:40] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 4550.8369139999995 for 230 rounds
# Permutation number: 6
# [13:02:39] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [13:02:39] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 4553.693847500001 for 235 rounds
# Permutation number: 7
# [13:04:24] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [13:04:24] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 4577.630127 for 225 rounds
# Permutation number: 8
# [13:05:16] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [13:05:16] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 4611.882324 for 243 rounds
# Permutation number: 9
# [13:06:49] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [13:06:50] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 4531.0183105 for 231 rounds
# Permutation number: 10
# [13:08:47] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [13:08:47] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 4492.954834 for 242 rounds
# Permutation number: 11
# [13:10:21] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [13:10:21] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 4538.6750485 for 244 rounds
# Permutation number: 12
# [13:11:44] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [13:11:44] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 4512.965087500001 for 241 rounds
# Permutation number: 13
# [13:13:35] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [13:13:35] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 4550.8369139999995 for 230 rounds
# Permutation number: 14
# [13:14:30] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [13:14:30] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 4553.693847500001 for 235 rounds
# Permutation number: 15
# [13:16:42] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [13:16:42] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 4577.630127 for 225 rounds
# Permutation number: 16
# [13:17:40] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [13:17:40] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 4611.882324 for 243 rounds
# Permutation number: 17
# [13:19:09] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [13:19:09] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 4587.311767499999 for 21 rounds
# Permutation number: 18
# [13:19:17] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [13:19:17] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 4580.7365725 for 21 rounds
# Permutation number: 19
# [13:19:26] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [13:19:26] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 4588.225097500001 for 20 rounds
# Permutation number: 20
# [13:19:33] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [13:19:33] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 4558.8847655 for 21 rounds
# Permutation number: 21
# [13:19:42] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [13:19:42] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 4576.7792965 for 21 rounds
# Permutation number: 22
# [13:19:47] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [13:19:47] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 4604.1154785 for 22 rounds
# Permutation number: 23
# [13:20:00] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [13:20:00] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 4577.5800785 for 20 rounds
# Permutation number: 24
# [13:20:07] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [13:20:07] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 4638.693115 for 21 rounds
# Permutation number: 25
# [13:20:21] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [13:20:21] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 4587.311767499999 for 21 rounds
# Permutation number: 26
# [13:20:28] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [13:20:29] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 4580.7365725 for 21 rounds
# Permutation number: 27
# [13:20:36] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [13:20:37] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 4588.225097500001 for 20 rounds
# Permutation number: 28
# [13:20:43] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [13:20:43] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 4558.8847655 for 21 rounds
# Permutation number: 29
# [13:20:53] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [13:20:53] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 4576.7792965 for 21 rounds
# Permutation number: 30
# [13:20:58] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [13:20:58] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 4604.1154785 for 22 rounds
# Permutation number: 31
# [13:21:11] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [13:21:11] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 4577.5800785 for 20 rounds
# Permutation number: 32
# [13:21:20] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [13:21:20] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 4638.693115 for 21 rounds

# %%
#Retrain a model with new best params
model_wage = xgb.train(
    best_params_wage,
    dtrain_wage,
    num_boost_round=num_boost_round,
    evals=evaluation_set_wage,
    early_stopping_rounds=early_stopping_rounds
)
# Out:
# [13:21:33] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	Test_set-rmse:24856.2	Test_set-mae:9631.28
# Multiple eval metrics have been passed: 'Test_set-mae' will be used for early stopping.
#
# Will train until Test_set-mae hasn't improved in 10 rounds.
# [1]	Test_set-rmse:24675.1	Test_set-mae:9542.53
# [2]	Test_set-rmse:24501.4	Test_set-mae:9455.82
# [3]	Test_set-rmse:24344.5	Test_set-mae:9371.04
# [4]	Test_set-rmse:24163.5	Test_set-mae:9286.04
# [5]	Test_set-rmse:24000.6	Test_set-mae:9202.96
# [6]	Test_set-rmse:23839.1	Test_set-mae:9123.38
# [7]	Test_set-rmse:23680.2	Test_set-mae:9044.15
# [8]	Test_set-rmse:23503.4	Test_set-mae:8962.48
# [9]	Test_set-rmse:23377.4	Test_set-mae:8887.78
# [10]	Test_set-rmse:23232.8	Test_set-mae:8812.11
# [11]	Test_set-rmse:23081.7	Test_set-mae:8735.72
# [12]	Test_set-rmse:22925.7	Test_set-mae:8660.22
# [13]	Test_set-rmse:22775.5	Test_set-mae:8584.41
# [14]	Test_set-rmse:22637.3	Test_set-mae:8512.92
# [15]	Test_set-rmse:22493.1	Test_set-mae:8440.17
# [16]	Test_set-rmse:22338.2	Test_set-mae:8366.37
# [17]	Test_set-rmse:22186.9	Test_set-mae:8294.37
# [18]	Test_set-rmse:22045.8	Test_set-mae:8223.92
# [19]	Test_set-rmse:21873.4	Test_set-mae:8149.83
# [20]	Test_set-rmse:21751.2	Test_set-mae:8080.81
# [21]	Test_set-rmse:21607.7	Test_set-mae:8011.58
# [22]	Test_set-rmse:21458.7	Test_set-mae:7943.95
# [23]	Test_set-rmse:21332.7	Test_set-mae:7876.13
# [24]	Test_set-rmse:21201.7	Test_set-mae:7810.61
# [25]	Test_set-rmse:21060.1	Test_set-mae:7744.09
# [26]	Test_set-rmse:20939.8	Test_set-mae:7681.47
# [27]	Test_set-rmse:20795.4	Test_set-mae:7615.88
# [28]	Test_set-rmse:20678.8	Test_set-mae:7553.72
# [29]	Test_set-rmse:20542.8	Test_set-mae:7490.42
# [30]	Test_set-rmse:20429.3	Test_set-mae:7428.88
# [31]	Test_set-rmse:20290	Test_set-mae:7367.5
# [32]	Test_set-rmse:20157.9	Test_set-mae:7306.48
# [33]	Test_set-rmse:20016.8	Test_set-mae:7245.85
# [34]	Test_set-rmse:19884.2	Test_set-mae:7186.55
# [35]	Test_set-rmse:19750.4	Test_set-mae:7129.2
# [36]	Test_set-rmse:19632.4	Test_set-mae:7072.64
# [37]	Test_set-rmse:19506.5	Test_set-mae:7015.12
# [38]	Test_set-rmse:19391.8	Test_set-mae:6959.53
# [39]	Test_set-rmse:19296.6	Test_set-mae:6906.31
# [40]	Test_set-rmse:19168.4	Test_set-mae:6850.51
# [41]	Test_set-rmse:19050.4	Test_set-mae:6797.07
# [42]	Test_set-rmse:18933.5	Test_set-mae:6743.4
# [43]	Test_set-rmse:18812.2	Test_set-mae:6691.72
# [44]	Test_set-rmse:18701.9	Test_set-mae:6640.23
# [45]	Test_set-rmse:18608	Test_set-mae:6591.26
# [46]	Test_set-rmse:18494.7	Test_set-mae:6540.33
# [47]	Test_set-rmse:18374.4	Test_set-mae:6491.98
# [48]	Test_set-rmse:18266.8	Test_set-mae:6444.81
# [49]	Test_set-rmse:18157.1	Test_set-mae:6398.71
# [50]	Test_set-rmse:18040.9	Test_set-mae:6353.08
# [51]	Test_set-rmse:17936	Test_set-mae:6308.88
# [52]	Test_set-rmse:17831.8	Test_set-mae:6265.97
# [53]	Test_set-rmse:17736.2	Test_set-mae:6222.67
# [54]	Test_set-rmse:17635.4	Test_set-mae:6180.02
# [55]	Test_set-rmse:17530	Test_set-mae:6137.25
# [56]	Test_set-rmse:17441.7	Test_set-mae:6097.12
# [57]	Test_set-rmse:17340.2	Test_set-mae:6055.8
# [58]	Test_set-rmse:17234.5	Test_set-mae:6015.34
# [59]	Test_set-rmse:17145.5	Test_set-mae:5977.51
# [60]	Test_set-rmse:17065.7	Test_set-mae:5942.51
# [61]	Test_set-rmse:16972.8	Test_set-mae:5905.62
# [62]	Test_set-rmse:16894.8	Test_set-mae:5870.09
# [63]	Test_set-rmse:16833.8	Test_set-mae:5837.43
# [64]	Test_set-rmse:16730.2	Test_set-mae:5801.12
# [65]	Test_set-rmse:16635.7	Test_set-mae:5766.95
# [66]	Test_set-rmse:16552.7	Test_set-mae:5733.14
# [67]	Test_set-rmse:16492.4	Test_set-mae:5701.95
# [68]	Test_set-rmse:16422.1	Test_set-mae:5670.49
# [69]	Test_set-rmse:16330.9	Test_set-mae:5638.58
# [70]	Test_set-rmse:16237.3	Test_set-mae:5607.12
# [71]	Test_set-rmse:16141.9	Test_set-mae:5574.04
# [72]	Test_set-rmse:16068.6	Test_set-mae:5543.1
# [73]	Test_set-rmse:16008.5	Test_set-mae:5515.32
# [74]	Test_set-rmse:15934.7	Test_set-mae:5486.48
# [75]	Test_set-rmse:15862.4	Test_set-mae:5458.25
# [76]	Test_set-rmse:15776.7	Test_set-mae:5430.03
# [77]	Test_set-rmse:15714.2	Test_set-mae:5403.49
# [78]	Test_set-rmse:15644.2	Test_set-mae:5377.58
# [79]	Test_set-rmse:15582	Test_set-mae:5352.04
# [80]	Test_set-rmse:15512.7	Test_set-mae:5327.8
# [81]	Test_set-rmse:15447	Test_set-mae:5302.62
# [82]	Test_set-rmse:15367.4	Test_set-mae:5277.26
# [83]	Test_set-rmse:15303.1	Test_set-mae:5253.76
# [84]	Test_set-rmse:15223.1	Test_set-mae:5229.4
# [85]	Test_set-rmse:15147.5	Test_set-mae:5205.44
# [86]	Test_set-rmse:15077.4	Test_set-mae:5182.11
# [87]	Test_set-rmse:15001.4	Test_set-mae:5158.21
# [88]	Test_set-rmse:14940	Test_set-mae:5135.83
# [89]	Test_set-rmse:14885.9	Test_set-mae:5114.82
# [90]	Test_set-rmse:14826.2	Test_set-mae:5093.63
# [91]	Test_set-rmse:14777.4	Test_set-mae:5074.55
# [92]	Test_set-rmse:14719.9	Test_set-mae:5054.91
# [93]	Test_set-rmse:14653.9	Test_set-mae:5034.39
# [94]	Test_set-rmse:14605.2	Test_set-mae:5016.71
# [95]	Test_set-rmse:14538.8	Test_set-mae:4997.56
# [96]	Test_set-rmse:14477.8	Test_set-mae:4978.34
# [97]	Test_set-rmse:14410.9	Test_set-mae:4957.79
# [98]	Test_set-rmse:14355	Test_set-mae:4940.38
# [99]	Test_set-rmse:14291.3	Test_set-mae:4922.97
# [100]	Test_set-rmse:14238.9	Test_set-mae:4906.41
# [101]	Test_set-rmse:14180.7	Test_set-mae:4890.41
# [102]	Test_set-rmse:14115.5	Test_set-mae:4873.79
# [103]	Test_set-rmse:14057.6	Test_set-mae:4856.54
# [104]	Test_set-rmse:14012.2	Test_set-mae:4841.5
# [105]	Test_set-rmse:13959.2	Test_set-mae:4827.05
# [106]	Test_set-rmse:13908.8	Test_set-mae:4811.82
# [107]	Test_set-rmse:13869.1	Test_set-mae:4798.73
# [108]	Test_set-rmse:13826.4	Test_set-mae:4785.68
# [109]	Test_set-rmse:13780.1	Test_set-mae:4771.74
# [110]	Test_set-rmse:13724.5	Test_set-mae:4758.03
# [111]	Test_set-rmse:13674.6	Test_set-mae:4744.92
# [112]	Test_set-rmse:13626.8	Test_set-mae:4732.37
# [113]	Test_set-rmse:13577.3	Test_set-mae:4720.53
# [114]	Test_set-rmse:13523.4	Test_set-mae:4707.31
# [115]	Test_set-rmse:13479.8	Test_set-mae:4695.59
# [116]	Test_set-rmse:13430.9	Test_set-mae:4683.54
# [117]	Test_set-rmse:13389.8	Test_set-mae:4672.81
# [118]	Test_set-rmse:13341.5	Test_set-mae:4660.63
# [119]	Test_set-rmse:13295.5	Test_set-mae:4649.5
# [120]	Test_set-rmse:13250	Test_set-mae:4638.77
# [121]	Test_set-rmse:13201.8	Test_set-mae:4628.16
# [122]	Test_set-rmse:13153.3	Test_set-mae:4616.85
# [123]	Test_set-rmse:13119	Test_set-mae:4607.66
# [124]	Test_set-rmse:13071.8	Test_set-mae:4597.54
# [125]	Test_set-rmse:13035.3	Test_set-mae:4587.45
# [126]	Test_set-rmse:12987.6	Test_set-mae:4575.81
# [127]	Test_set-rmse:12941.2	Test_set-mae:4565.53
# [128]	Test_set-rmse:12892.8	Test_set-mae:4555.12
# [129]	Test_set-rmse:12844.8	Test_set-mae:4545.23
# [130]	Test_set-rmse:12807.8	Test_set-mae:4536.43
# [131]	Test_set-rmse:12771.2	Test_set-mae:4528.11
# [132]	Test_set-rmse:12736.3	Test_set-mae:4518.61
# [133]	Test_set-rmse:12707.3	Test_set-mae:4511.1
# [134]	Test_set-rmse:12670.8	Test_set-mae:4502.82
# [135]	Test_set-rmse:12636.7	Test_set-mae:4495.16
# [136]	Test_set-rmse:12606.2	Test_set-mae:4487.81
# [137]	Test_set-rmse:12572	Test_set-mae:4480.88
# [138]	Test_set-rmse:12542.4	Test_set-mae:4474.32
# [139]	Test_set-rmse:12503.3	Test_set-mae:4467.15
# [140]	Test_set-rmse:12481.9	Test_set-mae:4462.17
# [141]	Test_set-rmse:12446.9	Test_set-mae:4456.03
# [142]	Test_set-rmse:12411.2	Test_set-mae:4449.2
# [143]	Test_set-rmse:12377.4	Test_set-mae:4442.17
# [144]	Test_set-rmse:12351.4	Test_set-mae:4436.64
# [145]	Test_set-rmse:12307.4	Test_set-mae:4429.04
# [146]	Test_set-rmse:12272.8	Test_set-mae:4422.49
# [147]	Test_set-rmse:12249.5	Test_set-mae:4416.91
# [148]	Test_set-rmse:12223.5	Test_set-mae:4411.38
# [149]	Test_set-rmse:12189.9	Test_set-mae:4405.56
# [150]	Test_set-rmse:12163.7	Test_set-mae:4399.48
# [151]	Test_set-rmse:12144.4	Test_set-mae:4395.65
# [152]	Test_set-rmse:12107.6	Test_set-mae:4389.82
# [153]	Test_set-rmse:12078.8	Test_set-mae:4384.84
# [154]	Test_set-rmse:12055.6	Test_set-mae:4379.7
# [155]	Test_set-rmse:12022.7	Test_set-mae:4374.97
# [156]	Test_set-rmse:11997.9	Test_set-mae:4370.06
# [157]	Test_set-rmse:11967.3	Test_set-mae:4365.27
# [158]	Test_set-rmse:11942.3	Test_set-mae:4361.06
# [159]	Test_set-rmse:11915.5	Test_set-mae:4357.52
# [160]	Test_set-rmse:11888.1	Test_set-mae:4353.5
# [161]	Test_set-rmse:11857.9	Test_set-mae:4349.2
# [162]	Test_set-rmse:11829.6	Test_set-mae:4345.58
# [163]	Test_set-rmse:11805.2	Test_set-mae:4341.19
# [164]	Test_set-rmse:11778.5	Test_set-mae:4338.08
# [165]	Test_set-rmse:11754.8	Test_set-mae:4334.66
# [166]	Test_set-rmse:11726.6	Test_set-mae:4331.36
# [167]	Test_set-rmse:11696.9	Test_set-mae:4326.99
# [168]	Test_set-rmse:11671.4	Test_set-mae:4324.29
# [169]	Test_set-rmse:11645.3	Test_set-mae:4320.54
# [170]	Test_set-rmse:11618.1	Test_set-mae:4316.69
# [171]	Test_set-rmse:11590.9	Test_set-mae:4313.63
# [172]	Test_set-rmse:11565.6	Test_set-mae:4310.23
# [173]	Test_set-rmse:11541.8	Test_set-mae:4306.68
# [174]	Test_set-rmse:11518.3	Test_set-mae:4303.95
# [175]	Test_set-rmse:11491.2	Test_set-mae:4300.35
# [176]	Test_set-rmse:11470.4	Test_set-mae:4297.41
# [177]	Test_set-rmse:11452.4	Test_set-mae:4294.53
# [178]	Test_set-rmse:11438.9	Test_set-mae:4293.31
# [179]	Test_set-rmse:11420.9	Test_set-mae:4290.06
# [180]	Test_set-rmse:11395.7	Test_set-mae:4287.35
# [181]	Test_set-rmse:11376.1	Test_set-mae:4284.81
# [182]	Test_set-rmse:11357.9	Test_set-mae:4283.12
# [183]	Test_set-rmse:11337.3	Test_set-mae:4281.57
# [184]	Test_set-rmse:11313.9	Test_set-mae:4278.61
# [185]	Test_set-rmse:11292	Test_set-mae:4276.21
# [186]	Test_set-rmse:11276	Test_set-mae:4273.62
# [187]	Test_set-rmse:11258.8	Test_set-mae:4271.68
# [188]	Test_set-rmse:11235.6	Test_set-mae:4270.04
# [189]	Test_set-rmse:11218.4	Test_set-mae:4267.96
# [190]	Test_set-rmse:11199.1	Test_set-mae:4265.33
# [191]	Test_set-rmse:11183.9	Test_set-mae:4263.66
# [192]	Test_set-rmse:11161.1	Test_set-mae:4261.88
# [193]	Test_set-rmse:11141.8	Test_set-mae:4260.39
# [194]	Test_set-rmse:11126.7	Test_set-mae:4258.66
# [195]	Test_set-rmse:11112.9	Test_set-mae:4256.98
# [196]	Test_set-rmse:11091	Test_set-mae:4254.99
# [197]	Test_set-rmse:11079.9	Test_set-mae:4253.51
# [198]	Test_set-rmse:11067.9	Test_set-mae:4252.38
# [199]	Test_set-rmse:11048.4	Test_set-mae:4250.36
# [200]	Test_set-rmse:11027.5	Test_set-mae:4248.09
# [201]	Test_set-rmse:11007.5	Test_set-mae:4246.39
# [202]	Test_set-rmse:10986.7	Test_set-mae:4245.05
# [203]	Test_set-rmse:10970.2	Test_set-mae:4243.34
# [204]	Test_set-rmse:10952	Test_set-mae:4241.5
# [205]	Test_set-rmse:10936.1	Test_set-mae:4239.28
# [206]	Test_set-rmse:10923.5	Test_set-mae:4237.81
# [207]	Test_set-rmse:10910.6	Test_set-mae:4236.8
# [208]	Test_set-rmse:10895.3	Test_set-mae:4234.96
# [209]	Test_set-rmse:10879.1	Test_set-mae:4233.98
# [210]	Test_set-rmse:10862.3	Test_set-mae:4232.13
# [211]	Test_set-rmse:10850.2	Test_set-mae:4231.18
# [212]	Test_set-rmse:10841	Test_set-mae:4230.38
# [213]	Test_set-rmse:10827.3	Test_set-mae:4229.54
# [214]	Test_set-rmse:10820.3	Test_set-mae:4229.39
# [215]	Test_set-rmse:10809.4	Test_set-mae:4228.39
# [216]	Test_set-rmse:10792.9	Test_set-mae:4226.86
# [217]	Test_set-rmse:10784.1	Test_set-mae:4226.03
# [218]	Test_set-rmse:10773.6	Test_set-mae:4225.16
# [219]	Test_set-rmse:10756.1	Test_set-mae:4223.95
# [220]	Test_set-rmse:10746.1	Test_set-mae:4223.58
# [221]	Test_set-rmse:10736.9	Test_set-mae:4223.14
# [222]	Test_set-rmse:10728.5	Test_set-mae:4223.04
# [223]	Test_set-rmse:10714.6	Test_set-mae:4222.07
# [224]	Test_set-rmse:10700.6	Test_set-mae:4221.19
# [225]	Test_set-rmse:10692.7	Test_set-mae:4220.8
# [226]	Test_set-rmse:10683.6	Test_set-mae:4220.35
# [227]	Test_set-rmse:10673.1	Test_set-mae:4219.39
# [228]	Test_set-rmse:10657.9	Test_set-mae:4218.92
# [229]	Test_set-rmse:10649.1	Test_set-mae:4218.12
# [230]	Test_set-rmse:10631.1	Test_set-mae:4216.28
# [231]	Test_set-rmse:10625.3	Test_set-mae:4215.66
# [232]	Test_set-rmse:10608.5	Test_set-mae:4214.77
# [233]	Test_set-rmse:10601.7	Test_set-mae:4214.52
# [234]	Test_set-rmse:10590.5	Test_set-mae:4213.93
# [235]	Test_set-rmse:10585.2	Test_set-mae:4214.26
# [236]	Test_set-rmse:10571.9	Test_set-mae:4213.8
# [237]	Test_set-rmse:10558.9	Test_set-mae:4213.24
# [238]	Test_set-rmse:10551.8	Test_set-mae:4213.75
# [239]	Test_set-rmse:10545.8	Test_set-mae:4213.38
# [240]	Test_set-rmse:10540.3	Test_set-mae:4213.5
# [241]	Test_set-rmse:10529.8	Test_set-mae:4212.68
# [242]	Test_set-rmse:10524.8	Test_set-mae:4212.78
# [243]	Test_set-rmse:10515.9	Test_set-mae:4212.24
# [244]	Test_set-rmse:10503.1	Test_set-mae:4211.5
# [245]	Test_set-rmse:10496.7	Test_set-mae:4211.03
# [246]	Test_set-rmse:10491.4	Test_set-mae:4211.03
# [247]	Test_set-rmse:10480.3	Test_set-mae:4209.83
# [248]	Test_set-rmse:10470.1	Test_set-mae:4209.3
# [249]	Test_set-rmse:10464.8	Test_set-mae:4209.21
# [250]	Test_set-rmse:10455.6	Test_set-mae:4208.3
# [251]	Test_set-rmse:10447.4	Test_set-mae:4207.8
# [252]	Test_set-rmse:10438.6	Test_set-mae:4207.06
# [253]	Test_set-rmse:10429.4	Test_set-mae:4206.53
# [254]	Test_set-rmse:10422.2	Test_set-mae:4205.65
# [255]	Test_set-rmse:10414.2	Test_set-mae:4205.2
# [256]	Test_set-rmse:10405.5	Test_set-mae:4204.26
# [257]	Test_set-rmse:10395.7	Test_set-mae:4203.29
# [258]	Test_set-rmse:10389	Test_set-mae:4203.27
# [259]	Test_set-rmse:10381.4	Test_set-mae:4203.18
# [260]	Test_set-rmse:10373.2	Test_set-mae:4202.78
# [261]	Test_set-rmse:10369.3	Test_set-mae:4203.13
# [262]	Test_set-rmse:10361.2	Test_set-mae:4203.08
# [263]	Test_set-rmse:10353.9	Test_set-mae:4203
# [264]	Test_set-rmse:10348.3	Test_set-mae:4203.3
# [265]	Test_set-rmse:10343	Test_set-mae:4203.22
# [266]	Test_set-rmse:10336.8	Test_set-mae:4203.01
# [267]	Test_set-rmse:10330.6	Test_set-mae:4203.17
# [268]	Test_set-rmse:10324.4	Test_set-mae:4203.08
# [269]	Test_set-rmse:10315.6	Test_set-mae:4202.9
# [270]	Test_set-rmse:10308.4	Test_set-mae:4203.02
# Stopping. Best iteration:
# [260]	Test_set-rmse:10373.2	Test_set-mae:4202.78

# %%
print("Average guess error", mae_baseline_wage)
print("vs Mean Absolute Error", mean_absolute_error(model_wage.predict(dtest_wage), y_test_wage))
# Out:
# Average guess error 10533.127228148242
# vs Mean Absolute Error 4203.012834644265

# %%
#Feature Importance
plt.figure(figsize=(20,15))
xgb.plot_importance(model_wage, ax=plt.gca())

# %%
#Predict the value based on the model.
dpred_wage = xgb.DMatrix(fifasup_mach, label = y_wage)
y_pred_wage = pd.Series(model_wage.predict(dpred_wage))

# %%
#Top 10% players with overpriced wages.
sub_wage = y_value.subtract(y_pred_wage)
exp_wage = fifasup_mach.loc[sub_wage.nlargest(int(len(sub_wage)/1000)).index]
exp_wage
# Out:
#     Age  Height(cm)  Weight(kgs)  Weak Foot  Inter_Rep  Overall  Potential  \
# 2    26  179.823225    68.053800        5.0        5.0       92         93
# 0    31  173.727522    72.137028        4.0        5.0       94         94
# 4    27  155.745200    69.868568        5.0        4.0       91         92
# 5    27  176.775373    73.951796        4.0        4.0       91         91
# 15   24  155.440415    74.859180        3.0        3.0       89         94
# 16   24  188.966778    88.923632        4.0        3.0       89         91
# 25   19  155.440415    73.044412        4.0        3.0       88         95
# 7    31  182.871076    86.201480        4.0        5.0       91         91
# 17   27  179.823225    73.044412        3.0        4.0       89         90
# 10   29  182.871076    79.849792        4.0        4.0       90         90
# 1    33  188.966778    83.025636        4.0        5.0       94         94
# 11   28  182.871076    76.220256        5.0        4.0       90         90
# 31   26  155.745200    76.220256        5.0        3.0       88         91
# 30   26  179.823225    78.942408        3.0        3.0       88         91
# 3    27  195.062481    76.220256        3.0        4.0       91         93
# 28   26  155.745200    78.035024        3.0        4.0       88         89
# 26   26  179.823225    71.229644        3.0        3.0       88         89
# 32   26  176.775373    68.053800        4.0        3.0       88         89
#
#     Difference  Release_Clause(€M)  Special  ...  LDM  CDM  RDM  RWB  LB  LCB  \
# 2            1         228100000.0     2143  ...   60   60   60   65  60   47
# 0            0         226500000.0     2202  ...   61   61   61   64  59   47
# 4            1         196400000.0     2281  ...   77   77   77   77  73   66
# 5            0         172100000.0     2142  ...   63   63   63   66  60   49
# 15           5         153500000.0     2092  ...   58   58   58   62  56   45
# 16           2         160700000.0     2165  ...   66   66   66   65  62   60
# 25           7         166100000.0     2118  ...   62   62   62   66  62   54
# 7            0         164000000.0     2346  ...   68   68   68   69  66   63
# 17           1         165800000.0     2246  ...   67   67   67   70  67   61
# 10           0         127100000.0     2152  ...   62   62   62   61  58   57
# 1            0         127100000.0     2228  ...   61   61   61   65  61   53
# 11           0         156800000.0     2190  ...   82   82   82   79  77   72
# 31           3         141500000.0     2117  ...   71   71   71   71  66   57
# 30           3         156200000.0     2137  ...   73   73   73   72  68   63
# 3            2         138600000.0     1471  ...   50   50   50   50  50   50
# 28           1            200000.0     2171  ...   68   68   68   69  65   58
# 26           1         137300000.0     2146  ...   66   66   66   70  66   57
# 32           1         147700000.0     2175  ...   70   70   70   71  67   58
#
#     CB  RCB  RB  Versatility
# 2   47   47  60            1
# 0   47   47  59            1
# 4   66   66  73            1
# 5   49   49  60            1
# 15  45   45  56            1
# 16  60   60  62            1
# 25  54   54  62            1
# 7   63   63  66            1
# 17  61   61  67            1
# 10  57   57  58            1
# 1   53   53  61            1
# 11  72   72  77            1
# 31  57   57  66            1
# 30  63   63  68            1
# 3   50   50  50            1
# 28  58   58  65            1
# 26  57   57  66            1
# 32  58   58  67            1
#
# [18 rows x 72 columns]

# %%
#Top 10% players with underpriced transfer values.
cheap_wage = sub_wage.nsmallest(int(len(sub_wage)/1000))
cheap_wage = fifasup_mach.loc[cheap_wage.index]
cheap_wage
# Out:
#       Age  Height(cm)  Weight(kgs)  Weak Foot  Inter_Rep  Overall  Potential  \
# 452    24  155.745200    74.859180        4.0        2.0       80         85
# 874    29  198.110332    91.192092        3.0        2.0       78         78
# 1936   26  188.966778    81.210868        3.0        1.0       75         75
# 864    40  155.745200    78.035024        3.0        2.0       78         78
# 2399   26  155.440415    74.859180        4.0        1.0       74         74
# 2999   28  182.871076    79.849792        3.0        2.0       73         73
# 1008   29  155.745200    79.849792        3.0        2.0       77         77
# 3208   27  185.918927    86.201480        4.0        1.0       73         74
# 1902   26  170.679671    60.794728        4.0        1.0       75         75
# 4667   23  185.918927    78.035024        3.0        1.0       71         78
# 1671   33  185.918927    82.118252        3.0        1.0       75         75
# 3170   24  188.966778    74.859180        3.0        1.0       73         78
# 4121   30  179.823225    63.970572        3.0        1.0       71         71
# 997    25  182.871076    73.951796        3.0        1.0       77         80
# 538    33  195.062481    83.933020        4.0        2.0       80         80
# 2443   23  173.727522    64.877956        5.0        1.0       74         80
# 677    29  155.440415    69.868568        3.0        2.0       79         79
# 1964   26  182.871076    78.942408        3.0        1.0       75         78
#
#       Difference  Release_Clause(€M)  Special  ...  LDM  CDM  RDM  RWB  LB  \
# 452            5            200000.0     2122  ...   77   77   77   75  74
# 874            0            200000.0     1810  ...   52   52   52   52  48
# 1936           0            200000.0     1877  ...   57   57   57   59  57
# 864            0            200000.0     1807  ...   73   73   73   67  68
# 2399           0            200000.0     1938  ...   55   55   55   59  56
# 2999           0            200000.0     2030  ...   71   71   71   72  71
# 1008           0            200000.0     1933  ...   52   52   52   53  50
# 3208           1            200000.0     1893  ...   55   55   55   59  56
# 1902           0            200000.0     1849  ...   57   57   57   60  57
# 4667           7            200000.0     1805  ...   59   59   59   59  57
# 1671           0            200000.0     2012  ...   73   73   73   71  71
# 3170           5            200000.0     1732  ...   67   67   67   64  67
# 4121           0            200000.0     1744  ...   49   49   49   51  46
# 997            3            200000.0     2041  ...   75   75   75   75  74
# 538            0            200000.0     1797  ...   74   74   74   68  70
# 2443           6            200000.0     1728  ...   49   49   49   54  50
# 677            0            200000.0     2038  ...   75   75   75   78  78
# 1964           3            200000.0     1868  ...   60   60   60   62  58
#
#       LCB  CB  RCB  RB  Versatility
# 452    72  72   72  74            1
# 874    48  48   48  48            1
# 1936   52  52   52  57            1
# 864    76  76   76  68            1
# 2399   48  48   48  56            1
# 2999   69  69   69  71            1
# 1008   46  46   46  50            1
# 3208   53  53   53  56            1
# 1902   48  48   48  57            1
# 4667   53  53   53  57            1
# 1671   75  75   75  71            1
# 3170   72  72   72  67            1
# 4121   37  37   37  46            1
# 997    70  70   70  74            1
# 538    79  79   79  70            1
# 2443   38  38   38  50            1
# 677    73  73   73  78            1
# 1964   51  51   51  58            1
#
# [18 rows x 72 columns]

# %%
model_wage.save_model("model_wage.model")
