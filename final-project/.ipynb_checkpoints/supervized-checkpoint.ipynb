# %%
# !pip3 install xgboost
# Out:
# Requirement already satisfied: xgboost in /usr/local/lib/python3.7/site-packages (0.90)
# Requirement already satisfied: numpy in /Users/macos/Library/Python/3.7/lib/python/site-packages (from xgboost) (1.17.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/site-packages (from xgboost) (1.3.1)

# %%
pip install xgboost
# Out:
# Requirement already satisfied: xgboost in /usr/local/Cellar/jupyterlab/1.2.3/libexec/lib/python3.7/site-packages (0.90)
# Requirement already satisfied: scipy in /usr/local/Cellar/jupyterlab/1.2.3/libexec/lib/python3.7/site-packages (from xgboost) (1.3.3)
# Requirement already satisfied: numpy in /usr/local/Cellar/jupyterlab/1.2.3/libexec/lib/python3.7/site-packages (from xgboost) (1.17.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install graphviz
# Out:
# Collecting graphviz
#   Downloading https://files.pythonhosted.org/packages/f5/74/dbed754c0abd63768d3a7a7b472da35b08ac442cf87d73d5850a6f32391e/graphviz-0.13.2-py2.py3-none-any.whl
# Installing collected packages: graphviz
# Successfully installed graphviz-0.13.2
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # IMPORTANDO LIBRERÍAS

# %%
import warnings
warnings.filterwarnings('ignore')

import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns
#import plotly.plotly as py

from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error, mean_squared_error
import xgboost as xgb

from itertools import product
import itertools
from collections import OrderedDict
import operator
import re
from math import sqrt
import pickle

# %% [markdown]
# # DATAFRAME

# %%
fifasup=pd.read_csv('prediction.csv')
fifasup.head()
# Out:
#        ID               Name Position  Age  Height(cm)  Weight(kgs)  \
# 0  158023           L. Messi       RF   31  173.727522    72.137028
# 1   20801  Cristiano Ronaldo       ST   33  188.966778    83.025636
# 2  190871          Neymar Jr       LW   26  179.823225    68.053800
# 3  193080             De Gea       GK   27  195.062481    76.220256
# 4  192985       K. De Bruyne      RCM   27  155.745200    69.868568
#
#   Preferred Foot  Weak Foot Nationality Continent  ...  LWB LDM CDM  RDM  RWB  \
# 0           Left        4.0   Argentina   America  ...   64  61  61   61   64
# 1          Right        4.0    Portugal    Europe  ...   65  61  61   61   65
# 2          Right        5.0      Brazil   America  ...   65  60  60   60   65
# 3          Right        3.0       Spain    Europe  ...   50  50  50   50   50
# 4          Right        5.0     Belgium    Europe  ...   77  77  77   77   77
#
#    LB  LCB  CB  RCB  RB
# 0  59   47  47   47  59
# 1  61   53  53   53  61
# 2  60   47  47   47  60
# 3  50   50  50   50  50
# 4  73   66  66   66  73
#
# [5 rows x 90 columns]

# %% [markdown]
# # AGRUPACIÓN DE DATOS

# %%
#Player value per position
positions = {
    'Forward' : ['CF', 'LF', 'LS', 'LW', 'RF', 'RS', 'RW', 'ST'],
    'Midfield' : ['CAM', 'CDM', 'CM', 'LAM', 'LCM', 'LDM', 'LM', 'RAM', 'RCB', 'RCM', 'RDM', 'RM'],
    'Defense' : ['CB', 'LB', 'LCB', 'LWB', 'RB', 'RCB', 'RWB'],
    'Goalkeeper' : ['GK'],
}
count_position = {'Forward': 0, 'Midfield': 0, 'Defense': 0, 'Goalkeeper': 0}
players_position = {'Forward': 0, 'Midfield': 0, 'Defense': 0, 'Goalkeeper': 0}
position_avg = {'Forward': 0, 'Midfield': 0, 'Defense': 0, 'Goalkeeper': 0}

def add_values(series):
    already_counted = [0, 0, 0, 0]
    preferred_position_list = re.sub("[^\w]", " ",  series[0]).split() #Split the preferred positions
    value = series[1]

    #Count the players per position category
    index = 0
    for preferred_position in preferred_position_list:
        for position in positions:
            if preferred_position in positions[position]:
                if(not already_counted[index]):
                    count_position[position] += value
                    players_position[position] += 1                    
                    already_counted[index] = 1
                    
position_value = fifasup[['Position', 'Value(€M)']]
position_value.apply(add_values, 1)

#Average the players value per position category
for position in count_position:
    position_avg[position] = count_position[position] / players_position[position]

fig = plt.figure(figsize=(6,4))
ax = fig.add_subplot(111)
ax.bar(range(len(position_avg)), list(position_avg.values()))
plt.xticks(range(len(position_avg)), list(position_avg.keys()))
plt.xlabel('Position')
plt.ylabel('Average value of players')
plt.show()

# %% [markdown]
# Como podemos observar, las posiciones con mayor cantidad de jugadores son **Delanteros** y **Mediocampistas**.

# %% [markdown]
# # MODELOS PREDICTIVOS

# %% [markdown]
# Estableceremos un modelo de machine learning para intentar predecir el **valor de mercado** de una jugadora y el **salario** que debería de recibir con base en sus características individuales.
#
# Es importante mencionar que la **nacionalidad** y el **club** son variables que por sí solas genera una brecha salarial y mercado.

# %%
fifasup_mach = fifasup.copy()
fifasup_mach = fifasup_mach.drop(['Name', 'Nationality', 'Club','Work Rate','Work RAttack',
                                 'Work RDefense','Contract_Expiry','Preferred Foot', 'Joined',
                                 'Evolution', 'Continent', 'year_joined', 'month_joined',
                                 'day_joined', 'Jersey'], axis = 1)
fifasup_mach = fifasup_mach.drop(fifasup_mach.columns[0], axis = 1)

# %%
fifaw_value=pd.read_csv('wdata.csv')
fifaw_value.head()
# Out:
#        ID               Name Position  Age  Height(cm)  Weight(kgs)  \
# 0  190101      Samantha Kerr       ST   26         167           55
# 1  190102      Megan Rapinoe       CM   34         170           60
# 2  190103  Eugénie Le Sommer       ST   30         161           58
# 3  190104      Lieke Martens       CM   26         170           66
# 4  190105        Alex Morgan       ST   40         170           62
#
#   Preferred Foot  Weak Foot  Nationality Continent  ...  LWB LDM CDM  RDM  \
# 0          Right          4    Australia   Oceania  ...   61  74  57   82
# 1          Right          4          USA   America  ...   64  61  61   61
# 2          Right          5       France    Europe  ...    9  95  11   77
# 3          Right          4  Netherlands    Europe  ...   70  67  67   67
# 4           Left          4          USA   America  ...   60  58  58   58
#
#    RWB  LB  LCB  CB  RCB  RB
# 0   26  76   51  57   99  32
# 1   64  59   47  47   47  59
# 2   31  76   28  23   85  64
# 3   70  67   61  61   61  67
# 4   60  57   54  54   54  57
#
# [5 rows x 90 columns]

# %%
fifaw_value = fifaw_value.copy()
fifaw_value = fifaw_value.drop(['Name', 'Nationality', 'Club','Work Rate','Work RAttack',
                                 'Work RDefense','Contract_Expiry','Preferred Foot', 'Joined',
                                 'Evolution', 'Continent', 'year_joined', 'month_joined',
                                 'day_joined', 'Jersey'], axis = 1)
fifaw_value = fifaw_value.drop(fifaw_value.columns[0], axis = 1)

# %%
fifaw_wage=pd.read_csv('wdata.csv')
fifaw_wage.head()
# Out:
#        ID               Name Position  Age  Height(cm)  Weight(kgs)  \
# 0  190101      Samantha Kerr       ST   26         167           55
# 1  190102      Megan Rapinoe       CM   34         170           60
# 2  190103  Eugénie Le Sommer       ST   30         161           58
# 3  190104      Lieke Martens       CM   26         170           66
# 4  190105        Alex Morgan       ST   40         170           62
#
#   Preferred Foot  Weak Foot  Nationality Continent  ...  LWB LDM CDM  RDM  \
# 0          Right          4    Australia   Oceania  ...   61  74  57   82
# 1          Right          4          USA   America  ...   64  61  61   61
# 2          Right          5       France    Europe  ...    9  95  11   77
# 3          Right          4  Netherlands    Europe  ...   70  67  67   67
# 4           Left          4          USA   America  ...   60  58  58   58
#
#    RWB  LB  LCB  CB  RCB  RB
# 0   26  76   51  57   99  32
# 1   64  59   47  47   47  59
# 2   31  76   28  23   85  64
# 3   70  67   61  61   61  67
# 4   60  57   54  54   54  57
#
# [5 rows x 90 columns]

# %%
fifaw_wage = fifaw_wage.copy()
fifaw_wage = fifaw_wage.drop(['Name', 'Nationality', 'Club','Work Rate','Work RAttack',
                                 'Work RDefense','Contract_Expiry','Preferred Foot', 'Joined',
                                 'Evolution', 'Continent', 'year_joined', 'month_joined',
                                 'day_joined', 'Jersey'], axis = 1)
fifaw_wage = fifaw_wage.drop(fifaw_wage.columns[0], axis = 1)

# %%
y_valuew = fifaw_value['Value(€M)'].copy()
fifaw_value = fifaw_value.drop(['Value(€M)', 'Wage(€K)'], axis = 1)

# %%
y_wagew = fifaw_wage['Wage(€K)'].copy()
fifaw_wage = fifaw_wage.drop(['Value(€M)', 'Wage(€K)'], axis = 1)

# %%
y_value = fifasup_mach['Value(€M)'].copy()
y_wage = fifasup_mach['Wage(€K)'].copy()
fifasup_mach = fifasup_mach.drop(['Value(€M)', 'Wage(€K)'], axis = 1)

# %%
def count_positions(position):
    return len(re.sub("[^\w]", " ",  position).split())

# %%
fifasup_mach['Versatility'] = fifasup_mach['Position'].apply(count_positions)
fifasup_mach.head()
# Out:
#   Position  Age  Height(cm)  Weight(kgs)  Weak Foot  Inter_Rep  Overall  \
# 0       RF   31  173.727522    72.137028        4.0        5.0       94
# 1       ST   33  188.966778    83.025636        4.0        5.0       94
# 2       LW   26  179.823225    68.053800        5.0        5.0       92
# 3       GK   27  195.062481    76.220256        3.0        4.0       91
# 4      RCM   27  155.745200    69.868568        5.0        4.0       91
#
#    Potential  Difference  Release_Clause(€M)  ...  LDM  CDM  RDM  RWB  LB  \
# 0         94           0         226500000.0  ...   61   61   61   64  59
# 1         94           0         127100000.0  ...   61   61   61   65  61
# 2         93           1         228100000.0  ...   60   60   60   65  60
# 3         93           2         138600000.0  ...   50   50   50   50  50
# 4         92           1         196400000.0  ...   77   77   77   77  73
#
#    LCB  CB  RCB  RB  Versatility
# 0   47  47   47  59            1
# 1   53  53   53  61            1
# 2   47  47   47  60            1
# 3   50  50   50  50            1
# 4   66  66   66  73            1
#
# [5 rows x 73 columns]

# %%
fifaw_value['Versatility'] = fifaw_value['Position'].apply(count_positions)
fifaw_value.head()
# Out:
#   Position  Age  Height(cm)  Weight(kgs)  Weak Foot  Inter_Rep  Overall  \
# 0       ST   26         167           55          4          4       92
# 1       CM   34         170           60          4          5       92
# 2       ST   30         161           58          5          3       91
# 3       CM   26         170           66          4          4       90
# 4       ST   40         170           62          4          3       90
#
#    Potential  Difference  Release_Clause(€M)  ...  LDM  CDM  RDM  RWB  LB  \
# 0         95           3              200000  ...   74   57   82   26  76
# 1         92           0              200000  ...   61   61   61   64  59
# 2         91           2              200000  ...   95   11   77   31  76
# 3         91           1              200000  ...   67   67   67   70  67
# 4         92           2              200000  ...   58   58   58   60  57
#
#    LCB  CB  RCB  RB  Versatility
# 0   51  57   99  32            1
# 1   47  47   47  59            1
# 2   28  23   85  64            1
# 3   61  61   61  67            1
# 4   54  54   54  57            1
#
# [5 rows x 73 columns]

# %%
fifaw_wage['Versatility'] = fifaw_wage['Position'].apply(count_positions)
fifaw_wage.head()
# Out:
#   Position  Age  Height(cm)  Weight(kgs)  Weak Foot  Inter_Rep  Overall  \
# 0       ST   26         167           55          4          4       92
# 1       CM   34         170           60          4          5       92
# 2       ST   30         161           58          5          3       91
# 3       CM   26         170           66          4          4       90
# 4       ST   40         170           62          4          3       90
#
#    Potential  Difference  Release_Clause(€M)  ...  LDM  CDM  RDM  RWB  LB  \
# 0         95           3              200000  ...   74   57   82   26  76
# 1         92           0              200000  ...   61   61   61   64  59
# 2         91           2              200000  ...   95   11   77   31  76
# 3         91           1              200000  ...   67   67   67   70  67
# 4         92           2              200000  ...   58   58   58   60  57
#
#    LCB  CB  RCB  RB  Versatility
# 0   51  57   99  32            1
# 1   47  47   47  59            1
# 2   28  23   85  64            1
# 3   61  61   61  67            1
# 4   54  54   54  57            1
#
# [5 rows x 73 columns]

# %%
fifasup_mach['Versatility'].unique()
# Out:
# array([1])

# %%
fifasup_mach = fifasup_mach.drop(['Position'], axis = 1)

# %%
fifaw_value = fifaw_value.drop(['Position'], axis = 1)

# %%
fifaw_wage = fifaw_wage.drop(['Position'], axis = 1)

# %% [markdown]
# **Boosting** aplica un proceso iterativo donde en lugar de entrenar a todos los modelos de forma aislada cada nuevo modelo se entrena para corregir los errores cometidos por los anteriores. Es decir, los modelos se van agregando de forma secuencialmente hasta que no se puedan realizar más mejoras.
#
# Empezaremos por crear un train-test-split donde el entrenamiento tome el 80% de los datos y el test el restante 20%.
#
# **XGBoost** requiere que la información se presente de una forma particular denominada **DMatrix**. Es una transformación linear de los datos, pero es requerida.
#
# Los parámetros más simples son **max_depth** (profundidad máxima de los árboles de decisión que se están entrenando), **objective** (la función de pérdida utilizada) y **num_class** (el número de clases en el conjunto de datos). El parámetro **eta** tiene una interpretación especial.
#
#
# **Gradient Boosting** implica crear y agregar árboles de decisión a un modelo de conjunto secuencialmente. Se crean nuevos árboles para corregir los errores residuales en las predicciones del conjunto existente. Tener varios modelos juntos para formar uno muy grande y complicado puede generar que esta técnica sea propensa al **overfitting**. El parámetro **eta** nos permite evitar este problema, ya que se puede considerarlo como una tasa de aprendizaje.
#
# En lugar de simplemente agregar las predicciones de nuevos árboles al conjunto con todo el peso, el eta se multiplicará por los residuos que se agregan para reducir su peso. Esto reduce efectivamente la complejidad del modelo general.
#
# Es común tener valores pequeños en el rango de **0.1 a 0.3**. La menor ponderación de estos residuos todavía nos ayudará a entrenar un modelo poderoso, pero no permitirá que ese modelo se escape a una complejidad profunda donde es más probable que ocurra un **overfitting**.
#
# La información para adaptar mi modelo https://blog.cambridgespark.com/hyperparameter-tuning-in-xgboost-4ff9100a3b2f

# %% [markdown]
# # MODELO 1: Predicción del valor de mercado

# %%
X_train_value, X_test_value, y_train_value, y_test_value = train_test_split(fifasup_mach, y_value, test_size=0.2)

# %%
num_boost_round = 999
early_stopping_rounds = 10

xgb_params = {
                'n_estimators':[500],
                'objective':['reg:linear'],
                'eval_metric':[ ["rmse" ,"mae"]],
                'min_child_weight': [1],
                'eta': [0.01, 0.1], 
                'gamma': [0.05, 0.1],  
                'subsample': [0.8, 1.0],
                'colsample_bytree': [0.8, 1.0],
               'max_depth': [6, 9]
              }

params_perms = [dict(zip(xgb_params, v)) for v in product(*xgb_params.values())]
print(len(params_perms))
print(params_perms[0])
# Out:
# 32
# {'n_estimators': 500, 'objective': 'reg:linear', 'eval_metric': ['rmse', 'mae'], 'min_child_weight': 1, 'eta': 0.01, 'gamma': 0.05, 'subsample': 0.8, 'colsample_bytree': 0.8, 'max_depth': 6}

# %%
dtrain_value = xgb.DMatrix(X_train_value, label=y_train_value)
dtest_value = xgb.DMatrix(X_test_value, label=y_test_value)
evaluation_set_value = [(dtest_value, "Test_set")]

# %%
mean_train_value = np.mean(y_train_value)

baseline_predictions_value = np.ones(y_test_value.shape) * mean_train_value

mae_baseline_value = mean_absolute_error(y_test_value, baseline_predictions_value)

rmse_baseline_value = sqrt(mean_squared_error(y_test_value, baseline_predictions_value))

print("Baseline MAE is {:.2f}".format(mae_baseline_value))
print("Baseline RMSE is {:.2f}".format(rmse_baseline_value))
# Out:
# Baseline MAE is 2821517.32
# Baseline RMSE is 5607631.53

# %%
best_score_value = mae_baseline_value
best_params_value = {}
for i, grid_search_value in enumerate(params_perms):
    print("Permutation number:", i+1)
    cv_results_value = xgb.cv(grid_search_value,
                        dtrain_value,
                       num_boost_round=num_boost_round,
                      seed=42,
                     nfold=2,
                    metrics=['mae', 'rmse'],
                   early_stopping_rounds=early_stopping_rounds
                  )
    
    mean_mae_value = cv_results_value['test-mae-mean'].min()
    boost_rounds_value = cv_results_value['test-mae-mean'].argmin()
    print("\tMAE {} for {} rounds".format(mean_mae_value, boost_rounds_value))
    if mean_mae_value < best_score_value:
        best_score_value = mean_mae_value
        best_params_value = grid_search_value
# Out:
# Permutation number: 1
# [11:43:52] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [11:43:52] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 186659.4921875 for 998 rounds
# Permutation number: 2
# [11:45:35] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [11:45:35] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 177382.5 for 998 rounds
# Permutation number: 3
# [11:47:28] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [11:47:28] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 188971.65625 for 998 rounds
# Permutation number: 4
# [11:49:02] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [11:49:02] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 176179.0078125 for 998 rounds
# Permutation number: 5
# [11:51:12] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [11:51:12] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 192975.34375 for 997 rounds
# Permutation number: 6
# [11:52:32] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [11:52:32] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 181356.2109375 for 998 rounds
# Permutation number: 7
# [11:54:21] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [11:54:22] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 198090.7265625 for 998 rounds
# Permutation number: 8
# [11:56:04] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [11:56:04] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 184824.4453125 for 998 rounds
# Permutation number: 9
# [11:58:09] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [11:58:09] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 186659.4921875 for 998 rounds
# Permutation number: 10
# [11:59:31] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [11:59:31] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 177382.5 for 998 rounds
# Permutation number: 11
# [12:01:22] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [12:01:22] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 188971.65625 for 998 rounds
# Permutation number: 12
# [12:02:55] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [12:02:55] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 176179.0078125 for 998 rounds
# Permutation number: 13
# [12:05:04] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [12:05:04] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 192975.34375 for 997 rounds
# Permutation number: 14
# [12:06:23] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [12:06:23] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 181356.2109375 for 998 rounds
# Permutation number: 15
# [12:08:12] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [12:08:12] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 198090.7265625 for 998 rounds
# Permutation number: 16
# [12:09:43] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [12:09:43] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 184824.4453125 for 998 rounds
# Permutation number: 17
# [12:11:49] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [12:11:49] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 198719.609375 for 140 rounds
# Permutation number: 18
# [12:12:01] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [12:12:01] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 191527.3828125 for 168 rounds
# Permutation number: 19
# [12:12:21] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [12:12:21] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 197079.4921875 for 113 rounds
# Permutation number: 20
# [12:12:33] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [12:12:33] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 181476.59375 for 215 rounds
# Permutation number: 21
# [12:13:03] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [12:13:03] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 199539.984375 for 114 rounds
# Permutation number: 22
# [12:13:13] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [12:13:13] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 187941.03125 for 268 rounds
# Permutation number: 23
# [12:13:44] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [12:13:44] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 202375.875 for 95 rounds
# Permutation number: 24
# [12:13:54] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [12:13:54] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 187321.296875 for 169 rounds
# Permutation number: 25
# [12:14:17] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [12:14:17] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 198719.609375 for 140 rounds
# Permutation number: 26
# [12:14:30] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [12:14:30] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 191527.3828125 for 168 rounds
# Permutation number: 27
# [12:14:50] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [12:14:50] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 197079.4921875 for 113 rounds
# Permutation number: 28
# [12:15:01] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [12:15:02] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 181476.59375 for 215 rounds
# Permutation number: 29
# [12:15:32] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [12:15:32] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 199539.984375 for 114 rounds
# Permutation number: 30
# [12:15:42] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [12:15:42] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 187941.03125 for 268 rounds
# Permutation number: 31
# [12:16:13] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [12:16:13] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 202375.875 for 95 rounds
# Permutation number: 32
# [12:16:23] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [12:16:23] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 187321.296875 for 169 rounds

# %%
print("Best Score:", best_score_value)
print("Best Parameters:", best_params_value)
# Out:
# Best Score: 176179.0078125
# Best Parameters: {'n_estimators': 500, 'objective': 'reg:linear', 'eval_metric': ['rmse', 'mae'], 'min_child_weight': 1, 'eta': 0.01, 'gamma': 0.05, 'subsample': 0.8, 'colsample_bytree': 1.0, 'max_depth': 9}

# %%
#Retrain a model with new best params
model_value = xgb.train(
    best_params_value,
    dtrain_value,
    num_boost_round=num_boost_round,
    evals=evaluation_set_value,
    early_stopping_rounds=early_stopping_rounds
 )
# Out:
# [12:16:46] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	Test_set-rmse:6.0729e+06	Test_set-mae:2.4594e+06
# Multiple eval metrics have been passed: 'Test_set-mae' will be used for early stopping.
#
# Will train until Test_set-mae hasn't improved in 10 rounds.
# [1]	Test_set-rmse:6.01295e+06	Test_set-mae:2.43498e+06
# [2]	Test_set-rmse:5.95615e+06	Test_set-mae:2.41124e+06
# [3]	Test_set-rmse:5.89969e+06	Test_set-mae:2.38774e+06
# [4]	Test_set-rmse:5.84366e+06	Test_set-mae:2.36453e+06
# [5]	Test_set-rmse:5.78782e+06	Test_set-mae:2.34148e+06
# [6]	Test_set-rmse:5.73143e+06	Test_set-mae:2.31862e+06
# [7]	Test_set-rmse:5.677e+06	Test_set-mae:2.29626e+06
# [8]	Test_set-rmse:5.62367e+06	Test_set-mae:2.27416e+06
# [9]	Test_set-rmse:5.57062e+06	Test_set-mae:2.25236e+06
# [10]	Test_set-rmse:5.51759e+06	Test_set-mae:2.23062e+06
# [11]	Test_set-rmse:5.46408e+06	Test_set-mae:2.20898e+06
# [12]	Test_set-rmse:5.41284e+06	Test_set-mae:2.18783e+06
# [13]	Test_set-rmse:5.36156e+06	Test_set-mae:2.16671e+06
# [14]	Test_set-rmse:5.30895e+06	Test_set-mae:2.14556e+06
# [15]	Test_set-rmse:5.25782e+06	Test_set-mae:2.12477e+06
# [16]	Test_set-rmse:5.2085e+06	Test_set-mae:2.10442e+06
# [17]	Test_set-rmse:5.15946e+06	Test_set-mae:2.08422e+06
# [18]	Test_set-rmse:5.11077e+06	Test_set-mae:2.06422e+06
# [19]	Test_set-rmse:5.06176e+06	Test_set-mae:2.04429e+06
# [20]	Test_set-rmse:5.01355e+06	Test_set-mae:2.02466e+06
# [21]	Test_set-rmse:4.96563e+06	Test_set-mae:2.00521e+06
# [22]	Test_set-rmse:4.91752e+06	Test_set-mae:1.9858e+06
# [23]	Test_set-rmse:4.87082e+06	Test_set-mae:1.96669e+06
# [24]	Test_set-rmse:4.82542e+06	Test_set-mae:1.94795e+06
# [25]	Test_set-rmse:4.78008e+06	Test_set-mae:1.92914e+06
# [26]	Test_set-rmse:4.73476e+06	Test_set-mae:1.91064e+06
# [27]	Test_set-rmse:4.68985e+06	Test_set-mae:1.8923e+06
# [28]	Test_set-rmse:4.64544e+06	Test_set-mae:1.87422e+06
# [29]	Test_set-rmse:4.60128e+06	Test_set-mae:1.85628e+06
# [30]	Test_set-rmse:4.55622e+06	Test_set-mae:1.83825e+06
# [31]	Test_set-rmse:4.51208e+06	Test_set-mae:1.82057e+06
# [32]	Test_set-rmse:4.46983e+06	Test_set-mae:1.80316e+06
# [33]	Test_set-rmse:4.42653e+06	Test_set-mae:1.7858e+06
# [34]	Test_set-rmse:4.38369e+06	Test_set-mae:1.7684e+06
# [35]	Test_set-rmse:4.3423e+06	Test_set-mae:1.7514e+06
# [36]	Test_set-rmse:4.29995e+06	Test_set-mae:1.73459e+06
# [37]	Test_set-rmse:4.25837e+06	Test_set-mae:1.71789e+06
# [38]	Test_set-rmse:4.2187e+06	Test_set-mae:1.70147e+06
# [39]	Test_set-rmse:4.17848e+06	Test_set-mae:1.68515e+06
# [40]	Test_set-rmse:4.1382e+06	Test_set-mae:1.66901e+06
# [41]	Test_set-rmse:4.09893e+06	Test_set-mae:1.65308e+06
# [42]	Test_set-rmse:4.05938e+06	Test_set-mae:1.63727e+06
# [43]	Test_set-rmse:4.02137e+06	Test_set-mae:1.62173e+06
# [44]	Test_set-rmse:3.98329e+06	Test_set-mae:1.60631e+06
# [45]	Test_set-rmse:3.94572e+06	Test_set-mae:1.59091e+06
# [46]	Test_set-rmse:3.90896e+06	Test_set-mae:1.57586e+06
# [47]	Test_set-rmse:3.87281e+06	Test_set-mae:1.56105e+06
# [48]	Test_set-rmse:3.83654e+06	Test_set-mae:1.54629e+06
# [49]	Test_set-rmse:3.79949e+06	Test_set-mae:1.53146e+06
# [50]	Test_set-rmse:3.76296e+06	Test_set-mae:1.51685e+06
# [51]	Test_set-rmse:3.72622e+06	Test_set-mae:1.50231e+06
# [52]	Test_set-rmse:3.6911e+06	Test_set-mae:1.48797e+06
# [53]	Test_set-rmse:3.65663e+06	Test_set-mae:1.47383e+06
# [54]	Test_set-rmse:3.62357e+06	Test_set-mae:1.4601e+06
# [55]	Test_set-rmse:3.58813e+06	Test_set-mae:1.44605e+06
# [56]	Test_set-rmse:3.55362e+06	Test_set-mae:1.43228e+06
# [57]	Test_set-rmse:3.52075e+06	Test_set-mae:1.41886e+06
# [58]	Test_set-rmse:3.487e+06	Test_set-mae:1.40531e+06
# [59]	Test_set-rmse:3.45345e+06	Test_set-mae:1.39191e+06
# [60]	Test_set-rmse:3.42091e+06	Test_set-mae:1.37863e+06
# [61]	Test_set-rmse:3.38878e+06	Test_set-mae:1.36554e+06
# [62]	Test_set-rmse:3.35699e+06	Test_set-mae:1.35263e+06
# [63]	Test_set-rmse:3.32572e+06	Test_set-mae:1.3398e+06
# [64]	Test_set-rmse:3.29531e+06	Test_set-mae:1.32727e+06
# [65]	Test_set-rmse:3.2639e+06	Test_set-mae:1.3147e+06
# [66]	Test_set-rmse:3.23333e+06	Test_set-mae:1.3022e+06
# [67]	Test_set-rmse:3.20291e+06	Test_set-mae:1.2898e+06
# [68]	Test_set-rmse:3.17256e+06	Test_set-mae:1.27752e+06
# [69]	Test_set-rmse:3.14299e+06	Test_set-mae:1.26545e+06
# [70]	Test_set-rmse:3.11374e+06	Test_set-mae:1.25353e+06
# [71]	Test_set-rmse:3.08406e+06	Test_set-mae:1.2416e+06
# [72]	Test_set-rmse:3.05608e+06	Test_set-mae:1.23009e+06
# [73]	Test_set-rmse:3.02835e+06	Test_set-mae:1.21862e+06
# [74]	Test_set-rmse:2.99994e+06	Test_set-mae:1.20705e+06
# [75]	Test_set-rmse:2.97243e+06	Test_set-mae:1.1957e+06
# [76]	Test_set-rmse:2.94539e+06	Test_set-mae:1.1845e+06
# [77]	Test_set-rmse:2.91798e+06	Test_set-mae:1.1733e+06
# [78]	Test_set-rmse:2.89118e+06	Test_set-mae:1.16225e+06
# [79]	Test_set-rmse:2.86376e+06	Test_set-mae:1.15123e+06
# [80]	Test_set-rmse:2.8371e+06	Test_set-mae:1.14032e+06
# [81]	Test_set-rmse:2.81057e+06	Test_set-mae:1.12957e+06
# [82]	Test_set-rmse:2.78413e+06	Test_set-mae:1.11886e+06
# [83]	Test_set-rmse:2.75874e+06	Test_set-mae:1.10835e+06
# [84]	Test_set-rmse:2.73297e+06	Test_set-mae:1.09796e+06
# [85]	Test_set-rmse:2.7074e+06	Test_set-mae:1.08764e+06
# [86]	Test_set-rmse:2.68304e+06	Test_set-mae:1.07765e+06
# [87]	Test_set-rmse:2.65877e+06	Test_set-mae:1.06762e+06
# [88]	Test_set-rmse:2.63459e+06	Test_set-mae:1.05769e+06
# [89]	Test_set-rmse:2.61045e+06	Test_set-mae:1.04787e+06
# [90]	Test_set-rmse:2.58689e+06	Test_set-mae:1.03814e+06
# [91]	Test_set-rmse:2.56388e+06	Test_set-mae:1.02865e+06
# [92]	Test_set-rmse:2.54082e+06	Test_set-mae:1.01915e+06
# [93]	Test_set-rmse:2.51812e+06	Test_set-mae:1.00978e+06
# [94]	Test_set-rmse:2.49425e+06	Test_set-mae:1.00026e+06
# [95]	Test_set-rmse:2.47153e+06	Test_set-mae:990973
# [96]	Test_set-rmse:2.44933e+06	Test_set-mae:981891
# [97]	Test_set-rmse:2.42773e+06	Test_set-mae:972934
# [98]	Test_set-rmse:2.40651e+06	Test_set-mae:964014
# [99]	Test_set-rmse:2.3855e+06	Test_set-mae:955189
# [100]	Test_set-rmse:2.36448e+06	Test_set-mae:946453
# [101]	Test_set-rmse:2.34391e+06	Test_set-mae:937839
# [102]	Test_set-rmse:2.32267e+06	Test_set-mae:929095
# [103]	Test_set-rmse:2.30237e+06	Test_set-mae:920554
# [104]	Test_set-rmse:2.28223e+06	Test_set-mae:912088
# [105]	Test_set-rmse:2.26193e+06	Test_set-mae:903694
# [106]	Test_set-rmse:2.24151e+06	Test_set-mae:895371
# [107]	Test_set-rmse:2.22234e+06	Test_set-mae:887214
# [108]	Test_set-rmse:2.20197e+06	Test_set-mae:878974
# [109]	Test_set-rmse:2.1831e+06	Test_set-mae:871039
# [110]	Test_set-rmse:2.16328e+06	Test_set-mae:862948
# [111]	Test_set-rmse:2.14462e+06	Test_set-mae:855076
# [112]	Test_set-rmse:2.12662e+06	Test_set-mae:847415
# [113]	Test_set-rmse:2.10802e+06	Test_set-mae:839697
# [114]	Test_set-rmse:2.08913e+06	Test_set-mae:832064
# [115]	Test_set-rmse:2.07115e+06	Test_set-mae:824526
# [116]	Test_set-rmse:2.05344e+06	Test_set-mae:817088
# [117]	Test_set-rmse:2.03571e+06	Test_set-mae:809690
# [118]	Test_set-rmse:2.01836e+06	Test_set-mae:802382
# [119]	Test_set-rmse:2.00084e+06	Test_set-mae:795147
# [120]	Test_set-rmse:1.98362e+06	Test_set-mae:787972
# [121]	Test_set-rmse:1.96675e+06	Test_set-mae:780850
# [122]	Test_set-rmse:1.94998e+06	Test_set-mae:773773
# [123]	Test_set-rmse:1.93348e+06	Test_set-mae:766826
# [124]	Test_set-rmse:1.9167e+06	Test_set-mae:759857
# [125]	Test_set-rmse:1.90028e+06	Test_set-mae:752964
# [126]	Test_set-rmse:1.88443e+06	Test_set-mae:746140
# [127]	Test_set-rmse:1.86827e+06	Test_set-mae:739416
# [128]	Test_set-rmse:1.85244e+06	Test_set-mae:732771
# [129]	Test_set-rmse:1.83686e+06	Test_set-mae:726178
# [130]	Test_set-rmse:1.82139e+06	Test_set-mae:719623
# [131]	Test_set-rmse:1.80583e+06	Test_set-mae:713143
# [132]	Test_set-rmse:1.7907e+06	Test_set-mae:706722
# [133]	Test_set-rmse:1.77491e+06	Test_set-mae:700281
# [134]	Test_set-rmse:1.76021e+06	Test_set-mae:694070
# [135]	Test_set-rmse:1.74554e+06	Test_set-mae:687879
# [136]	Test_set-rmse:1.73101e+06	Test_set-mae:681791
# [137]	Test_set-rmse:1.71669e+06	Test_set-mae:675806
# [138]	Test_set-rmse:1.70222e+06	Test_set-mae:669816
# [139]	Test_set-rmse:1.68785e+06	Test_set-mae:663782
# [140]	Test_set-rmse:1.67467e+06	Test_set-mae:657982
# [141]	Test_set-rmse:1.66121e+06	Test_set-mae:652252
# [142]	Test_set-rmse:1.64771e+06	Test_set-mae:646473
# [143]	Test_set-rmse:1.63464e+06	Test_set-mae:640833
# [144]	Test_set-rmse:1.62118e+06	Test_set-mae:635174
# [145]	Test_set-rmse:1.60756e+06	Test_set-mae:629480
# [146]	Test_set-rmse:1.59432e+06	Test_set-mae:623873
# [147]	Test_set-rmse:1.58094e+06	Test_set-mae:618355
# [148]	Test_set-rmse:1.56874e+06	Test_set-mae:613002
# [149]	Test_set-rmse:1.55571e+06	Test_set-mae:607625
# [150]	Test_set-rmse:1.54335e+06	Test_set-mae:602262
# [151]	Test_set-rmse:1.53166e+06	Test_set-mae:597063
# [152]	Test_set-rmse:1.51934e+06	Test_set-mae:591850
# [153]	Test_set-rmse:1.50794e+06	Test_set-mae:586737
# [154]	Test_set-rmse:1.49611e+06	Test_set-mae:581593
# [155]	Test_set-rmse:1.48457e+06	Test_set-mae:576614
# [156]	Test_set-rmse:1.47269e+06	Test_set-mae:571665
# [157]	Test_set-rmse:1.46135e+06	Test_set-mae:566760
# [158]	Test_set-rmse:1.4492e+06	Test_set-mae:561795
# [159]	Test_set-rmse:1.43823e+06	Test_set-mae:556969
# [160]	Test_set-rmse:1.42733e+06	Test_set-mae:552152
# [161]	Test_set-rmse:1.41641e+06	Test_set-mae:547412
# [162]	Test_set-rmse:1.40544e+06	Test_set-mae:542677
# [163]	Test_set-rmse:1.39484e+06	Test_set-mae:538078
# [164]	Test_set-rmse:1.38445e+06	Test_set-mae:533476
# [165]	Test_set-rmse:1.37479e+06	Test_set-mae:528968
# [166]	Test_set-rmse:1.36372e+06	Test_set-mae:524364
# [167]	Test_set-rmse:1.35365e+06	Test_set-mae:519931
# [168]	Test_set-rmse:1.34239e+06	Test_set-mae:515368
# [169]	Test_set-rmse:1.33224e+06	Test_set-mae:511020
# [170]	Test_set-rmse:1.3226e+06	Test_set-mae:506720
# [171]	Test_set-rmse:1.3128e+06	Test_set-mae:502478
# [172]	Test_set-rmse:1.30342e+06	Test_set-mae:498307
# [173]	Test_set-rmse:1.29403e+06	Test_set-mae:494128
# [174]	Test_set-rmse:1.28521e+06	Test_set-mae:490005
# [175]	Test_set-rmse:1.27588e+06	Test_set-mae:485934
# [176]	Test_set-rmse:1.26703e+06	Test_set-mae:481959
# [177]	Test_set-rmse:1.25776e+06	Test_set-mae:477854
# [178]	Test_set-rmse:1.24883e+06	Test_set-mae:473920
# [179]	Test_set-rmse:1.24037e+06	Test_set-mae:470004
# [180]	Test_set-rmse:1.23083e+06	Test_set-mae:465974
# [181]	Test_set-rmse:1.22227e+06	Test_set-mae:462150
# [182]	Test_set-rmse:1.21405e+06	Test_set-mae:458381
# [183]	Test_set-rmse:1.20587e+06	Test_set-mae:454646
# [184]	Test_set-rmse:1.19729e+06	Test_set-mae:450886
# [185]	Test_set-rmse:1.18901e+06	Test_set-mae:447238
# [186]	Test_set-rmse:1.18166e+06	Test_set-mae:443650
# [187]	Test_set-rmse:1.17366e+06	Test_set-mae:440016
# [188]	Test_set-rmse:1.16576e+06	Test_set-mae:436405
# [189]	Test_set-rmse:1.15846e+06	Test_set-mae:432920
# [190]	Test_set-rmse:1.15052e+06	Test_set-mae:429370
# [191]	Test_set-rmse:1.14261e+06	Test_set-mae:425861
# [192]	Test_set-rmse:1.13494e+06	Test_set-mae:422426
# [193]	Test_set-rmse:1.12746e+06	Test_set-mae:419033
# [194]	Test_set-rmse:1.11963e+06	Test_set-mae:415694
# [195]	Test_set-rmse:1.11247e+06	Test_set-mae:412430
# [196]	Test_set-rmse:1.10501e+06	Test_set-mae:409085
# [197]	Test_set-rmse:1.09748e+06	Test_set-mae:405855
# [198]	Test_set-rmse:1.09001e+06	Test_set-mae:402629
# [199]	Test_set-rmse:1.08283e+06	Test_set-mae:399430
# [200]	Test_set-rmse:1.07555e+06	Test_set-mae:396305
# [201]	Test_set-rmse:1.06893e+06	Test_set-mae:393202
# [202]	Test_set-rmse:1.06234e+06	Test_set-mae:390165
# [203]	Test_set-rmse:1.05594e+06	Test_set-mae:387208
# [204]	Test_set-rmse:1.04975e+06	Test_set-mae:384222
# [205]	Test_set-rmse:1.04308e+06	Test_set-mae:381284
# [206]	Test_set-rmse:1.03634e+06	Test_set-mae:378299
# [207]	Test_set-rmse:1.02969e+06	Test_set-mae:375426
# [208]	Test_set-rmse:1.02314e+06	Test_set-mae:372521
# [209]	Test_set-rmse:1.017e+06	Test_set-mae:369688
# [210]	Test_set-rmse:1.01101e+06	Test_set-mae:366925
# [211]	Test_set-rmse:1.00511e+06	Test_set-mae:364239
# [212]	Test_set-rmse:999158	Test_set-mae:361627
# [213]	Test_set-rmse:993252	Test_set-mae:358947
# [214]	Test_set-rmse:987586	Test_set-mae:356259
# [215]	Test_set-rmse:981867	Test_set-mae:353613
# [216]	Test_set-rmse:976577	Test_set-mae:351041
# [217]	Test_set-rmse:970745	Test_set-mae:348453
# [218]	Test_set-rmse:964818	Test_set-mae:345830
# [219]	Test_set-rmse:958635	Test_set-mae:343234
# [220]	Test_set-rmse:953753	Test_set-mae:340802
# [221]	Test_set-rmse:948471	Test_set-mae:338278
# [222]	Test_set-rmse:942766	Test_set-mae:335756
# [223]	Test_set-rmse:937562	Test_set-mae:333404
# [224]	Test_set-rmse:931818	Test_set-mae:330891
# [225]	Test_set-rmse:926992	Test_set-mae:328557
# [226]	Test_set-rmse:921443	Test_set-mae:326140
# [227]	Test_set-rmse:916371	Test_set-mae:323817
# [228]	Test_set-rmse:911380	Test_set-mae:321485
# [229]	Test_set-rmse:906537	Test_set-mae:319232
# [230]	Test_set-rmse:901987	Test_set-mae:317082
# [231]	Test_set-rmse:897072	Test_set-mae:314825
# [232]	Test_set-rmse:892241	Test_set-mae:312621
# [233]	Test_set-rmse:887859	Test_set-mae:310430
# [234]	Test_set-rmse:883561	Test_set-mae:308332
# [235]	Test_set-rmse:879328	Test_set-mae:306239
# [236]	Test_set-rmse:875196	Test_set-mae:304163
# [237]	Test_set-rmse:871080	Test_set-mae:302139
# [238]	Test_set-rmse:867017	Test_set-mae:300115
# [239]	Test_set-rmse:862844	Test_set-mae:298184
# [240]	Test_set-rmse:858667	Test_set-mae:296244
# [241]	Test_set-rmse:854743	Test_set-mae:294359
# [242]	Test_set-rmse:851054	Test_set-mae:292491
# [243]	Test_set-rmse:847507	Test_set-mae:290707
# [244]	Test_set-rmse:843707	Test_set-mae:288833
# [245]	Test_set-rmse:840114	Test_set-mae:287037
# [246]	Test_set-rmse:836462	Test_set-mae:285268
# [247]	Test_set-rmse:832476	Test_set-mae:283538
# [248]	Test_set-rmse:828654	Test_set-mae:281778
# [249]	Test_set-rmse:825048	Test_set-mae:280042
# [250]	Test_set-rmse:820938	Test_set-mae:278364
# [251]	Test_set-rmse:817355	Test_set-mae:276731
# [252]	Test_set-rmse:813927	Test_set-mae:275138
# [253]	Test_set-rmse:810544	Test_set-mae:273612
# [254]	Test_set-rmse:807426	Test_set-mae:272104
# [255]	Test_set-rmse:804020	Test_set-mae:270579
# [256]	Test_set-rmse:801298	Test_set-mae:269166
# [257]	Test_set-rmse:797115	Test_set-mae:267576
# [258]	Test_set-rmse:794095	Test_set-mae:266134
# [259]	Test_set-rmse:790648	Test_set-mae:264652
# [260]	Test_set-rmse:787470	Test_set-mae:263196
# [261]	Test_set-rmse:784148	Test_set-mae:261684
# [262]	Test_set-rmse:781279	Test_set-mae:260338
# [263]	Test_set-rmse:778368	Test_set-mae:259001
# [264]	Test_set-rmse:775647	Test_set-mae:257708
# [265]	Test_set-rmse:772694	Test_set-mae:256393
# [266]	Test_set-rmse:770004	Test_set-mae:255125
# [267]	Test_set-rmse:767330	Test_set-mae:253869
# [268]	Test_set-rmse:764362	Test_set-mae:252560
# [269]	Test_set-rmse:761864	Test_set-mae:251377
# [270]	Test_set-rmse:759022	Test_set-mae:250107
# [271]	Test_set-rmse:756415	Test_set-mae:248940
# [272]	Test_set-rmse:754171	Test_set-mae:247817
# [273]	Test_set-rmse:751505	Test_set-mae:246641
# [274]	Test_set-rmse:749037	Test_set-mae:245513
# [275]	Test_set-rmse:746287	Test_set-mae:244341
# [276]	Test_set-rmse:743979	Test_set-mae:243267
# [277]	Test_set-rmse:741456	Test_set-mae:242100
# [278]	Test_set-rmse:738731	Test_set-mae:240972
# [279]	Test_set-rmse:736177	Test_set-mae:239835
# [280]	Test_set-rmse:733903	Test_set-mae:238758
# [281]	Test_set-rmse:731457	Test_set-mae:237722
# [282]	Test_set-rmse:729030	Test_set-mae:236612
# [283]	Test_set-rmse:727194	Test_set-mae:235658
# [284]	Test_set-rmse:725012	Test_set-mae:234642
# [285]	Test_set-rmse:723010	Test_set-mae:233659
# [286]	Test_set-rmse:721058	Test_set-mae:232699
# [287]	Test_set-rmse:719062	Test_set-mae:231750
# [288]	Test_set-rmse:717152	Test_set-mae:230824
# [289]	Test_set-rmse:715094	Test_set-mae:229918
# [290]	Test_set-rmse:712906	Test_set-mae:228949
# [291]	Test_set-rmse:710845	Test_set-mae:228048
# [292]	Test_set-rmse:708906	Test_set-mae:227118
# [293]	Test_set-rmse:707126	Test_set-mae:226244
# [294]	Test_set-rmse:705461	Test_set-mae:225413
# [295]	Test_set-rmse:703770	Test_set-mae:224574
# [296]	Test_set-rmse:702016	Test_set-mae:223739
# [297]	Test_set-rmse:700218	Test_set-mae:222899
# [298]	Test_set-rmse:698243	Test_set-mae:221993
# [299]	Test_set-rmse:696380	Test_set-mae:221160
# [300]	Test_set-rmse:694746	Test_set-mae:220385
# [301]	Test_set-rmse:693209	Test_set-mae:219589
# [302]	Test_set-rmse:691461	Test_set-mae:218782
# [303]	Test_set-rmse:689685	Test_set-mae:217997
# [304]	Test_set-rmse:688108	Test_set-mae:217259
# [305]	Test_set-rmse:686089	Test_set-mae:216471
# [306]	Test_set-rmse:684566	Test_set-mae:215762
# [307]	Test_set-rmse:683182	Test_set-mae:215103
# [308]	Test_set-rmse:681548	Test_set-mae:214385
# [309]	Test_set-rmse:680160	Test_set-mae:213703
# [310]	Test_set-rmse:678728	Test_set-mae:213019
# [311]	Test_set-rmse:677160	Test_set-mae:212340
# [312]	Test_set-rmse:675630	Test_set-mae:211690
# [313]	Test_set-rmse:673985	Test_set-mae:210998
# [314]	Test_set-rmse:672713	Test_set-mae:210393
# [315]	Test_set-rmse:671516	Test_set-mae:209827
# [316]	Test_set-rmse:670093	Test_set-mae:209230
# [317]	Test_set-rmse:669056	Test_set-mae:208698
# [318]	Test_set-rmse:667735	Test_set-mae:208092
# [319]	Test_set-rmse:666260	Test_set-mae:207506
# [320]	Test_set-rmse:664914	Test_set-mae:206931
# [321]	Test_set-rmse:663698	Test_set-mae:206376
# [322]	Test_set-rmse:662747	Test_set-mae:205869
# [323]	Test_set-rmse:661520	Test_set-mae:205310
# [324]	Test_set-rmse:660236	Test_set-mae:204781
# [325]	Test_set-rmse:659110	Test_set-mae:204265
# [326]	Test_set-rmse:657856	Test_set-mae:203722
# [327]	Test_set-rmse:656882	Test_set-mae:203254
# [328]	Test_set-rmse:655618	Test_set-mae:202746
# [329]	Test_set-rmse:654718	Test_set-mae:202326
# [330]	Test_set-rmse:653594	Test_set-mae:201859
# [331]	Test_set-rmse:652797	Test_set-mae:201396
# [332]	Test_set-rmse:651862	Test_set-mae:200929
# [333]	Test_set-rmse:650690	Test_set-mae:200438
# [334]	Test_set-rmse:649636	Test_set-mae:199986
# [335]	Test_set-rmse:648796	Test_set-mae:199566
# [336]	Test_set-rmse:647729	Test_set-mae:199141
# [337]	Test_set-rmse:646688	Test_set-mae:198679
# [338]	Test_set-rmse:645694	Test_set-mae:198254
# [339]	Test_set-rmse:644686	Test_set-mae:197793
# [340]	Test_set-rmse:643719	Test_set-mae:197355
# [341]	Test_set-rmse:642741	Test_set-mae:196946
# [342]	Test_set-rmse:641828	Test_set-mae:196515
# [343]	Test_set-rmse:641178	Test_set-mae:196170
# [344]	Test_set-rmse:640404	Test_set-mae:195796
# [345]	Test_set-rmse:639500	Test_set-mae:195414
# [346]	Test_set-rmse:638468	Test_set-mae:195007
# [347]	Test_set-rmse:637645	Test_set-mae:194662
# [348]	Test_set-rmse:636498	Test_set-mae:194262
# [349]	Test_set-rmse:635833	Test_set-mae:193909
# [350]	Test_set-rmse:634627	Test_set-mae:193511
# [351]	Test_set-rmse:633754	Test_set-mae:193126
# [352]	Test_set-rmse:632915	Test_set-mae:192764
# [353]	Test_set-rmse:632086	Test_set-mae:192406
# [354]	Test_set-rmse:631470	Test_set-mae:192072
# [355]	Test_set-rmse:630716	Test_set-mae:191745
# [356]	Test_set-rmse:629898	Test_set-mae:191399
# [357]	Test_set-rmse:629157	Test_set-mae:191107
# [358]	Test_set-rmse:628376	Test_set-mae:190781
# [359]	Test_set-rmse:627778	Test_set-mae:190476
# [360]	Test_set-rmse:627219	Test_set-mae:190158
# [361]	Test_set-rmse:626465	Test_set-mae:189845
# [362]	Test_set-rmse:625741	Test_set-mae:189556
# [363]	Test_set-rmse:625044	Test_set-mae:189255
# [364]	Test_set-rmse:624485	Test_set-mae:188974
# [365]	Test_set-rmse:623758	Test_set-mae:188672
# [366]	Test_set-rmse:623037	Test_set-mae:188382
# [367]	Test_set-rmse:622563	Test_set-mae:188116
# [368]	Test_set-rmse:622048	Test_set-mae:187860
# [369]	Test_set-rmse:621392	Test_set-mae:187582
# [370]	Test_set-rmse:620710	Test_set-mae:187314
# [371]	Test_set-rmse:620083	Test_set-mae:187023
# [372]	Test_set-rmse:619314	Test_set-mae:186742
# [373]	Test_set-rmse:618794	Test_set-mae:186483
# [374]	Test_set-rmse:618280	Test_set-mae:186247
# [375]	Test_set-rmse:617774	Test_set-mae:186015
# [376]	Test_set-rmse:617175	Test_set-mae:185776
# [377]	Test_set-rmse:616577	Test_set-mae:185518
# [378]	Test_set-rmse:616074	Test_set-mae:185280
# [379]	Test_set-rmse:615577	Test_set-mae:185038
# [380]	Test_set-rmse:615007	Test_set-mae:184819
# [381]	Test_set-rmse:614311	Test_set-mae:184580
# [382]	Test_set-rmse:613707	Test_set-mae:184326
# [383]	Test_set-rmse:613165	Test_set-mae:184088
# [384]	Test_set-rmse:612803	Test_set-mae:183888
# [385]	Test_set-rmse:612374	Test_set-mae:183686
# [386]	Test_set-rmse:611974	Test_set-mae:183465
# [387]	Test_set-rmse:611477	Test_set-mae:183247
# [388]	Test_set-rmse:611052	Test_set-mae:183068
# [389]	Test_set-rmse:610480	Test_set-mae:182853
# [390]	Test_set-rmse:609921	Test_set-mae:182636
# [391]	Test_set-rmse:609530	Test_set-mae:182441
# [392]	Test_set-rmse:609227	Test_set-mae:182264
# [393]	Test_set-rmse:608848	Test_set-mae:182057
# [394]	Test_set-rmse:608440	Test_set-mae:181849
# [395]	Test_set-rmse:608131	Test_set-mae:181695
# [396]	Test_set-rmse:607636	Test_set-mae:181490
# [397]	Test_set-rmse:607094	Test_set-mae:181259
# [398]	Test_set-rmse:606740	Test_set-mae:181081
# [399]	Test_set-rmse:606266	Test_set-mae:180880
# [400]	Test_set-rmse:606016	Test_set-mae:180725
# [401]	Test_set-rmse:605725	Test_set-mae:180571
# [402]	Test_set-rmse:605340	Test_set-mae:180394
# [403]	Test_set-rmse:604926	Test_set-mae:180234
# [404]	Test_set-rmse:604544	Test_set-mae:180063
# [405]	Test_set-rmse:604131	Test_set-mae:179901
# [406]	Test_set-rmse:603875	Test_set-mae:179758
# [407]	Test_set-rmse:603501	Test_set-mae:179575
# [408]	Test_set-rmse:603220	Test_set-mae:179421
# [409]	Test_set-rmse:602841	Test_set-mae:179254
# [410]	Test_set-rmse:602560	Test_set-mae:179132
# [411]	Test_set-rmse:602234	Test_set-mae:178987
# [412]	Test_set-rmse:601907	Test_set-mae:178826
# [413]	Test_set-rmse:601627	Test_set-mae:178690
# [414]	Test_set-rmse:601419	Test_set-mae:178566
# [415]	Test_set-rmse:601176	Test_set-mae:178425
# [416]	Test_set-rmse:600943	Test_set-mae:178291
# [417]	Test_set-rmse:600643	Test_set-mae:178136
# [418]	Test_set-rmse:600398	Test_set-mae:178006
# [419]	Test_set-rmse:600068	Test_set-mae:177884
# [420]	Test_set-rmse:599659	Test_set-mae:177726
# [421]	Test_set-rmse:599386	Test_set-mae:177581
# [422]	Test_set-rmse:599031	Test_set-mae:177449
# [423]	Test_set-rmse:598740	Test_set-mae:177309
# [424]	Test_set-rmse:598470	Test_set-mae:177188
# [425]	Test_set-rmse:598136	Test_set-mae:177035
# [426]	Test_set-rmse:597890	Test_set-mae:176907
# [427]	Test_set-rmse:597593	Test_set-mae:176779
# [428]	Test_set-rmse:597375	Test_set-mae:176645
# [429]	Test_set-rmse:597066	Test_set-mae:176520
# [430]	Test_set-rmse:596788	Test_set-mae:176382
# [431]	Test_set-rmse:596348	Test_set-mae:176248
# [432]	Test_set-rmse:596235	Test_set-mae:176157
# [433]	Test_set-rmse:595999	Test_set-mae:176001
# [434]	Test_set-rmse:595735	Test_set-mae:175870
# [435]	Test_set-rmse:595574	Test_set-mae:175758
# [436]	Test_set-rmse:595287	Test_set-mae:175625
# [437]	Test_set-rmse:595053	Test_set-mae:175491
# [438]	Test_set-rmse:594819	Test_set-mae:175376
# [439]	Test_set-rmse:594693	Test_set-mae:175300
# [440]	Test_set-rmse:594487	Test_set-mae:175177
# [441]	Test_set-rmse:594285	Test_set-mae:175067
# [442]	Test_set-rmse:594198	Test_set-mae:174995
# [443]	Test_set-rmse:593869	Test_set-mae:174881
# [444]	Test_set-rmse:593776	Test_set-mae:174811
# [445]	Test_set-rmse:593601	Test_set-mae:174713
# [446]	Test_set-rmse:593384	Test_set-mae:174607
# [447]	Test_set-rmse:593175	Test_set-mae:174521
# [448]	Test_set-rmse:593010	Test_set-mae:174425
# [449]	Test_set-rmse:592813	Test_set-mae:174334
# [450]	Test_set-rmse:592778	Test_set-mae:174241
# [451]	Test_set-rmse:592465	Test_set-mae:174148
# [452]	Test_set-rmse:592260	Test_set-mae:174041
# [453]	Test_set-rmse:592083	Test_set-mae:173953
# [454]	Test_set-rmse:591864	Test_set-mae:173843
# [455]	Test_set-rmse:591720	Test_set-mae:173733
# [456]	Test_set-rmse:591517	Test_set-mae:173628
# [457]	Test_set-rmse:591384	Test_set-mae:173565
# [458]	Test_set-rmse:591223	Test_set-mae:173461
# [459]	Test_set-rmse:591055	Test_set-mae:173382
# [460]	Test_set-rmse:590857	Test_set-mae:173280
# [461]	Test_set-rmse:590709	Test_set-mae:173209
# [462]	Test_set-rmse:590429	Test_set-mae:173110
# [463]	Test_set-rmse:590241	Test_set-mae:173019
# [464]	Test_set-rmse:590109	Test_set-mae:172950
# [465]	Test_set-rmse:590027	Test_set-mae:172886
# [466]	Test_set-rmse:589747	Test_set-mae:172791
# [467]	Test_set-rmse:589588	Test_set-mae:172696
# [468]	Test_set-rmse:589473	Test_set-mae:172622
# [469]	Test_set-rmse:589292	Test_set-mae:172542
# [470]	Test_set-rmse:589098	Test_set-mae:172451
# [471]	Test_set-rmse:588993	Test_set-mae:172377
# [472]	Test_set-rmse:588864	Test_set-mae:172299
# [473]	Test_set-rmse:588649	Test_set-mae:172218
# [474]	Test_set-rmse:588542	Test_set-mae:172164
# [475]	Test_set-rmse:588407	Test_set-mae:172096
# [476]	Test_set-rmse:588273	Test_set-mae:172034
# [477]	Test_set-rmse:588114	Test_set-mae:171963
# [478]	Test_set-rmse:587931	Test_set-mae:171888
# [479]	Test_set-rmse:587880	Test_set-mae:171840
# [480]	Test_set-rmse:587732	Test_set-mae:171796
# [481]	Test_set-rmse:587557	Test_set-mae:171720
# [482]	Test_set-rmse:587422	Test_set-mae:171656
# [483]	Test_set-rmse:587254	Test_set-mae:171595
# [484]	Test_set-rmse:587241	Test_set-mae:171563
# [485]	Test_set-rmse:587022	Test_set-mae:171472
# [486]	Test_set-rmse:586839	Test_set-mae:171413
# [487]	Test_set-rmse:586786	Test_set-mae:171364
# [488]	Test_set-rmse:586727	Test_set-mae:171299
# [489]	Test_set-rmse:586557	Test_set-mae:171257
# [490]	Test_set-rmse:586437	Test_set-mae:171194
# [491]	Test_set-rmse:586353	Test_set-mae:171147
# [492]	Test_set-rmse:586194	Test_set-mae:171069
# [493]	Test_set-rmse:586088	Test_set-mae:171013
# [494]	Test_set-rmse:585922	Test_set-mae:170955
# [495]	Test_set-rmse:585826	Test_set-mae:170909
# [496]	Test_set-rmse:585751	Test_set-mae:170873
# [497]	Test_set-rmse:585534	Test_set-mae:170812
# [498]	Test_set-rmse:585426	Test_set-mae:170767
# [499]	Test_set-rmse:585299	Test_set-mae:170715
# [500]	Test_set-rmse:585261	Test_set-mae:170675
# [501]	Test_set-rmse:585140	Test_set-mae:170620
# [502]	Test_set-rmse:585134	Test_set-mae:170584
# [503]	Test_set-rmse:584961	Test_set-mae:170536
# [504]	Test_set-rmse:584831	Test_set-mae:170468
# [505]	Test_set-rmse:584629	Test_set-mae:170418
# [506]	Test_set-rmse:584535	Test_set-mae:170369
# [507]	Test_set-rmse:584444	Test_set-mae:170321
# [508]	Test_set-rmse:584248	Test_set-mae:170252
# [509]	Test_set-rmse:584208	Test_set-mae:170225
# [510]	Test_set-rmse:584040	Test_set-mae:170176
# [511]	Test_set-rmse:583908	Test_set-mae:170132
# [512]	Test_set-rmse:583904	Test_set-mae:170105
# [513]	Test_set-rmse:583870	Test_set-mae:170068
# [514]	Test_set-rmse:583707	Test_set-mae:170013
# [515]	Test_set-rmse:583635	Test_set-mae:169967
# [516]	Test_set-rmse:583569	Test_set-mae:169919
# [517]	Test_set-rmse:583454	Test_set-mae:169873
# [518]	Test_set-rmse:583366	Test_set-mae:169829
# [519]	Test_set-rmse:583276	Test_set-mae:169794
# [520]	Test_set-rmse:583232	Test_set-mae:169750
# [521]	Test_set-rmse:583168	Test_set-mae:169706
# [522]	Test_set-rmse:583141	Test_set-mae:169669
# [523]	Test_set-rmse:583016	Test_set-mae:169617
# [524]	Test_set-rmse:582959	Test_set-mae:169582
# [525]	Test_set-rmse:582794	Test_set-mae:169525
# [526]	Test_set-rmse:582721	Test_set-mae:169482
# [527]	Test_set-rmse:582621	Test_set-mae:169442
# [528]	Test_set-rmse:582534	Test_set-mae:169389
# [529]	Test_set-rmse:582475	Test_set-mae:169336
# [530]	Test_set-rmse:582424	Test_set-mae:169308
# [531]	Test_set-rmse:582307	Test_set-mae:169266
# [532]	Test_set-rmse:582224	Test_set-mae:169224
# [533]	Test_set-rmse:582182	Test_set-mae:169197
# [534]	Test_set-rmse:582105	Test_set-mae:169149
# [535]	Test_set-rmse:581999	Test_set-mae:169095
# [536]	Test_set-rmse:581913	Test_set-mae:169060
# [537]	Test_set-rmse:581844	Test_set-mae:169012
# [538]	Test_set-rmse:581756	Test_set-mae:168961
# [539]	Test_set-rmse:581724	Test_set-mae:168916
# [540]	Test_set-rmse:581650	Test_set-mae:168887
# [541]	Test_set-rmse:581542	Test_set-mae:168850
# [542]	Test_set-rmse:581435	Test_set-mae:168814
# [543]	Test_set-rmse:581345	Test_set-mae:168768
# [544]	Test_set-rmse:581277	Test_set-mae:168742
# [545]	Test_set-rmse:581228	Test_set-mae:168701
# [546]	Test_set-rmse:581127	Test_set-mae:168668
# [547]	Test_set-rmse:581042	Test_set-mae:168637
# [548]	Test_set-rmse:580874	Test_set-mae:168572
# [549]	Test_set-rmse:580835	Test_set-mae:168528
# [550]	Test_set-rmse:580732	Test_set-mae:168494
# [551]	Test_set-rmse:580659	Test_set-mae:168464
# [552]	Test_set-rmse:580595	Test_set-mae:168443
# [553]	Test_set-rmse:580536	Test_set-mae:168412
# [554]	Test_set-rmse:580418	Test_set-mae:168356
# [555]	Test_set-rmse:580419	Test_set-mae:168322
# [556]	Test_set-rmse:580367	Test_set-mae:168285
# [557]	Test_set-rmse:580389	Test_set-mae:168260
# [558]	Test_set-rmse:580359	Test_set-mae:168235
# [559]	Test_set-rmse:580322	Test_set-mae:168193
# [560]	Test_set-rmse:580297	Test_set-mae:168144
# [561]	Test_set-rmse:580285	Test_set-mae:168110
# [562]	Test_set-rmse:580235	Test_set-mae:168081
# [563]	Test_set-rmse:580155	Test_set-mae:168062
# [564]	Test_set-rmse:580097	Test_set-mae:168057
# [565]	Test_set-rmse:580100	Test_set-mae:168039
# [566]	Test_set-rmse:580085	Test_set-mae:168015
# [567]	Test_set-rmse:580018	Test_set-mae:167978
# [568]	Test_set-rmse:579986	Test_set-mae:167949
# [569]	Test_set-rmse:579903	Test_set-mae:167915
# [570]	Test_set-rmse:579862	Test_set-mae:167893
# [571]	Test_set-rmse:579826	Test_set-mae:167859
# [572]	Test_set-rmse:579807	Test_set-mae:167838
# [573]	Test_set-rmse:579775	Test_set-mae:167820
# [574]	Test_set-rmse:579753	Test_set-mae:167803
# [575]	Test_set-rmse:579737	Test_set-mae:167774
# [576]	Test_set-rmse:579698	Test_set-mae:167759
# [577]	Test_set-rmse:579624	Test_set-mae:167730
# [578]	Test_set-rmse:579520	Test_set-mae:167702
# [579]	Test_set-rmse:579499	Test_set-mae:167676
# [580]	Test_set-rmse:579482	Test_set-mae:167650
# [581]	Test_set-rmse:579422	Test_set-mae:167635
# [582]	Test_set-rmse:579366	Test_set-mae:167609
# [583]	Test_set-rmse:579353	Test_set-mae:167597
# [584]	Test_set-rmse:579351	Test_set-mae:167585
# [585]	Test_set-rmse:579325	Test_set-mae:167565
# [586]	Test_set-rmse:579321	Test_set-mae:167551
# [587]	Test_set-rmse:579280	Test_set-mae:167537
# [588]	Test_set-rmse:579224	Test_set-mae:167505
# [589]	Test_set-rmse:579221	Test_set-mae:167475
# [590]	Test_set-rmse:579155	Test_set-mae:167445
# [591]	Test_set-rmse:579151	Test_set-mae:167424
# [592]	Test_set-rmse:579090	Test_set-mae:167403
# [593]	Test_set-rmse:579056	Test_set-mae:167389
# [594]	Test_set-rmse:579065	Test_set-mae:167378
# [595]	Test_set-rmse:579033	Test_set-mae:167366
# [596]	Test_set-rmse:578963	Test_set-mae:167333
# [597]	Test_set-rmse:578902	Test_set-mae:167310
# [598]	Test_set-rmse:578843	Test_set-mae:167277
# [599]	Test_set-rmse:578758	Test_set-mae:167250
# [600]	Test_set-rmse:578728	Test_set-mae:167230
# [601]	Test_set-rmse:578664	Test_set-mae:167214
# [602]	Test_set-rmse:578571	Test_set-mae:167179
# [603]	Test_set-rmse:578531	Test_set-mae:167154
# [604]	Test_set-rmse:578464	Test_set-mae:167119
# [605]	Test_set-rmse:578434	Test_set-mae:167099
# [606]	Test_set-rmse:578382	Test_set-mae:167077
# [607]	Test_set-rmse:578363	Test_set-mae:167063
# [608]	Test_set-rmse:578334	Test_set-mae:167044
# [609]	Test_set-rmse:578273	Test_set-mae:167013
# [610]	Test_set-rmse:578261	Test_set-mae:166999
# [611]	Test_set-rmse:578188	Test_set-mae:166974
# [612]	Test_set-rmse:578152	Test_set-mae:166961
# [613]	Test_set-rmse:578063	Test_set-mae:166924
# [614]	Test_set-rmse:578048	Test_set-mae:166913
# [615]	Test_set-rmse:578046	Test_set-mae:166908
# [616]	Test_set-rmse:578036	Test_set-mae:166887
# [617]	Test_set-rmse:577968	Test_set-mae:166869
# [618]	Test_set-rmse:577986	Test_set-mae:166864
# [619]	Test_set-rmse:577968	Test_set-mae:166864
# [620]	Test_set-rmse:577953	Test_set-mae:166852
# [621]	Test_set-rmse:577907	Test_set-mae:166837
# [622]	Test_set-rmse:577889	Test_set-mae:166816
# [623]	Test_set-rmse:577886	Test_set-mae:166801
# [624]	Test_set-rmse:577846	Test_set-mae:166786
# [625]	Test_set-rmse:577819	Test_set-mae:166758
# [626]	Test_set-rmse:577757	Test_set-mae:166745
# [627]	Test_set-rmse:577687	Test_set-mae:166716
# [628]	Test_set-rmse:577666	Test_set-mae:166711
# [629]	Test_set-rmse:577639	Test_set-mae:166688
# [630]	Test_set-rmse:577600	Test_set-mae:166680
# [631]	Test_set-rmse:577550	Test_set-mae:166670
# [632]	Test_set-rmse:577538	Test_set-mae:166658
# [633]	Test_set-rmse:577486	Test_set-mae:166634
# [634]	Test_set-rmse:577441	Test_set-mae:166607
# [635]	Test_set-rmse:577392	Test_set-mae:166599
# [636]	Test_set-rmse:577390	Test_set-mae:166575
# [637]	Test_set-rmse:577380	Test_set-mae:166570
# [638]	Test_set-rmse:577320	Test_set-mae:166550
# [639]	Test_set-rmse:577322	Test_set-mae:166541
# [640]	Test_set-rmse:577281	Test_set-mae:166527
# [641]	Test_set-rmse:577270	Test_set-mae:166515
# [642]	Test_set-rmse:577250	Test_set-mae:166499
# [643]	Test_set-rmse:577205	Test_set-mae:166476
# [644]	Test_set-rmse:577164	Test_set-mae:166452
# [645]	Test_set-rmse:577136	Test_set-mae:166432
# [646]	Test_set-rmse:577087	Test_set-mae:166418
# [647]	Test_set-rmse:577067	Test_set-mae:166407
# [648]	Test_set-rmse:577034	Test_set-mae:166396
# [649]	Test_set-rmse:576984	Test_set-mae:166376
# [650]	Test_set-rmse:576962	Test_set-mae:166351
# [651]	Test_set-rmse:576918	Test_set-mae:166329
# [652]	Test_set-rmse:576887	Test_set-mae:166308
# [653]	Test_set-rmse:576837	Test_set-mae:166296
# [654]	Test_set-rmse:576803	Test_set-mae:166285
# [655]	Test_set-rmse:576745	Test_set-mae:166258
# [656]	Test_set-rmse:576708	Test_set-mae:166233
# [657]	Test_set-rmse:576664	Test_set-mae:166215
# [658]	Test_set-rmse:576633	Test_set-mae:166203
# [659]	Test_set-rmse:576601	Test_set-mae:166187
# [660]	Test_set-rmse:576588	Test_set-mae:166183
# [661]	Test_set-rmse:576558	Test_set-mae:166174
# [662]	Test_set-rmse:576532	Test_set-mae:166159
# [663]	Test_set-rmse:576511	Test_set-mae:166148
# [664]	Test_set-rmse:576452	Test_set-mae:166136
# [665]	Test_set-rmse:576382	Test_set-mae:166119
# [666]	Test_set-rmse:576379	Test_set-mae:166113
# [667]	Test_set-rmse:576339	Test_set-mae:166094
# [668]	Test_set-rmse:576339	Test_set-mae:166078
# [669]	Test_set-rmse:576287	Test_set-mae:166064
# [670]	Test_set-rmse:576219	Test_set-mae:166048
# [671]	Test_set-rmse:576138	Test_set-mae:166030
# [672]	Test_set-rmse:576046	Test_set-mae:166004
# [673]	Test_set-rmse:576038	Test_set-mae:165994
# [674]	Test_set-rmse:576010	Test_set-mae:165976
# [675]	Test_set-rmse:575981	Test_set-mae:165965
# [676]	Test_set-rmse:575981	Test_set-mae:165963
# [677]	Test_set-rmse:575932	Test_set-mae:165952
# [678]	Test_set-rmse:575888	Test_set-mae:165936
# [679]	Test_set-rmse:575880	Test_set-mae:165926
# [680]	Test_set-rmse:575853	Test_set-mae:165913
# [681]	Test_set-rmse:575819	Test_set-mae:165892
# [682]	Test_set-rmse:575774	Test_set-mae:165874
# [683]	Test_set-rmse:575745	Test_set-mae:165860
# [684]	Test_set-rmse:575743	Test_set-mae:165856
# [685]	Test_set-rmse:575712	Test_set-mae:165844
# [686]	Test_set-rmse:575701	Test_set-mae:165824
# [687]	Test_set-rmse:575689	Test_set-mae:165813
# [688]	Test_set-rmse:575661	Test_set-mae:165790
# [689]	Test_set-rmse:575627	Test_set-mae:165773
# [690]	Test_set-rmse:575614	Test_set-mae:165766
# [691]	Test_set-rmse:575619	Test_set-mae:165756
# [692]	Test_set-rmse:575634	Test_set-mae:165746
# [693]	Test_set-rmse:575604	Test_set-mae:165732
# [694]	Test_set-rmse:575579	Test_set-mae:165721
# [695]	Test_set-rmse:575542	Test_set-mae:165720
# [696]	Test_set-rmse:575517	Test_set-mae:165714
# [697]	Test_set-rmse:575478	Test_set-mae:165696
# [698]	Test_set-rmse:575457	Test_set-mae:165689
# [699]	Test_set-rmse:575440	Test_set-mae:165674
# [700]	Test_set-rmse:575451	Test_set-mae:165676
# [701]	Test_set-rmse:575441	Test_set-mae:165675
# [702]	Test_set-rmse:575454	Test_set-mae:165673
# [703]	Test_set-rmse:575456	Test_set-mae:165672
# [704]	Test_set-rmse:575408	Test_set-mae:165640
# [705]	Test_set-rmse:575389	Test_set-mae:165624
# [706]	Test_set-rmse:575371	Test_set-mae:165619
# [707]	Test_set-rmse:575367	Test_set-mae:165612
# [708]	Test_set-rmse:575369	Test_set-mae:165605
# [709]	Test_set-rmse:575382	Test_set-mae:165596
# [710]	Test_set-rmse:575382	Test_set-mae:165580
# [711]	Test_set-rmse:575340	Test_set-mae:165559
# [712]	Test_set-rmse:575315	Test_set-mae:165543
# [713]	Test_set-rmse:575306	Test_set-mae:165540
# [714]	Test_set-rmse:575294	Test_set-mae:165536
# [715]	Test_set-rmse:575281	Test_set-mae:165528
# [716]	Test_set-rmse:575249	Test_set-mae:165516
# [717]	Test_set-rmse:575228	Test_set-mae:165496
# [718]	Test_set-rmse:575225	Test_set-mae:165496
# [719]	Test_set-rmse:575230	Test_set-mae:165487
# [720]	Test_set-rmse:575223	Test_set-mae:165482
# [721]	Test_set-rmse:575222	Test_set-mae:165468
# [722]	Test_set-rmse:575210	Test_set-mae:165460
# [723]	Test_set-rmse:575160	Test_set-mae:165450
# [724]	Test_set-rmse:575117	Test_set-mae:165440
# [725]	Test_set-rmse:575106	Test_set-mae:165435
# [726]	Test_set-rmse:575100	Test_set-mae:165431
# [727]	Test_set-rmse:575083	Test_set-mae:165417
# [728]	Test_set-rmse:575078	Test_set-mae:165410
# [729]	Test_set-rmse:575056	Test_set-mae:165391
# [730]	Test_set-rmse:575024	Test_set-mae:165378
# [731]	Test_set-rmse:575004	Test_set-mae:165364
# [732]	Test_set-rmse:575003	Test_set-mae:165350
# [733]	Test_set-rmse:574993	Test_set-mae:165347
# [734]	Test_set-rmse:574969	Test_set-mae:165330
# [735]	Test_set-rmse:574978	Test_set-mae:165330
# [736]	Test_set-rmse:574962	Test_set-mae:165326
# [737]	Test_set-rmse:574943	Test_set-mae:165321
# [738]	Test_set-rmse:574939	Test_set-mae:165315
# [739]	Test_set-rmse:574907	Test_set-mae:165304
# [740]	Test_set-rmse:574892	Test_set-mae:165286
# [741]	Test_set-rmse:574896	Test_set-mae:165262
# [742]	Test_set-rmse:574888	Test_set-mae:165250
# [743]	Test_set-rmse:574881	Test_set-mae:165233
# [744]	Test_set-rmse:574838	Test_set-mae:165214
# [745]	Test_set-rmse:574806	Test_set-mae:165199
# [746]	Test_set-rmse:574770	Test_set-mae:165191
# [747]	Test_set-rmse:574775	Test_set-mae:165191
# [748]	Test_set-rmse:574749	Test_set-mae:165185
# [749]	Test_set-rmse:574723	Test_set-mae:165169
# [750]	Test_set-rmse:574660	Test_set-mae:165146
# [751]	Test_set-rmse:574656	Test_set-mae:165143
# [752]	Test_set-rmse:574624	Test_set-mae:165135
# [753]	Test_set-rmse:574618	Test_set-mae:165128
# [754]	Test_set-rmse:574627	Test_set-mae:165131
# [755]	Test_set-rmse:574607	Test_set-mae:165133
# [756]	Test_set-rmse:574604	Test_set-mae:165123
# [757]	Test_set-rmse:574581	Test_set-mae:165109
# [758]	Test_set-rmse:574557	Test_set-mae:165102
# [759]	Test_set-rmse:574509	Test_set-mae:165089
# [760]	Test_set-rmse:574507	Test_set-mae:165082
# [761]	Test_set-rmse:574502	Test_set-mae:165074
# [762]	Test_set-rmse:574491	Test_set-mae:165061
# [763]	Test_set-rmse:574477	Test_set-mae:165058
# [764]	Test_set-rmse:574446	Test_set-mae:165049
# [765]	Test_set-rmse:574456	Test_set-mae:165046
# [766]	Test_set-rmse:574440	Test_set-mae:165032
# [767]	Test_set-rmse:574417	Test_set-mae:165017
# [768]	Test_set-rmse:574429	Test_set-mae:165015
# [769]	Test_set-rmse:574424	Test_set-mae:165003
# [770]	Test_set-rmse:574426	Test_set-mae:165002
# [771]	Test_set-rmse:574400	Test_set-mae:164986
# [772]	Test_set-rmse:574375	Test_set-mae:164975
# [773]	Test_set-rmse:574355	Test_set-mae:164963
# [774]	Test_set-rmse:574356	Test_set-mae:164950
# [775]	Test_set-rmse:574353	Test_set-mae:164949
# [776]	Test_set-rmse:574346	Test_set-mae:164942
# [777]	Test_set-rmse:574329	Test_set-mae:164934
# [778]	Test_set-rmse:574288	Test_set-mae:164927
# [779]	Test_set-rmse:574187	Test_set-mae:164923
# [780]	Test_set-rmse:574179	Test_set-mae:164918
# [781]	Test_set-rmse:574160	Test_set-mae:164914
# [782]	Test_set-rmse:574180	Test_set-mae:164915
# [783]	Test_set-rmse:574189	Test_set-mae:164912
# [784]	Test_set-rmse:574206	Test_set-mae:164903
# [785]	Test_set-rmse:574209	Test_set-mae:164896
# [786]	Test_set-rmse:574178	Test_set-mae:164882
# [787]	Test_set-rmse:574176	Test_set-mae:164864
# [788]	Test_set-rmse:574161	Test_set-mae:164861
# [789]	Test_set-rmse:574120	Test_set-mae:164851
# [790]	Test_set-rmse:574105	Test_set-mae:164843
# [791]	Test_set-rmse:574097	Test_set-mae:164825
# [792]	Test_set-rmse:574094	Test_set-mae:164817
# [793]	Test_set-rmse:574089	Test_set-mae:164812
# [794]	Test_set-rmse:574083	Test_set-mae:164808
# [795]	Test_set-rmse:574073	Test_set-mae:164802
# [796]	Test_set-rmse:574057	Test_set-mae:164783
# [797]	Test_set-rmse:574050	Test_set-mae:164778
# [798]	Test_set-rmse:574054	Test_set-mae:164768
# [799]	Test_set-rmse:574055	Test_set-mae:164757
# [800]	Test_set-rmse:574035	Test_set-mae:164747
# [801]	Test_set-rmse:574024	Test_set-mae:164745
# [802]	Test_set-rmse:574017	Test_set-mae:164734
# [803]	Test_set-rmse:574030	Test_set-mae:164733
# [804]	Test_set-rmse:574015	Test_set-mae:164720
# [805]	Test_set-rmse:574001	Test_set-mae:164713
# [806]	Test_set-rmse:574003	Test_set-mae:164698
# [807]	Test_set-rmse:574012	Test_set-mae:164693
# [808]	Test_set-rmse:574010	Test_set-mae:164691
# [809]	Test_set-rmse:573999	Test_set-mae:164685
# [810]	Test_set-rmse:573992	Test_set-mae:164669
# [811]	Test_set-rmse:573980	Test_set-mae:164662
# [812]	Test_set-rmse:573982	Test_set-mae:164657
# [813]	Test_set-rmse:573986	Test_set-mae:164653
# [814]	Test_set-rmse:573996	Test_set-mae:164651
# [815]	Test_set-rmse:573998	Test_set-mae:164647
# [816]	Test_set-rmse:573978	Test_set-mae:164636
# [817]	Test_set-rmse:573954	Test_set-mae:164625
# [818]	Test_set-rmse:573960	Test_set-mae:164611
# [819]	Test_set-rmse:573958	Test_set-mae:164605
# [820]	Test_set-rmse:573945	Test_set-mae:164584
# [821]	Test_set-rmse:573911	Test_set-mae:164568
# [822]	Test_set-rmse:573905	Test_set-mae:164555
# [823]	Test_set-rmse:573864	Test_set-mae:164548
# [824]	Test_set-rmse:573884	Test_set-mae:164549
# [825]	Test_set-rmse:573850	Test_set-mae:164542
# [826]	Test_set-rmse:573821	Test_set-mae:164517
# [827]	Test_set-rmse:573770	Test_set-mae:164495
# [828]	Test_set-rmse:573757	Test_set-mae:164483
# [829]	Test_set-rmse:573734	Test_set-mae:164479
# [830]	Test_set-rmse:573745	Test_set-mae:164471
# [831]	Test_set-rmse:573736	Test_set-mae:164458
# [832]	Test_set-rmse:573700	Test_set-mae:164449
# [833]	Test_set-rmse:573696	Test_set-mae:164446
# [834]	Test_set-rmse:573687	Test_set-mae:164445
# [835]	Test_set-rmse:573662	Test_set-mae:164436
# [836]	Test_set-rmse:573610	Test_set-mae:164422
# [837]	Test_set-rmse:573618	Test_set-mae:164403
# [838]	Test_set-rmse:573608	Test_set-mae:164394
# [839]	Test_set-rmse:573579	Test_set-mae:164390
# [840]	Test_set-rmse:573569	Test_set-mae:164387
# [841]	Test_set-rmse:573575	Test_set-mae:164386
# [842]	Test_set-rmse:573547	Test_set-mae:164376
# [843]	Test_set-rmse:573527	Test_set-mae:164367
# [844]	Test_set-rmse:573513	Test_set-mae:164364
# [845]	Test_set-rmse:573514	Test_set-mae:164361
# [846]	Test_set-rmse:573517	Test_set-mae:164351
# [847]	Test_set-rmse:573495	Test_set-mae:164327
# [848]	Test_set-rmse:573507	Test_set-mae:164324
# [849]	Test_set-rmse:573488	Test_set-mae:164319
# [850]	Test_set-rmse:573477	Test_set-mae:164300
# [851]	Test_set-rmse:573445	Test_set-mae:164284
# [852]	Test_set-rmse:573417	Test_set-mae:164276
# [853]	Test_set-rmse:573417	Test_set-mae:164273
# [854]	Test_set-rmse:573402	Test_set-mae:164254
# [855]	Test_set-rmse:573393	Test_set-mae:164245
# [856]	Test_set-rmse:573387	Test_set-mae:164241
# [857]	Test_set-rmse:573389	Test_set-mae:164236
# [858]	Test_set-rmse:573393	Test_set-mae:164239
# [859]	Test_set-rmse:573398	Test_set-mae:164236
# [860]	Test_set-rmse:573387	Test_set-mae:164228
# [861]	Test_set-rmse:573383	Test_set-mae:164210
# [862]	Test_set-rmse:573372	Test_set-mae:164202
# [863]	Test_set-rmse:573344	Test_set-mae:164196
# [864]	Test_set-rmse:573333	Test_set-mae:164194
# [865]	Test_set-rmse:573306	Test_set-mae:164187
# [866]	Test_set-rmse:573306	Test_set-mae:164177
# [867]	Test_set-rmse:573278	Test_set-mae:164167
# [868]	Test_set-rmse:573273	Test_set-mae:164152
# [869]	Test_set-rmse:573290	Test_set-mae:164143
# [870]	Test_set-rmse:573276	Test_set-mae:164127
# [871]	Test_set-rmse:573270	Test_set-mae:164115
# [872]	Test_set-rmse:573274	Test_set-mae:164108
# [873]	Test_set-rmse:573275	Test_set-mae:164102
# [874]	Test_set-rmse:573254	Test_set-mae:164090
# [875]	Test_set-rmse:573232	Test_set-mae:164085
# [876]	Test_set-rmse:573234	Test_set-mae:164081
# [877]	Test_set-rmse:573236	Test_set-mae:164068
# [878]	Test_set-rmse:573225	Test_set-mae:164063
# [879]	Test_set-rmse:573218	Test_set-mae:164057
# [880]	Test_set-rmse:573190	Test_set-mae:164045
# [881]	Test_set-rmse:573162	Test_set-mae:164038
# [882]	Test_set-rmse:573162	Test_set-mae:164041
# [883]	Test_set-rmse:573135	Test_set-mae:164032
# [884]	Test_set-rmse:573139	Test_set-mae:164023
# [885]	Test_set-rmse:573137	Test_set-mae:164024
# [886]	Test_set-rmse:573110	Test_set-mae:164008
# [887]	Test_set-rmse:573138	Test_set-mae:164002
# [888]	Test_set-rmse:573142	Test_set-mae:164000
# [889]	Test_set-rmse:573162	Test_set-mae:163996
# [890]	Test_set-rmse:573132	Test_set-mae:163985
# [891]	Test_set-rmse:573150	Test_set-mae:163978
# [892]	Test_set-rmse:573138	Test_set-mae:163971
# [893]	Test_set-rmse:573118	Test_set-mae:163962
# [894]	Test_set-rmse:573123	Test_set-mae:163952
# [895]	Test_set-rmse:573115	Test_set-mae:163941
# [896]	Test_set-rmse:573108	Test_set-mae:163936
# [897]	Test_set-rmse:573107	Test_set-mae:163932
# [898]	Test_set-rmse:573108	Test_set-mae:163925
# [899]	Test_set-rmse:573108	Test_set-mae:163919
# [900]	Test_set-rmse:573083	Test_set-mae:163902
# [901]	Test_set-rmse:573075	Test_set-mae:163895
# [902]	Test_set-rmse:573100	Test_set-mae:163897
# [903]	Test_set-rmse:573092	Test_set-mae:163887
# [904]	Test_set-rmse:573079	Test_set-mae:163886
# [905]	Test_set-rmse:573088	Test_set-mae:163888
# [906]	Test_set-rmse:573074	Test_set-mae:163875
# [907]	Test_set-rmse:573067	Test_set-mae:163863
# [908]	Test_set-rmse:573051	Test_set-mae:163859
# [909]	Test_set-rmse:573064	Test_set-mae:163850
# [910]	Test_set-rmse:573056	Test_set-mae:163845
# [911]	Test_set-rmse:573055	Test_set-mae:163844
# [912]	Test_set-rmse:573062	Test_set-mae:163842
# [913]	Test_set-rmse:573049	Test_set-mae:163837
# [914]	Test_set-rmse:573042	Test_set-mae:163834
# [915]	Test_set-rmse:573014	Test_set-mae:163819
# [916]	Test_set-rmse:573002	Test_set-mae:163811
# [917]	Test_set-rmse:572987	Test_set-mae:163801
# [918]	Test_set-rmse:572966	Test_set-mae:163788
# [919]	Test_set-rmse:572956	Test_set-mae:163780
# [920]	Test_set-rmse:572951	Test_set-mae:163773
# [921]	Test_set-rmse:572912	Test_set-mae:163775
# [922]	Test_set-rmse:572910	Test_set-mae:163770
# [923]	Test_set-rmse:572906	Test_set-mae:163769
# [924]	Test_set-rmse:572900	Test_set-mae:163769
# [925]	Test_set-rmse:572884	Test_set-mae:163762
# [926]	Test_set-rmse:572856	Test_set-mae:163756
# [927]	Test_set-rmse:572860	Test_set-mae:163756
# [928]	Test_set-rmse:572839	Test_set-mae:163754
# [929]	Test_set-rmse:572829	Test_set-mae:163744
# [930]	Test_set-rmse:572825	Test_set-mae:163730
# [931]	Test_set-rmse:572819	Test_set-mae:163710
# [932]	Test_set-rmse:572815	Test_set-mae:163708
# [933]	Test_set-rmse:572812	Test_set-mae:163708
# [934]	Test_set-rmse:572816	Test_set-mae:163712
# [935]	Test_set-rmse:572814	Test_set-mae:163699
# [936]	Test_set-rmse:572812	Test_set-mae:163699
# [937]	Test_set-rmse:572772	Test_set-mae:163695
# [938]	Test_set-rmse:572766	Test_set-mae:163694
# [939]	Test_set-rmse:572774	Test_set-mae:163692
# [940]	Test_set-rmse:572769	Test_set-mae:163690
# [941]	Test_set-rmse:572789	Test_set-mae:163694
# [942]	Test_set-rmse:572804	Test_set-mae:163692
# [943]	Test_set-rmse:572830	Test_set-mae:163691
# [944]	Test_set-rmse:572819	Test_set-mae:163687
# [945]	Test_set-rmse:572824	Test_set-mae:163684
# [946]	Test_set-rmse:572815	Test_set-mae:163676
# [947]	Test_set-rmse:572806	Test_set-mae:163668
# [948]	Test_set-rmse:572793	Test_set-mae:163662
# [949]	Test_set-rmse:572753	Test_set-mae:163662
# [950]	Test_set-rmse:572710	Test_set-mae:163639
# [951]	Test_set-rmse:572706	Test_set-mae:163632
# [952]	Test_set-rmse:572699	Test_set-mae:163625
# [953]	Test_set-rmse:572687	Test_set-mae:163619
# [954]	Test_set-rmse:572688	Test_set-mae:163613
# [955]	Test_set-rmse:572685	Test_set-mae:163599
# [956]	Test_set-rmse:572689	Test_set-mae:163598
# [957]	Test_set-rmse:572682	Test_set-mae:163600
# [958]	Test_set-rmse:572679	Test_set-mae:163598
# [959]	Test_set-rmse:572703	Test_set-mae:163597
# [960]	Test_set-rmse:572674	Test_set-mae:163588
# [961]	Test_set-rmse:572671	Test_set-mae:163580
# [962]	Test_set-rmse:572665	Test_set-mae:163574
# [963]	Test_set-rmse:572657	Test_set-mae:163570
# [964]	Test_set-rmse:572661	Test_set-mae:163553
# [965]	Test_set-rmse:572649	Test_set-mae:163545
# [966]	Test_set-rmse:572642	Test_set-mae:163539
# [967]	Test_set-rmse:572645	Test_set-mae:163538
# [968]	Test_set-rmse:572630	Test_set-mae:163532
# [969]	Test_set-rmse:572624	Test_set-mae:163531
# [970]	Test_set-rmse:572623	Test_set-mae:163529
# [971]	Test_set-rmse:572632	Test_set-mae:163521
# [972]	Test_set-rmse:572654	Test_set-mae:163524
# [973]	Test_set-rmse:572659	Test_set-mae:163522
# [974]	Test_set-rmse:572656	Test_set-mae:163521
# [975]	Test_set-rmse:572658	Test_set-mae:163512
# [976]	Test_set-rmse:572657	Test_set-mae:163505
# [977]	Test_set-rmse:572645	Test_set-mae:163498
# [978]	Test_set-rmse:572618	Test_set-mae:163493
# [979]	Test_set-rmse:572619	Test_set-mae:163487
# [980]	Test_set-rmse:572616	Test_set-mae:163493
# [981]	Test_set-rmse:572615	Test_set-mae:163491
# [982]	Test_set-rmse:572623	Test_set-mae:163490
# [983]	Test_set-rmse:572610	Test_set-mae:163483
# [984]	Test_set-rmse:572592	Test_set-mae:163475
# [985]	Test_set-rmse:572588	Test_set-mae:163470
# [986]	Test_set-rmse:572569	Test_set-mae:163446
# [987]	Test_set-rmse:572573	Test_set-mae:163438
# [988]	Test_set-rmse:572557	Test_set-mae:163441
# [989]	Test_set-rmse:572547	Test_set-mae:163440
# [990]	Test_set-rmse:572551	Test_set-mae:163442
# [991]	Test_set-rmse:572560	Test_set-mae:163445
# [992]	Test_set-rmse:572560	Test_set-mae:163445
# [993]	Test_set-rmse:572555	Test_set-mae:163442
# [994]	Test_set-rmse:572547	Test_set-mae:163435
# [995]	Test_set-rmse:572540	Test_set-mae:163429
# [996]	Test_set-rmse:572532	Test_set-mae:163426
# [997]	Test_set-rmse:572525	Test_set-mae:163412
# [998]	Test_set-rmse:572531	Test_set-mae:163409

# %%
print("Average guess error", mae_baseline_value)
print("vs Mean Absolute Error", mean_absolute_error(model_value.predict(dtest_value), y_test_value))
# Out:
# Average guess error 2821517.3238260644
# vs Mean Absolute Error 163409.43927481252

# %%
#!#Predict the value based on the model.
dpred_value = xgb.DMatrix(fifasup_mach, label = y_value)
y_pred = pd.Series(model_value.predict(dpred_value))

# %%
#!#Top 10% players with overpriced transfer values.
sub_value = y_value.subtract(y_pred)
exp_value = fifasup_mach.loc[sub_value.nlargest(int(len(sub_value)/1000)).index]
exp_value
# Out:
#      Age  Height(cm)  Weight(kgs)  Weak Foot  Inter_Rep  Overall  Potential  \
# 44    27  188.966778    88.923632        3.0        3.0       87         90
# 72    28  155.440415    72.137028        4.0        3.0       86         86
# 171   25  155.745200    64.877956        2.0        3.0       83         86
# 78    23  192.014630    76.220256        4.0        2.0       85         90
# 34    29  192.014630    92.099476        3.0        4.0       88         88
# 434   23  188.966778    84.840404        3.0        2.0       80         85
# 504   27  188.966778    86.201480        4.0        2.0       80         81
# 45    25  195.062481    83.933020        4.0        4.0       87         91
# 99    31  188.966778    89.831016        4.0        3.0       85         85
# 891   31  155.745200    76.220256        5.0        2.0       78         78
# 43    25  155.745200    74.859180        4.0        3.0       87         90
# 229   19  198.110332    89.831016        3.0        3.0       82         93
# 189   25  195.062481    89.831016        3.0        2.0       83         87
# 55    22  182.871076    74.859180        3.0        2.0       86         92
# 139   32  192.014630    84.840404        3.0        3.0       84         84
# 244   22  185.918927    83.933020        4.0        2.0       82         88
# 329   22  179.823225    69.868568        4.0        3.0       81         86
# 245   23  192.014630    83.933020        3.0        2.0       82         86
#
#      Difference  Release_Clause(€M)  Special  ...  LDM  CDM  RDM  RWB  LB  \
# 44            3          90500000.0     1660  ...   75   75   75   71  75
# 72            0          72600000.0     2182  ...   80   80   80   78  76
# 171           3          47900000.0     2098  ...   72   72   72   71  67
# 78            5          89600000.0     2206  ...   80   80   80   77  76
# 34            0          75900000.0     2038  ...   83   83   83   78  80
# 434           5            200000.0     1928  ...   78   78   78   74  75
# 504           1            200000.0     1191  ...   50   50   50   50  50
# 45            4         123200000.0     2247  ...   78   78   78   77  75
# 99            0          54500000.0     2154  ...   83   83   83   78  77
# 891           0            200000.0     2029  ...   76   76   76   77  76
# 43            3         114500000.0     1940  ...   53   53   53   54  52
# 229          11          55100000.0     1278  ...   50   50   50   50  50
# 189           4          37800000.0     1261  ...   50   50   50   50  50
# 55            6         125100000.0     2090  ...   59   59   59   65  61
# 139           0          41300000.0     2106  ...   72   72   72   71  71
# 244           6          58000000.0     1905  ...   56   56   56   59  54
# 329           5          35400000.0     2019  ...   59   59   59   64  60
# 245           4          42300000.0     1705  ...   74   74   74   70  73
#
#      LCB  CB  RCB  RB  Versatility
# 44    84  84   84  75            1
# 72    73  73   73  76            1
# 171   60  60   60  67            1
# 78    79  79   79  76            1
# 34    85  85   85  80            1
# 434   78  78   78  75            1
# 504   50  50   50  50            1
# 45    74  74   74  75            1
# 99    81  81   81  77            1
# 891   74  74   74  76            1
# 43    51  51   51  52            1
# 229   50  50   50  50            1
# 189   50  50   50  50            1
# 55    52  52   52  61            1
# 139   72  72   72  71            1
# 244   43  43   43  54            1
# 329   52  52   52  60            1
# 245   80  80   80  73            1
#
# [18 rows x 72 columns]

# %%
#Top 10% players with underpriced transfer values.
cheap_value = sub_value.nsmallest(int(len(sub_value)/1000))
cheap_value = fifasup_mach.loc[cheap_value.index]
cheap_value
# Out:
#       Age  Height(cm)  Weight(kgs)  Weak Foot  Inter_Rep  Overall  Potential  \
# 1819   24  170.679671    64.877956        4.0        1.0       75         81
# 1008   29  155.745200    79.849792        3.0        2.0       77         77
# 1964   26  182.871076    78.942408        3.0        1.0       75         78
# 26     26  179.823225    71.229644        3.0        3.0       88         89
# 1936   26  188.966778    81.210868        3.0        1.0       75         75
# 1902   26  170.679671    60.794728        4.0        1.0       75         75
# 173    24  155.745200    73.044412        4.0        3.0       83         86
# 2514   26  182.871076    77.127640        4.0        1.0       74         74
# 20     29  188.966778    76.220256        3.0        4.0       89         89
# 83     23  182.871076    77.127640        4.0        3.0       85         90
# 1602   28  182.871076    74.859180        4.0        1.0       75         75
# 3103   24  188.966778    82.118252        4.0        1.0       73         80
# 713    33  176.775373    74.859180        4.0        3.0       79         79
# 3170   24  188.966778    74.859180        3.0        1.0       73         78
# 49     29  173.727522    68.053800        3.0        3.0       87         87
# 2688   26  155.745200    71.229644        2.0        1.0       73         76
# 2347   29  192.014630    86.201480        3.0        1.0       74         75
# 2363   30  182.871076    82.118252        4.0        1.0       74         74
#
#       Difference  Release_Clause(€M)  Special  ...  LDM  CDM  RDM  RWB  LB  \
# 1819           6            200000.0     1837  ...   52   52   52   57  53
# 1008           0            200000.0     1933  ...   52   52   52   53  50
# 1964           3            200000.0     1868  ...   60   60   60   62  58
# 26             1         137300000.0     2146  ...   66   66   66   70  66
# 1936           0            200000.0     1877  ...   57   57   57   59  57
# 1902           0            200000.0     1849  ...   57   57   57   60  57
# 173            3          73400000.0     2015  ...   58   58   58   62  58
# 2514           0            200000.0     2003  ...   66   66   66   69  68
# 20             0         105600000.0     2065  ...   86   86   86   79  78
# 83             5         107300000.0     2196  ...   80   80   80   78  78
# 1602           0            200000.0     1848  ...   73   73   73   70  70
# 3103           7            200000.0     1995  ...   71   71   71   71  72
# 713            0          17200000.0     2070  ...   60   60   60   62  59
# 3170           5            200000.0     1732  ...   67   67   67   64  67
# 49             0          77900000.0     2230  ...   80   80   80   84  84
# 2688           3            200000.0     1838  ...   68   68   68   71  71
# 2347           1            200000.0     1648  ...   71   71   71   68  69
# 2363           0            200000.0     1786  ...   68   68   68   64  67
#
#       LCB  CB  RCB  RB  Versatility
# 1819   42  42   42  53            1
# 1008   46  46   46  50            1
# 1964   51  51   51  58            1
# 26     57  57   57  66            1
# 1936   52  52   52  57            1
# 1902   48  48   48  57            1
# 173    50  50   50  58            1
# 2514   62  62   62  68            1
# 20     82  82   82  78            1
# 83     78  78   78  78            1
# 1602   71  71   71  70            1
# 3103   72  72   72  72            1
# 713    53  53   53  59            1
# 3170   72  72   72  67            1
# 49     78  78   78  84            1
# 2688   68  68   68  71            1
# 2347   72  72   72  69            1
# 2363   73  73   73  67            1
#
# [18 rows x 72 columns]

# %%
model_value.save_model("model_value.model")

# %%
fifasup_mach.columns
# Out:
# Index(['Age', 'Height(cm)', 'Weight(kgs)', 'Weak Foot', 'Inter_Rep', 'Overall',
#        'Potential', 'Difference', 'Release_Clause(€M)', 'Special',
#        'SkillMoves', 'ShortPass', 'LongPass', 'ShotPower', 'LongShots',
#        'Penalties', 'Agility', 'Acceleration', 'SprintSpeed', 'Stamina',
#        'Strength', 'Reactions', 'Dribbling', 'BallControl', 'Aggression',
#        'Interceptions', 'Positioning', 'Vision', 'Balance', 'Composure',
#        'Crossing', 'Finishing', 'Jumping', 'HeadAccuracy', 'Marking',
#        'StandingTackle', 'SlidingTackle', 'GKDiving', 'Volleys', 'Curve',
#        'FKAccuracy', 'GKHandling', 'GKKicking', 'GKPositioning', 'GKReflexes',
#        'LS', 'ST', 'RS', 'LW', 'LF', 'CF', 'RF', 'RW', 'LAM', 'CAM', 'RAM',
#        'LM', 'LCM', 'CM', 'RCM', 'RM', 'LWB', 'LDM', 'CDM', 'RDM', 'RWB', 'LB',
#        'LCB', 'CB', 'RCB', 'RB', 'Versatility'],
#       dtype='object')

# %%
fifaw_value.shape
# Out:
# (15, 72)

# %%
loaded_modelv = xgb.Booster()
loaded_modelv.load_model("model_value.model")
# Out:
# [12:18:43] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.

# %%
fifaw_value['Value(€M)'] = loaded_modelv.predict(xgb.DMatrix(fifaw_value))

# %%
exchange_rate = 21.1473

# %%
fifaw_value['Value($M)'] = fifaw_value['Value(€M)'] * exchange_rate

# %%
fifaw_value
# Out:
#     Age  Height(cm)  Weight(kgs)  Weak Foot  Inter_Rep  Overall  Potential  \
# 0    26         167           55          4          4       92         95
# 1    34         170           60          4          5       92         92
# 2    30         161           58          5          3       91         91
# 3    26         170           66          4          4       90         91
# 4    40         170           62          4          3       90         92
# 5    26         156           52          5          2       88         91
# 6    28         160           55          2          3       82         82
# 7    28         152           52          4          4       82         84
# 8    30         166           57          4          3       83         83
# 9    27         175           68          3          4       81         84
# 10   24         165           59          3          2       81         88
# 11   24         169           60          3          5       80         86
# 12   25         160           59          4          3       77         79
# 13   27         162           58          4          4       78         79
# 14   25         174           63          3          2       78         83
#
#     Difference  Release_Clause(€M)  Special  ...  RDM  RWB  LB  LCB  CB  RCB  \
# 0            3              200000     1598  ...   82   26  76   51  57   99
# 1            0              200000     2202  ...   61   64  59   47  47   47
# 2            2              200000     1598  ...   77   31  76   28  23   85
# 3            1              200000     2246  ...   67   70  67   61  61   61
# 4            2              200000     2031  ...   58   60  57   54  54   54
# 5            3              200000     1598  ...   75   64  43   77  31   11
# 6            0              200000     2154  ...   83   78  77   81  81   81
# 7            2              200000     1926  ...   53   59  54   42  42   42
# 8            0              200000     1598  ...   90   96  60   32  30   36
# 9            3              200000     1598  ...   84   35  63   59  38   12
# 10           7              200000     1598  ...   52   83  16   17  56   25
# 11           6              200000     1598  ...   17   34  44   13  71   81
# 12           2              200000     1598  ...   84   70  28   40  72   84
# 13           1              200000     2058  ...   73   73  72   70  70   70
# 14           5              200000     1598  ...   31   51  65   54  67   75
#
#     RB  Versatility   Value(€M)     Value($M)
# 0   32            1  39915668.0  8.441086e+08
# 1   59            1  44689404.0  9.450603e+08
# 2   64            1  41998976.0  8.881650e+08
# 3   67            1  53855264.0  1.138893e+09
# 4   57            1  33680320.0  7.122479e+08
# 5   98            1  35581720.0  7.524573e+08
# 6   77            1  15570426.0  3.292725e+08
# 7   54            1  21335630.0  4.511910e+08
# 8   40            1  20480500.0  4.331073e+08
# 9   37            1  15166542.0  3.207314e+08
# 10  72            1  18375632.0  3.885950e+08
# 11  30            1  14290920.0  3.022144e+08
# 12  78            1  17864092.0  3.777773e+08
# 13  72            1   9657684.0  2.042340e+08
# 14  58            1  13452262.0  2.844790e+08
#
# [15 rows x 74 columns]

# %% [markdown]
# # MODELO 2: Predicción del salario

# %%
X_train_wage, X_test_wage, y_train_wage, y_test_wage = train_test_split(fifasup_mach, y_wage, test_size=0.2)

# %%
dtrain_wage = xgb.DMatrix(X_train_wage, label=y_train_wage)
dtest_wage = xgb.DMatrix(X_test_wage, label=y_test_wage)
evaluation_set_wage = [(dtest_wage, "Test_set")]

# %%
mean_train_wage = np.mean(y_train_wage)

baseline_predictions_wage = np.ones(y_test_wage.shape) * mean_train_wage

mae_baseline_wage = mean_absolute_error(y_test_wage, baseline_predictions_wage)

rmse_baseline_wage = sqrt(mean_squared_error(y_test_wage, baseline_predictions_wage))

print("Baseline MAE is {:.2f}".format(mae_baseline_wage))
print("Baseline RMSE is {:.2f}".format(rmse_baseline_wage))
# Out:
# Baseline MAE is 14535.36
# Baseline RMSE is 32249.61

# %%
best_score_wage = mae_baseline_wage
best_params_wage = {}
for i, grid_search_wage in enumerate(params_perms):
    print("Permutation number:", i+1)
    cv_results_wage = xgb.cv(grid_search_wage,
                        dtrain_wage,
                        num_boost_round=num_boost_round,
                        seed=42,
                        nfold=2,
                        metrics=['mae', 'rmse'],
                        early_stopping_rounds=early_stopping_rounds
                        )
    
    mean_mae_wage = cv_results_wage['test-mae-mean'].min()
    boost_rounds_wage = cv_results_wage['test-mae-mean'].argmin()
    print("\tMAE {} for {} rounds".format(mean_mae_wage, boost_rounds_wage))
    if mean_mae_wage < best_score_wage:
        best_score_wage = mean_mae_wage
        best_params_wage = grid_search_wage
# Out:
# Permutation number: 1
# [12:18:43] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [12:18:43] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 7478.4387205 for 150 rounds
# Permutation number: 2
# [12:19:42] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [12:19:42] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 7303.6918945 for 172 rounds
# Permutation number: 3
# [12:20:50] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [12:20:50] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 7554.022217 for 162 rounds
# Permutation number: 4
# [12:21:58] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [12:21:58] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 7380.8366695 for 171 rounds
# Permutation number: 5
# [12:23:09] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [12:23:09] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 7513.1223145 for 152 rounds
# Permutation number: 6
# [12:23:55] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [12:23:55] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 7386.415526999999 for 157 rounds
# Permutation number: 7
# [12:24:49] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [12:24:49] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 7589.8723145 for 159 rounds
# Permutation number: 8
# [12:25:52] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [12:25:52] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 7604.80542 for 164 rounds
# Permutation number: 9
# [12:26:41] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [12:26:41] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 7478.4387205 for 150 rounds
# Permutation number: 10
# [12:27:39] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [12:27:39] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 7303.6918945 for 172 rounds
# Permutation number: 11
# [12:28:47] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [12:28:47] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 7554.022217 for 162 rounds
# Permutation number: 12
# [12:29:55] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [12:29:55] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 7380.8366695 for 171 rounds
# Permutation number: 13
# [12:31:12] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [12:31:12] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 7513.1223145 for 152 rounds
# Permutation number: 14
# [12:32:08] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [12:32:08] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 7386.415526999999 for 157 rounds
# Permutation number: 15
# [12:33:06] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [12:33:06] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 7589.8723145 for 159 rounds
# Permutation number: 16
# [12:34:13] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [12:34:13] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 7604.80542 for 164 rounds
# Permutation number: 17
# [12:35:04] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [12:35:04] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 7554.733887 for 14 rounds
# Permutation number: 18
# [12:35:09] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [12:35:09] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 7476.188721 for 16 rounds
# Permutation number: 19
# [12:35:17] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [12:35:17] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 7582.36499 for 15 rounds
# Permutation number: 20
# [12:35:24] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [12:35:24] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 7505.101074 for 16 rounds
# Permutation number: 21
# [12:35:33] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [12:35:33] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 7574.373291 for 13 rounds
# Permutation number: 22
# [12:35:40] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [12:35:40] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 7470.817383 for 16 rounds
# Permutation number: 23
# [12:35:49] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [12:35:49] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 7592.4675295 for 15 rounds
# Permutation number: 24
# [12:35:57] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [12:35:58] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 7606.4104005 for 15 rounds
# Permutation number: 25
# [12:36:08] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [12:36:08] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 7554.733887 for 14 rounds
# Permutation number: 26
# [12:36:14] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [12:36:14] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 7476.188721 for 16 rounds
# Permutation number: 27
# [12:36:22] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [12:36:22] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 7582.36499 for 15 rounds
# Permutation number: 28
# [12:36:30] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [12:36:30] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 7505.101074 for 16 rounds
# Permutation number: 29
# [12:36:39] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [12:36:39] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 7574.373291 for 13 rounds
# Permutation number: 30
# [12:36:46] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [12:36:46] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 7470.817383 for 16 rounds
# Permutation number: 31
# [12:36:55] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [12:36:55] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 7592.4675295 for 15 rounds
# Permutation number: 32
# [12:37:04] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [12:37:04] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 7606.4104005 for 15 rounds

# %%
#!#Retrain a model with new best params
model_wage = xgb.train(
    best_params_wage,
    dtrain_wage,
    num_boost_round=num_boost_round,
    evals=evaluation_set_wage,
    early_stopping_rounds=early_stopping_rounds
)
# Out:
# [12:37:14] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	Test_set-rmse:34425.7	Test_set-mae:12456.8
# Multiple eval metrics have been passed: 'Test_set-mae' will be used for early stopping.
#
# Will train until Test_set-mae hasn't improved in 10 rounds.
# [1]	Test_set-rmse:34238.6	Test_set-mae:12336.3
# [2]	Test_set-rmse:34099.2	Test_set-mae:12226.5
# [3]	Test_set-rmse:33972.9	Test_set-mae:12118.4
# [4]	Test_set-rmse:33784.1	Test_set-mae:12011.3
# [5]	Test_set-rmse:33609.3	Test_set-mae:11907.2
# [6]	Test_set-rmse:33448.7	Test_set-mae:11806.5
# [7]	Test_set-rmse:33322.3	Test_set-mae:11705.6
# [8]	Test_set-rmse:33147.9	Test_set-mae:11606.6
# [9]	Test_set-rmse:33025.5	Test_set-mae:11507.6
# [10]	Test_set-rmse:32854.2	Test_set-mae:11414.3
# [11]	Test_set-rmse:32694.3	Test_set-mae:11326.7
# [12]	Test_set-rmse:32530.8	Test_set-mae:11239
# [13]	Test_set-rmse:32386.5	Test_set-mae:11153.9
# [14]	Test_set-rmse:32243.8	Test_set-mae:11071.3
# [15]	Test_set-rmse:32129.9	Test_set-mae:10977.3
# [16]	Test_set-rmse:31975.7	Test_set-mae:10892.8
# [17]	Test_set-rmse:31830.2	Test_set-mae:10816.4
# [18]	Test_set-rmse:31692.5	Test_set-mae:10740.4
# [19]	Test_set-rmse:31536	Test_set-mae:10662
# [20]	Test_set-rmse:31404.5	Test_set-mae:10588.9
# [21]	Test_set-rmse:31262	Test_set-mae:10514.1
# [22]	Test_set-rmse:31104.2	Test_set-mae:10440.2
# [23]	Test_set-rmse:30963.3	Test_set-mae:10371.9
# [24]	Test_set-rmse:30860.3	Test_set-mae:10288.5
# [25]	Test_set-rmse:30756.7	Test_set-mae:10208.3
# [26]	Test_set-rmse:30619.9	Test_set-mae:10142.9
# [27]	Test_set-rmse:30483.6	Test_set-mae:10079.6
# [28]	Test_set-rmse:30372.8	Test_set-mae:10021.3
# [29]	Test_set-rmse:30237.9	Test_set-mae:9956.72
# [30]	Test_set-rmse:30124	Test_set-mae:9898.97
# [31]	Test_set-rmse:29985.5	Test_set-mae:9835.37
# [32]	Test_set-rmse:29845.7	Test_set-mae:9775.4
# [33]	Test_set-rmse:29722.4	Test_set-mae:9713.86
# [34]	Test_set-rmse:29594.5	Test_set-mae:9653.25
# [35]	Test_set-rmse:29465.2	Test_set-mae:9596.1
# [36]	Test_set-rmse:29377.5	Test_set-mae:9528.3
# [37]	Test_set-rmse:29292.6	Test_set-mae:9461.52
# [38]	Test_set-rmse:29187.6	Test_set-mae:9410.87
# [39]	Test_set-rmse:29098.2	Test_set-mae:9364.89
# [40]	Test_set-rmse:28973.8	Test_set-mae:9313.41
# [41]	Test_set-rmse:28855.9	Test_set-mae:9262.91
# [42]	Test_set-rmse:28745.3	Test_set-mae:9212.94
# [43]	Test_set-rmse:28634.9	Test_set-mae:9167.92
# [44]	Test_set-rmse:28517.2	Test_set-mae:9120.01
# [45]	Test_set-rmse:28419.1	Test_set-mae:9075.71
# [46]	Test_set-rmse:28343.7	Test_set-mae:9019.97
# [47]	Test_set-rmse:28231.9	Test_set-mae:8976.06
# [48]	Test_set-rmse:28154.8	Test_set-mae:8921.36
# [49]	Test_set-rmse:28053.4	Test_set-mae:8882.35
# [50]	Test_set-rmse:27949.3	Test_set-mae:8843.39
# [51]	Test_set-rmse:27846.8	Test_set-mae:8806.52
# [52]	Test_set-rmse:27741.7	Test_set-mae:8767.26
# [53]	Test_set-rmse:27684.2	Test_set-mae:8720.93
# [54]	Test_set-rmse:27591	Test_set-mae:8686.21
# [55]	Test_set-rmse:27523.6	Test_set-mae:8640.77
# [56]	Test_set-rmse:27431.9	Test_set-mae:8605.08
# [57]	Test_set-rmse:27340.4	Test_set-mae:8569.11
# [58]	Test_set-rmse:27245.4	Test_set-mae:8535.46
# [59]	Test_set-rmse:27152.9	Test_set-mae:8504.38
# [60]	Test_set-rmse:27095.8	Test_set-mae:8465.3
# [61]	Test_set-rmse:27009	Test_set-mae:8435.08
# [62]	Test_set-rmse:26944.9	Test_set-mae:8396.92
# [63]	Test_set-rmse:26878.2	Test_set-mae:8372.61
# [64]	Test_set-rmse:26789.2	Test_set-mae:8344.93
# [65]	Test_set-rmse:26707	Test_set-mae:8321.27
# [66]	Test_set-rmse:26641.9	Test_set-mae:8300.14
# [67]	Test_set-rmse:26573.3	Test_set-mae:8272.74
# [68]	Test_set-rmse:26495.8	Test_set-mae:8249.12
# [69]	Test_set-rmse:26421.1	Test_set-mae:8226.04
# [70]	Test_set-rmse:26340.2	Test_set-mae:8202.72
# [71]	Test_set-rmse:26250.2	Test_set-mae:8178.68
# [72]	Test_set-rmse:26203.6	Test_set-mae:8148.77
# [73]	Test_set-rmse:26143.8	Test_set-mae:8128.79
# [74]	Test_set-rmse:26082.7	Test_set-mae:8109.95
# [75]	Test_set-rmse:26011.9	Test_set-mae:8090.06
# [76]	Test_set-rmse:25938.4	Test_set-mae:8068.03
# [77]	Test_set-rmse:25871.1	Test_set-mae:8050.01
# [78]	Test_set-rmse:25802.2	Test_set-mae:8032.03
# [79]	Test_set-rmse:25757.3	Test_set-mae:8004.39
# [80]	Test_set-rmse:25712.7	Test_set-mae:7980.33
# [81]	Test_set-rmse:25648.7	Test_set-mae:7963.76
# [82]	Test_set-rmse:25581.4	Test_set-mae:7945.34
# [83]	Test_set-rmse:25514.5	Test_set-mae:7930.46
# [84]	Test_set-rmse:25454	Test_set-mae:7914.29
# [85]	Test_set-rmse:25384.5	Test_set-mae:7896.54
# [86]	Test_set-rmse:25321.6	Test_set-mae:7878.99
# [87]	Test_set-rmse:25259.3	Test_set-mae:7862.6
# [88]	Test_set-rmse:25206.5	Test_set-mae:7848.73
# [89]	Test_set-rmse:25160.4	Test_set-mae:7836.29
# [90]	Test_set-rmse:25123.5	Test_set-mae:7818.25
# [91]	Test_set-rmse:25086.5	Test_set-mae:7798.56
# [92]	Test_set-rmse:25047.6	Test_set-mae:7781.38
# [93]	Test_set-rmse:24986.6	Test_set-mae:7763.98
# [94]	Test_set-rmse:24943.8	Test_set-mae:7753.28
# [95]	Test_set-rmse:24883.9	Test_set-mae:7740.81
# [96]	Test_set-rmse:24827.8	Test_set-mae:7726.95
# [97]	Test_set-rmse:24773.6	Test_set-mae:7712.55
# [98]	Test_set-rmse:24727.7	Test_set-mae:7702.42
# [99]	Test_set-rmse:24678.6	Test_set-mae:7693.12
# [100]	Test_set-rmse:24621.9	Test_set-mae:7680.77
# [101]	Test_set-rmse:24585.8	Test_set-mae:7666.08
# [102]	Test_set-rmse:24529.6	Test_set-mae:7653.4
# [103]	Test_set-rmse:24481.7	Test_set-mae:7642.48
# [104]	Test_set-rmse:24433.1	Test_set-mae:7633.09
# [105]	Test_set-rmse:24377.2	Test_set-mae:7622.7
# [106]	Test_set-rmse:24326.4	Test_set-mae:7611.18
# [107]	Test_set-rmse:24284.6	Test_set-mae:7602.37
# [108]	Test_set-rmse:24239.5	Test_set-mae:7593.42
# [109]	Test_set-rmse:24193.5	Test_set-mae:7581.11
# [110]	Test_set-rmse:24150	Test_set-mae:7572.07
# [111]	Test_set-rmse:24100.5	Test_set-mae:7562.09
# [112]	Test_set-rmse:24046.2	Test_set-mae:7552.42
# [113]	Test_set-rmse:24004.2	Test_set-mae:7545.57
# [114]	Test_set-rmse:23964.2	Test_set-mae:7539.26
# [115]	Test_set-rmse:23933.3	Test_set-mae:7533.62
# [116]	Test_set-rmse:23899.5	Test_set-mae:7527.47
# [117]	Test_set-rmse:23873.3	Test_set-mae:7518.44
# [118]	Test_set-rmse:23825.3	Test_set-mae:7509.07
# [119]	Test_set-rmse:23781.3	Test_set-mae:7501.82
# [120]	Test_set-rmse:23749.9	Test_set-mae:7496.76
# [121]	Test_set-rmse:23709.8	Test_set-mae:7491.08
# [122]	Test_set-rmse:23667.5	Test_set-mae:7484.36
# [123]	Test_set-rmse:23637.5	Test_set-mae:7478.27
# [124]	Test_set-rmse:23590.3	Test_set-mae:7473.34
# [125]	Test_set-rmse:23559.3	Test_set-mae:7468.56
# [126]	Test_set-rmse:23521.2	Test_set-mae:7463.67
# [127]	Test_set-rmse:23482.3	Test_set-mae:7458.81
# [128]	Test_set-rmse:23442.2	Test_set-mae:7451.71
# [129]	Test_set-rmse:23401.2	Test_set-mae:7445.52
# [130]	Test_set-rmse:23366.7	Test_set-mae:7440.53
# [131]	Test_set-rmse:23335.2	Test_set-mae:7437.38
# [132]	Test_set-rmse:23298.1	Test_set-mae:7433.6
# [133]	Test_set-rmse:23280	Test_set-mae:7428.76
# [134]	Test_set-rmse:23258	Test_set-mae:7425.65
# [135]	Test_set-rmse:23223.5	Test_set-mae:7423.26
# [136]	Test_set-rmse:23197.1	Test_set-mae:7420.97
# [137]	Test_set-rmse:23164.2	Test_set-mae:7417.37
# [138]	Test_set-rmse:23147.8	Test_set-mae:7413.27
# [139]	Test_set-rmse:23114.6	Test_set-mae:7408.72
# [140]	Test_set-rmse:23085.3	Test_set-mae:7405.37
# [141]	Test_set-rmse:23057.8	Test_set-mae:7402.07
# [142]	Test_set-rmse:23026.8	Test_set-mae:7398.67
# [143]	Test_set-rmse:23000.2	Test_set-mae:7395.71
# [144]	Test_set-rmse:22979.7	Test_set-mae:7395.56
# [145]	Test_set-rmse:22945.9	Test_set-mae:7391.27
# [146]	Test_set-rmse:22918.6	Test_set-mae:7388.87
# [147]	Test_set-rmse:22897.1	Test_set-mae:7387.15
# [148]	Test_set-rmse:22872.1	Test_set-mae:7385.78
# [149]	Test_set-rmse:22852.6	Test_set-mae:7383.49
# [150]	Test_set-rmse:22828.5	Test_set-mae:7379.93
# [151]	Test_set-rmse:22798.2	Test_set-mae:7375.4
# [152]	Test_set-rmse:22768.4	Test_set-mae:7375.01
# [153]	Test_set-rmse:22747.8	Test_set-mae:7373.89
# [154]	Test_set-rmse:22726	Test_set-mae:7371.43
# [155]	Test_set-rmse:22700.4	Test_set-mae:7367.74
# [156]	Test_set-rmse:22680.3	Test_set-mae:7366.12
# [157]	Test_set-rmse:22655.1	Test_set-mae:7365.36
# [158]	Test_set-rmse:22633.3	Test_set-mae:7364.55
# [159]	Test_set-rmse:22607.6	Test_set-mae:7362.86
# [160]	Test_set-rmse:22586.1	Test_set-mae:7363.31
# [161]	Test_set-rmse:22561	Test_set-mae:7360.5
# [162]	Test_set-rmse:22546.5	Test_set-mae:7359.23
# [163]	Test_set-rmse:22527.8	Test_set-mae:7358.74
# [164]	Test_set-rmse:22512.4	Test_set-mae:7357.24
# [165]	Test_set-rmse:22493.9	Test_set-mae:7356.78
# [166]	Test_set-rmse:22480.6	Test_set-mae:7357.62
# [167]	Test_set-rmse:22465.6	Test_set-mae:7354.52
# [168]	Test_set-rmse:22446.5	Test_set-mae:7354.5
# [169]	Test_set-rmse:22432.2	Test_set-mae:7352.35
# [170]	Test_set-rmse:22407	Test_set-mae:7350
# [171]	Test_set-rmse:22392.2	Test_set-mae:7347.46
# [172]	Test_set-rmse:22369.6	Test_set-mae:7346.68
# [173]	Test_set-rmse:22354.2	Test_set-mae:7347.86
# [174]	Test_set-rmse:22341.6	Test_set-mae:7347.24
# [175]	Test_set-rmse:22328.5	Test_set-mae:7346.55
# [176]	Test_set-rmse:22312.6	Test_set-mae:7347.06
# [177]	Test_set-rmse:22302	Test_set-mae:7347.06
# [178]	Test_set-rmse:22289.2	Test_set-mae:7349.53
# [179]	Test_set-rmse:22273.9	Test_set-mae:7348.36
# [180]	Test_set-rmse:22260.4	Test_set-mae:7348.5
# [181]	Test_set-rmse:22252.7	Test_set-mae:7349.64
# [182]	Test_set-rmse:22234.6	Test_set-mae:7349.5
# [183]	Test_set-rmse:22223.5	Test_set-mae:7349.3
# [184]	Test_set-rmse:22203.5	Test_set-mae:7347.21
# [185]	Test_set-rmse:22186.7	Test_set-mae:7346.9
# Stopping. Best iteration:
# [175]	Test_set-rmse:22328.5	Test_set-mae:7346.55

# %%
print("Average guess error", mae_baseline_wage)
print("vs Mean Absolute Error", mean_absolute_error(model_wage.predict(dtest_wage), y_test_wage))
# Out:
# Average guess error 14535.359641577184
# vs Mean Absolute Error 7346.8963366303715

# %%
#!#Predict the value based on the model.
dpred_wage = xgb.DMatrix(fifasup_mach, label = y_wage)
y_pred_wage = pd.Series(model_wage.predict(dpred_wage))

# %%
#!#Top 10% players with overpriced wages.
sub_wage = y_value.subtract(y_pred_wage)
exp_wage = fifasup_mach.loc[sub_wage.nlargest(int(len(sub_wage)/1000)).index]
exp_wage
# Out:
#     Age  Height(cm)  Weight(kgs)  Weak Foot  Inter_Rep  Overall  Potential  \
# 2    26  179.823225    68.053800        5.0        5.0       92         93
# 0    31  173.727522    72.137028        4.0        5.0       94         94
# 4    27  155.745200    69.868568        5.0        4.0       91         92
# 5    27  176.775373    73.951796        4.0        4.0       91         91
# 15   24  155.440415    74.859180        3.0        3.0       89         94
# 16   24  188.966778    88.923632        4.0        3.0       89         91
# 25   19  155.440415    73.044412        4.0        3.0       88         95
# 7    31  182.871076    86.201480        4.0        5.0       91         91
# 17   27  179.823225    73.044412        3.0        4.0       89         90
# 10   29  182.871076    79.849792        4.0        4.0       90         90
# 1    33  188.966778    83.025636        4.0        5.0       94         94
# 11   28  182.871076    76.220256        5.0        4.0       90         90
# 31   26  155.745200    76.220256        5.0        3.0       88         91
# 30   26  179.823225    78.942408        3.0        3.0       88         91
# 3    27  195.062481    76.220256        3.0        4.0       91         93
# 28   26  155.745200    78.035024        3.0        4.0       88         89
# 26   26  179.823225    71.229644        3.0        3.0       88         89
# 32   26  176.775373    68.053800        4.0        3.0       88         89
#
#     Difference  Release_Clause(€M)  Special  ...  LDM  CDM  RDM  RWB  LB  LCB  \
# 2            1         228100000.0     2143  ...   60   60   60   65  60   47
# 0            0         226500000.0     2202  ...   61   61   61   64  59   47
# 4            1         196400000.0     2281  ...   77   77   77   77  73   66
# 5            0         172100000.0     2142  ...   63   63   63   66  60   49
# 15           5         153500000.0     2092  ...   58   58   58   62  56   45
# 16           2         160700000.0     2165  ...   66   66   66   65  62   60
# 25           7         166100000.0     2118  ...   62   62   62   66  62   54
# 7            0         164000000.0     2346  ...   68   68   68   69  66   63
# 17           1         165800000.0     2246  ...   67   67   67   70  67   61
# 10           0         127100000.0     2152  ...   62   62   62   61  58   57
# 1            0         127100000.0     2228  ...   61   61   61   65  61   53
# 11           0         156800000.0     2190  ...   82   82   82   79  77   72
# 31           3         141500000.0     2117  ...   71   71   71   71  66   57
# 30           3         156200000.0     2137  ...   73   73   73   72  68   63
# 3            2         138600000.0     1471  ...   50   50   50   50  50   50
# 28           1            200000.0     2171  ...   68   68   68   69  65   58
# 26           1         137300000.0     2146  ...   66   66   66   70  66   57
# 32           1         147700000.0     2175  ...   70   70   70   71  67   58
#
#     CB  RCB  RB  Versatility
# 2   47   47  60            1
# 0   47   47  59            1
# 4   66   66  73            1
# 5   49   49  60            1
# 15  45   45  56            1
# 16  60   60  62            1
# 25  54   54  62            1
# 7   63   63  66            1
# 17  61   61  67            1
# 10  57   57  58            1
# 1   53   53  61            1
# 11  72   72  77            1
# 31  57   57  66            1
# 30  63   63  68            1
# 3   50   50  50            1
# 28  58   58  65            1
# 26  57   57  66            1
# 32  58   58  67            1
#
# [18 rows x 72 columns]

# %%
#!#Top 10% players with underpriced transfer values.
cheap_wage = sub_wage.nsmallest(int(len(sub_wage)/1000))
cheap_wage = fifasup_mach.loc[cheap_wage.index]
cheap_wage
# Out:
#        Age  Height(cm)  Weight(kgs)  Weak Foot  Inter_Rep  Overall  Potential  \
# 16628   38  188.966778    79.849792        2.0        1.0       57         57
# 16310   36  188.966778    83.933020        2.0        1.0       57         57
# 17657   35  198.110332    78.942408        2.0        1.0       53         53
# 16596   40  182.871076    86.201480        3.0        1.0       57         57
# 17842   39  185.918927    73.951796        3.0        1.0       52         52
# 15426   41  182.871076    83.025636        3.0        1.0       59         59
# 17209   37  188.966778    78.942408        2.0        1.0       55         55
# 15133   39  188.966778    88.923632        3.0        1.0       60         60
# 17704   36  182.871076    78.035024        2.0        1.0       53         53
# 16204   37  188.966778    88.016248        2.0        1.0       58         58
# 16249   37  192.014630    86.201480        3.0        1.0       58         58
# 16264   40  185.918927    76.220256        3.0        1.0       58         58
# 16565   36  155.745200    78.035024        2.0        1.0       57         57
# 15508   37  192.014630    88.923632        3.0        1.0       59         59
# 14759   37  188.966778    78.035024        3.0        1.0       60         60
# 17978   21  155.745200    74.859180        2.0        1.0       51         57
# 16936   35  185.918927    79.849792        2.0        1.0       56         56
# 18025   27  185.918927    76.220256        2.0        1.0       50         50
#
#        Difference  Release_Clause(€M)  Special  ...  LDM  CDM  RDM  RWB  LB  \
# 16628           0             13000.0     1001  ...   50   50   50   50  50
# 16310           0             18000.0     1117  ...   50   50   50   50  50
# 17657           0             18000.0     1000  ...   44   44   44   38  41
# 16596           0             17000.0     1066  ...   50   50   50   50  50
# 17842           0             22000.0     1473  ...   46   46   46   45  44
# 15426           0             18000.0     1031  ...   50   50   50   50  50
# 17209           0             13000.0      823  ...   50   50   50   50  50
# 15133           0             15000.0      942  ...   50   50   50   50  50
# 17704           0             15000.0      867  ...   50   50   50   50  50
# 16204           0             13000.0     1070  ...   50   50   50   50  50
# 16249           0             13000.0     1011  ...   50   50   50   50  50
# 16264           0             15000.0      965  ...   50   50   50   50  50
# 16565           0             13000.0     1175  ...   44   44   44   40  44
# 15508           0             18000.0     1039  ...   50   50   50   50  50
# 14759           0             22000.0      970  ...   50   50   50   50  50
# 17978           6            200000.0     1277  ...   31   31   31   34  33
# 16936           0             25000.0     1303  ...   50   50   50   50  50
# 18025           0             27000.0      941  ...   50   50   50   50  50
#
#        LCB  CB  RCB  RB  Versatility
# 16628   50  50   50  50            1
# 16310   50  50   50  50            1
# 17657   51  51   51  41            1
# 16596   50  50   50  50            1
# 17842   44  44   44  44            1
# 15426   50  50   50  50            1
# 17209   50  50   50  50            1
# 15133   50  50   50  50            1
# 17704   50  50   50  50            1
# 16204   50  50   50  50            1
# 16249   50  50   50  50            1
# 16264   50  50   50  50            1
# 16565   56  56   56  44            1
# 15508   50  50   50  50            1
# 14759   50  50   50  50            1
# 17978   30  30   30  33            1
# 16936   50  50   50  50            1
# 18025   50  50   50  50            1
#
# [18 rows x 72 columns]

# %%
model_wage.save_model("model_wage.model")

# %%
loaded_modelw = xgb.Booster()
loaded_modelw.load_model("model_wage.model")
# Out:
# [12:37:35] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.

# %%
fifaw_wage['Wage(€K)'] = loaded_modelw.predict(xgb.DMatrix(fifaw_wage))

# %%
exchange_rate = 21.1473

# %%
fifaw_wage['Wage($K)'] = (fifaw_wage['Wage(€K)'] * exchange_rate)/1000000

# %%
fifaw_wage['WageM($K)'] = (fifaw_wage['Wage($K)']/12)*1000

# %%
fifaw_wage
# Out:
#     Age  Height(cm)  Weight(kgs)  Weak Foot  Inter_Rep  Overall  Potential  \
# 0    26         167           55          4          4       92         95
# 1    34         170           60          4          5       92         92
# 2    30         161           58          5          3       91         91
# 3    26         170           66          4          4       90         91
# 4    40         170           62          4          3       90         92
# 5    26         156           52          5          2       88         91
# 6    28         160           55          2          3       82         82
# 7    28         152           52          4          4       82         84
# 8    30         166           57          4          3       83         83
# 9    27         175           68          3          4       81         84
# 10   24         165           59          3          2       81         88
# 11   24         169           60          3          5       80         86
# 12   25         160           59          4          3       77         79
# 13   27         162           58          4          4       78         79
# 14   25         174           63          3          2       78         83
#
#     Difference  Release_Clause(€M)  Special  ...  RWB  LB  LCB  CB  RCB  RB  \
# 0            3              200000     1598  ...   26  76   51  57   99  32
# 1            0              200000     2202  ...   64  59   47  47   47  59
# 2            2              200000     1598  ...   31  76   28  23   85  64
# 3            1              200000     2246  ...   70  67   61  61   61  67
# 4            2              200000     2031  ...   60  57   54  54   54  57
# 5            3              200000     1598  ...   64  43   77  31   11  98
# 6            0              200000     2154  ...   78  77   81  81   81  77
# 7            2              200000     1926  ...   59  54   42  42   42  54
# 8            0              200000     1598  ...   96  60   32  30   36  40
# 9            3              200000     1598  ...   35  63   59  38   12  37
# 10           7              200000     1598  ...   83  16   17  56   25  72
# 11           6              200000     1598  ...   34  44   13  71   81  30
# 12           2              200000     1598  ...   70  28   40  72   84  78
# 13           1              200000     2058  ...   73  72   70  70   70  72
# 14           5              200000     1598  ...   51  65   54  67   75  58
#
#     Versatility       Wage(€K)  Wage($K)   WageM($K)
# 0             1  146650.406250  3.101260  258.438354
# 1             1  156428.562500  3.308042  275.670146
# 2             1  178536.906250  3.775574  314.631146
# 3             1  125084.164062  2.645192  220.432708
# 4             1   98450.859375  2.081970  173.497490
# 5             1  115076.148438  2.433550  202.795833
# 6             1   61430.449219  1.299088  108.257344
# 7             1   55289.703125  1.169228   97.435667
# 8             1   60763.574219  1.284986  107.082135
# 9             1   61746.792969  1.305778  108.814833
# 10            1   51340.222656  1.085707   90.475594
# 11            1   65019.484375  1.374987  114.582219
# 12            1   67477.179688  1.426960  118.913354
# 13            1   52430.519531  1.108764   92.397000
# 14            1   48099.621094  1.017177   84.764760
#
# [15 rows x 75 columns]

# %%
df_names = pd.read_csv('wdata.csv')

# %%
df_names = df_names[['Name']]

# %%
fifaw_wage = fifaw_wage.join(df_names)

# %%
fifaw_value = fifaw_value.join(df_names)

# %%
fifaw_wage = fifaw_wage.set_index('Name')

# %%
fifaw_wage.to_csv('fifaw_wage_pred', encoding='utf-8', index=False)

# %%
fifaw_value = fifaw_value.set_index('Name')

# %%
fifaw_value.to_csv('fifaw_value_pred', encoding='utf-8', index=False)

# %%
fifaw_wage['Wage(€K)'].max()
# Out:
# 178536.9

# %%
fifaw_value['Value(€M)'].max()
# Out:
# 53855264.0
