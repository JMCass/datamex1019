# %%
import pandas as pd
import numpy as np
from pandas.io.json import json_normalize
from IPython.core.display import HTML
import os
import glob
import re
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline
from IPython.display import set_matplotlib_formats
set_matplotlib_formats('svg')

# %%
fifamach=pd.read_csv('unsupervized.csv')
fifamach.head()
# Out:
#        ID               Name Position  Age  Height(cm)  Weight(kgs)  \
# 0  158023           L. Messi       RF   31  173.727522    72.137028
# 1   20801  Cristiano Ronaldo       ST   33  188.966778    83.025636
# 2  190871          Neymar Jr       LW   26  179.823225    68.053800
# 3  193080             De Gea       GK   27  195.062481    76.220256
# 4  192985       K. De Bruyne      RCM   27  155.745200    69.868568
#
#   Preferred Foot  Weak Foot Nationality  Inter_Rep  ... CDM RDM  RWB  LB  LCB  \
# 0           Left        4.0   Argentina        5.0  ...  61  61   64  59   47
# 1          Right        4.0    Portugal        5.0  ...  61  61   65  61   53
# 2          Right        5.0      Brazil        5.0  ...  60  60   65  60   47
# 3          Right        3.0       Spain        4.0  ...  50  50   50  50   50
# 4          Right        5.0     Belgium        4.0  ...  77  77   77  73   66
#
#    CB  RCB  RB  Work RAttack  Work RDefence
# ...

# %%
fifamach.describe()
# Out:
#                   ID           Age    Height(cm)   Weight(kgs)     Weak Foot  \
# count   18207.000000  18207.000000  18207.000000  18207.000000  18207.000000
# mean   214298.338606     25.122206    176.687304     75.307016      2.947438
# std     29965.244204      4.669943     13.644282      7.065593      0.659591
# min        16.000000     16.000000    155.440415     49.906120      1.000000
# 25%    200315.500000     21.000000    155.745200     69.868568      3.000000
# 50%    221759.000000     25.000000    179.823225     74.859180      3.000000
# 75%    236529.500000     28.000000    185.918927     79.849792      3.000000
# max    246620.000000     45.000000    210.301737    110.247156      5.000000
#
#           Inter_Rep        Jersey       Overall     Potential     Value(€M)  \
# count  18207.000000  18207.000000  18207.000000  18207.000000  1.820700e+04
# mean       1.112924     19.481683     66.238699     71.307299  2.410696e+06
# ...

# %%
fifamach.isnull().sum(axis=0)
# Out:
# ID               0
# Name             0
# Position         0
# Age              0
# Height(cm)       0
#                 ..
# CB               0
# RCB              0
# RB               0
# Work RAttack     0
# Work RDefence    0
# Length: 84, dtype: int64

# %%
cols=[c for c in fifamach.columns.values if c not in ['Name', 'Position', 'Preferred Foot',
                                                   'Nationality', 'Club', 'Joined', 'Contract_Expiry',
                                                   'Work Rate', 'Work RAttack', 'Work RDefence']]

# %%
from sklearn.cluster import KMeans

kmeans=KMeans(n_clusters=4)
clusters=kmeans.fit(fifamach[cols])

# %%
len(clusters.cluster_centers_)
# Out:
# 4

# %%
clusters.cluster_centers_
# Out:
# array([[2.15724086e+05, 2.49930283e+01, 1.76634658e+02, 7.51749146e+01,
#         2.91279178e+00, 1.04400871e+00, 1.99946467e+01, 6.47400560e+01,
#         7.01040149e+01, 1.03999004e+06, 5.28534080e+03, 1.53373607e+06,
#         1.56163654e+03, 2.28050687e+00, 5.69996864e+01, 5.10747073e+01,
#         5.37508299e+01, 4.52782620e+01, 4.73291212e+01, 6.25849470e+01,
#         6.37904436e+01, 6.38891313e+01, 6.20495212e+01, 6.47178322e+01,
#         6.01492161e+01, 5.36092006e+01, 5.66070174e+01, 5.45811834e+01,
#         4.54698112e+01, 4.82774981e+01, 5.16968094e+01, 6.34795142e+01,
#         5.68685414e+01, 4.81446150e+01, 4.39110765e+01, 6.45470459e+01,
#         5.11283729e+01, 4.61959239e+01, 4.66219419e+01, 4.47475723e+01,
#         1.67916327e+01, 4.12424297e+01, 4.53683286e+01, 4.13356633e+01,
#         1.65671831e+01, 1.64235381e+01, 1.65493724e+01, 1.68976111e+01,
#         5.55959539e+01, 5.55959539e+01, 5.55959539e+01, 5.66305633e+01,
# ...

# %%
preds=clusters.fit_predict(fifamach[cols])
len(preds)
# Out:
# 18207

# %%
distancias=clusters.fit_transform(fifamach[cols])
len(distancias)
# Out:
# 18207

# %%
import numpy as np

distancias[np.where(preds==1)[0]]
# Out:
# array([[2.50183193e+08, 1.07063875e+08, 1.93953519e+08, 2.33040793e+08],
#        [1.46754923e+08, 1.12829664e+07, 9.07378183e+07, 1.29655129e+08],
#        [2.55204247e+08, 1.12044826e+08, 1.98960226e+08, 2.38057654e+08],
#        [1.54345551e+08, 1.12306143e+07, 9.81014912e+07, 1.37198925e+08],
#        [2.19467326e+08, 7.63097737e+07, 1.63223248e+08, 2.02320716e+08],
#        [1.93777209e+08, 5.07678908e+07, 1.37550020e+08, 1.76634234e+08],
#        [1.51031580e+08, 8.30982833e+06, 9.48071809e+07, 1.33889783e+08],
#        [1.80638240e+08, 3.75782177e+07, 1.24411257e+08, 1.63496155e+08],
#        [1.14537336e+08, 2.87353392e+07, 5.83192469e+07, 9.73960404e+07],
#        [1.57870211e+08, 1.54784276e+07, 1.01679757e+08, 1.40736296e+08],
#        [1.46754388e+08, 1.12804819e+07, 9.07371584e+07, 1.29654577e+08],
#        [1.72632411e+08, 2.95957842e+07, 1.16405787e+08, 1.55490343e+08],
#        [1.24335137e+08, 1.91013550e+07, 6.81123357e+07, 1.07192218e+08],
# ...

# %%
fifamach['cluster']=preds
fifamach.cluster.unique()
# Out:
# array([1, 3, 2, 0])

# %%
fifamach[fifamach.cluster==2]
# Out:
#           ID               Name Position  Age  Height(cm)  Weight(kgs)  \
# 28    198710       J. Rodríguez      LAM   26  155.745200    78.035024
# 38    167664         G. Higuaín       LS   30  185.918927    88.923632
# 75    135507        Fernandinho      CDM   33  155.440415    67.146416
# 76        41            Iniesta       LF   34  173.727522    68.053800
# 91    187961           Paulinho      LDM   29  182.871076    71.229644
# ...      ...                ...      ...  ...         ...          ...
# 4590  236496       M. Guendouzi      CDM   19  185.918927    68.053800
# 4654  239845    K. Galanopoulos      RDM   20  176.775373    72.137028
# 4719  225782  A. Maitland-Niles       CM   20  155.440415    71.229644
# 4763  225539         D. Solanke       ST   20  188.966778    79.849792
# 5334  244389           Fernando       LM   19  179.823225    72.137028
#
#      Preferred Foot  Weak Foot Nationality  Inter_Rep  ... RDM RWB  LB  LCB  \
# ...

# %%
fifamach[fifamach.cluster==0].Club.value_counts()
# Out:
# No Club       241
# Frosinone      31
# Millwall       30
# Cosenza        30
# Al Raed        30
#              ...
# Inter           5
# Roma            5
# SL Benfica      4
# Juventus        3
# Napoli          2
# Name: Club, Length: 652, dtype: int64

# %%
fifamach.groupby(['cluster'])['Value(€M)'].mean()
# Out:
# cluster
# 0    1.039990e+06
# 1    6.591000e+07
# 2    8.874289e+06
# 3    2.667893e+07
# Name: Value(€M), dtype: float64
